# %% [markdown]
# # Mine Safety
#
# We're interested in [US mine safety](https://arlweb.msha.gov/drs/drshome.htm), thank goodness we can search for these things.

# %% [markdown]
# ## Setup: Import what you'll need to search and scrape and Selenium

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait
import pandas as pd

# %% [markdown]
# ## Starting from `https://arlweb.msha.gov/drs/drshome.htm`, search for every operator with 'dirt' in their name, including abandoned mines.
#
# > - *Tip: If you can't make an element work using name, class or ID, try to use the XPath*

# %%
driver = webdriver.Chrome()

# %%
driver.get('https://arlweb.msha.gov/drs/drshome.htm')

# %%
text_input = driver.find_element_by_name('OperSearch')

# %%
driver.execute_script("arguments[0].scrollIntoView(true)", text_input)

# %%
text_input.send_keys('dirt')

# %%
search_button = driver.find_element_by_xpath('//*[@id="content"]/form[1]/table/tbody/tr[7]/td[3]/input[1]')
search_button.click()

# %% [markdown]
# ## Scrape the results page, saving it as `dirt-operators.csv`
#
# > - *Tip: Think about what each row in your dataset will be, and start by looping through that*
# > - *Tip: Printing is cool and good! Print everything! Move it into a dictionary later.*
# > - *Tip: If you don't want a row, think about what's in the row that makes it different. You can use an `if` statement or list slicing to skip the ones you aren't interested in.*
# > - *Tip: Make sure your dictionary and your loop variable have DIFFERENT NAMES*
# > - *Tip: After you've made your dictionary (and printed it, of course), you'll want to add it to your list of rows*
# > - *Tip: Be sure to import pandas to convert it to a dataframe*
# > - *Tip: Make sure you don't include the index when saving your dataframe*

# %%
operators = driver.find_elements_by_tag_name('tr')
for operator in operators:
    print(operator.text)
# Out:
# Operator Name or Mine Name
# Search
# Abandoned*
# Indicates Mine is Abandoned and Sealed
# *CM (Coal or Metal Mine/Nonmetal Mine)
# C
# M ...... Coal
# ...... Metal/Nonmetal
# Abandoned*
# Indicates Mine is Abandoned and Sealed
# *CM (Coal or Metal Mine/Nonmetal Mine)
# C
# M ...... Coal
# ...... Metal/Nonmetal
# ID State Operator Mine Name Type CM* Status Commodity More Info
# 3503598
# OR  Newberg Rock & Dirt   Newberg Rock & Dirt Surface M  Active  Crushed, Broken Stone NEC
# 1401575
# KS  Bender Sand & Dirt   BENDER SAND & DIRT Surface M  Intermittent  Construction Sand and Gravel
# 5001797
# AK  Dirt Company   Bush Pilot Surface M  Intermittent  Construction Sand and Gravel
# 2103723
# MN  Dirt Doctor Inc   Rock Lake Plant Surface M  Intermittent  Construction Sand and Gravel
# 2103914
# MN  Dirt Work Specialists LLC   Astec Plant Surface M  Intermittent  Construction Sand and Gravel
# 4104757
# TX  Dirt Works   Portable #1 Surface M  Intermittent  Construction Sand and Gravel
# 0801306
# FL  Holley Dirt Company, Inc   River Road Pit Surface M  Active  Sand, Common
# 3901432
# SD  Krueger Brothers Gravel & Dirt   PORTABLE SCREENER Surface M  Intermittent  Construction Sand and Gravel
# 3609624
# PA  M R Dirt   Forbes Pit Surface M  Temporarily Idled  Construction Sand and Gravel
# 3609931
# PA  M.R. Dirt Inc.   Camptown Quarry Surface M  Intermittent  Dimension Stone NEC
# 1519799
# KY  P B Dirt Movers, Inc   Fedscreek Surface Surface C  Active  Coal (Bituminous)
# 4407379
# VA  P B Dirt Movers, Inc.   No. 3 Surface C  New Mine
# 4407296
# VA  PB Dirt Movers   Mine No. 6 Underground C  Temporarily Idled  Coal (Bituminous)
# 0203332
# AZ  Prescott Dirt, LLC   Sandretto Drive Surface M  Intermittent  Construction Sand and Gravel
# 2901986
# NM  R D Blankenship Dirt Work LLC   R D BLANKENSHIP DIRT WORK Surface M  Active  Construction Sand and Gravel
# 0801417
# FL  Sand & Dirt, Inc   Molino Pit Surface M  Active  Sand, Common
# 4300768
# VT  SIMPSON DIRTWORX LLC   Pettibone Jaw Crusher Surface M  Intermittent  Construction Sand and Gravel
# 4300776
# VT  SIMPSON DIRTWORX LLC   Chieftan 1400 Surface M  Intermittent  Construction Sand and Gravel
# 2302283
# MO  Spry's Dirt & Gravel, Inc.   Mike's Money Pit Surface M  Intermittent  Construction Sand and Gravel
# 2103518
# MN  Vogt Dirt Service   Crusher Surface M  Intermittent  Construction Sand and Gravel
# Total Number of Mines Found:  20

# %% [markdown]
# ### Hopefully you know that each `tr` is supposed to be a row of your data. What is the index of the first row element that is actually a result?
#
# > - *Tip: `.text` will help you here.*
# > - *Tip: You aren't interesting in annotations or anything, just mines and where they are from*
# > - *Tip: Using `print("-----")` will help you keep track of different rows*
# > - *Tip: If you have a list called `animals`, `animals[2:]` will skip the first two and start with the third. You can use this to skip ahead to the 'good' data if you want*

# %%
first_id = driver.find_element_by_xpath('//*[@id="content"]/table[3]/tbody/tr[2]/td[1]/form/font') 
print(first_id.text)
# Out:
# 3503598

# %% [markdown]
# ### Loop through each operator result, printing its name
#
# > - *Tip: If you have a list called `animals`, `animals[2:]` will skip the first two and start with the third.*
# > - *Tip: You can use list slicing or an `if` statement to skip the non-data row(s). List slicing is probably easier, even if you aren't comfortable with it.*
# > - *Tip: or honestly you can use `try` and `except` if you know how it works.*
# > - *Tip: Once you have the "right" rows of data, you're going to be looking for a certain tag inside*
# > - *Tip: Sometimes you can't say "give me this class," and instead you have to say "give me all of the `div` elements, and then give me the third one."*

# %%
for operator in operators[7:]:
    print(operator.text)
# Out:
# 3503598
# OR  Newberg Rock & Dirt   Newberg Rock & Dirt Surface M  Active  Crushed, Broken Stone NEC
# 1401575
# KS  Bender Sand & Dirt   BENDER SAND & DIRT Surface M  Intermittent  Construction Sand and Gravel
# 5001797
# AK  Dirt Company   Bush Pilot Surface M  Intermittent  Construction Sand and Gravel
# 2103723
# MN  Dirt Doctor Inc   Rock Lake Plant Surface M  Intermittent  Construction Sand and Gravel
# 2103914
# MN  Dirt Work Specialists LLC   Astec Plant Surface M  Intermittent  Construction Sand and Gravel
# 4104757
# TX  Dirt Works   Portable #1 Surface M  Intermittent  Construction Sand and Gravel
# 0801306
# FL  Holley Dirt Company, Inc   River Road Pit Surface M  Active  Sand, Common
# 3901432
# SD  Krueger Brothers Gravel & Dirt   PORTABLE SCREENER Surface M  Intermittent  Construction Sand and Gravel
# 3609624
# PA  M R Dirt   Forbes Pit Surface M  Temporarily Idled  Construction Sand and Gravel
# 3609931
# PA  M.R. Dirt Inc.   Camptown Quarry Surface M  Intermittent  Dimension Stone NEC
# 1519799
# KY  P B Dirt Movers, Inc   Fedscreek Surface Surface C  Active  Coal (Bituminous)
# 4407379
# VA  P B Dirt Movers, Inc.   No. 3 Surface C  New Mine
# 4407296
# VA  PB Dirt Movers   Mine No. 6 Underground C  Temporarily Idled  Coal (Bituminous)
# 0203332
# AZ  Prescott Dirt, LLC   Sandretto Drive Surface M  Intermittent  Construction Sand and Gravel
# 2901986
# NM  R D Blankenship Dirt Work LLC   R D BLANKENSHIP DIRT WORK Surface M  Active  Construction Sand and Gravel
# 0801417
# FL  Sand & Dirt, Inc   Molino Pit Surface M  Active  Sand, Common
# 4300768
# VT  SIMPSON DIRTWORX LLC   Pettibone Jaw Crusher Surface M  Intermittent  Construction Sand and Gravel
# 4300776
# VT  SIMPSON DIRTWORX LLC   Chieftan 1400 Surface M  Intermittent  Construction Sand and Gravel
# 2302283
# MO  Spry's Dirt & Gravel, Inc.   Mike's Money Pit Surface M  Intermittent  Construction Sand and Gravel
# 2103518
# MN  Vogt Dirt Service   Crusher Surface M  Intermittent  Construction Sand and Gravel
# Total Number of Mines Found:  20

# %%
#operators = driver.find_elements_by_tag_name('tr')

for operator in operators[7:-1]:
    info = operator.find_elements_by_tag_name('td')
    print(info[2].text)
# Out:
# Newberg Rock & Dirt
# Bender Sand & Dirt
# Dirt Company
# Dirt Doctor Inc
# Dirt Work Specialists LLC
# Dirt Works
# Holley Dirt Company, Inc
# Krueger Brothers Gravel & Dirt
# M R Dirt
# M.R. Dirt Inc.
# P B Dirt Movers, Inc
# P B Dirt Movers, Inc.
# PB Dirt Movers
# Prescott Dirt, LLC
# R D Blankenship Dirt Work LLC
# Sand & Dirt, Inc
# SIMPSON DIRTWORX LLC
# SIMPSON DIRTWORX LLC
# Spry's Dirt & Gravel, Inc.
# Vogt Dirt Service

# %% [markdown]
# ### Loop through each operator result, printing its ID
#
# There should be ONE code per row, and NO empty rows between them.

# %%
#operators = driver.find_elements_by_tag_name('tr')

for operator in operators[7:-1]:
    info = operator.find_elements_by_tag_name('td')
    print(info[0].text)
# Out:
# 3503598
# 1401575
# 5001797
# 2103723
# 2103914
# 4104757
# 0801306
# 3901432
# 3609624
# 3609931
# 1519799
# 4407379
# 4407296
# 0203332
# 2901986
# 0801417
# 4300768
# 4300776
# 2302283
# 2103518

# %% [markdown]
# ## Saving the results
#
# ### Loop through each `tr` to create a list of dictionaries
#
# Each dictionary must contain
#
# - Operator ID
# - Operator name
# - Mine name
# - State
# - Mine type
# - Coal or metal
# - Status
# - Commodity
#
# Create a new dictionary for each row.
#
# > - *Tip: Start with an empty dictionary, then add the keys one at a time like we did during class*
# > - *Tip: You might want to save all of the cells in a variable, then use indexes to get the second, third, fourth, etc.*
# > - *Tip: I know you already skipped a bunch of rows already, but one of them still might be bad! Which one is it? How can you skip it? You might need to slice out some of the end of your list, too. Use `print` to help you debug, or just look at the page closely.*
# > - *Tip: Or, if you did the other homework already, `try` / `except` is also an option*

# %%
#operators = driver.find_elements_by_tag_name('tr')
rows = []

for operator in operators[7:-1]:
    print('-----------')
    info = operator.find_elements_by_tag_name('td')
   
    row = {}
    
    Operator_ID = info[0] 
    row['Operator_ID'] = Operator_ID.text
    
    Operator_name = info[2]
    row['Operator_name'] = Operator_name.text
    
    Mine_name = info[3]
    row['Mine_name'] = Mine_name.text
    
    State = info[1]
    row['State'] = State.text
    
    Mine_type = info[3]
    row['Mine_type'] = Mine_type.text
    
    C_M = info[5]
    row['C_M'] = C_M.text
    
    Status = info[6]
    row['Status'] = Status.text 
    
    Commodity = info[7]
    row['Commodity'] = Commodity.text 
    
    print(rows)
    rows.append(row)
# Out:
# -----------
# []
# -----------
# [{'Operator_ID': '3503598', 'Operator_name': 'Newberg Rock & Dirt  ', 'Mine_name': 'Newberg Rock & Dirt', 'State': 'OR ', 'Mine_type': 'Newberg Rock & Dirt', 'C_M': 'M ', 'Status': 'Active ', 'Commodity': 'Crushed, Broken Stone NEC '}]
# -----------
# [{'Operator_ID': '3503598', 'Operator_name': 'Newberg Rock & Dirt  ', 'Mine_name': 'Newberg Rock & Dirt', 'State': 'OR ', 'Mine_type': 'Newberg Rock & Dirt', 'C_M': 'M ', 'Status': 'Active ', 'Commodity': 'Crushed, Broken Stone NEC '}, {'Operator_ID': '1401575', 'Operator_name': 'Bender Sand & Dirt  ', 'Mine_name': 'BENDER SAND & DIRT', 'State': 'KS ', 'Mine_type': 'BENDER SAND & DIRT', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}]
# -----------
# [{'Operator_ID': '3503598', 'Operator_name': 'Newberg Rock & Dirt  ', 'Mine_name': 'Newberg Rock & Dirt', 'State': 'OR ', 'Mine_type': 'Newberg Rock & Dirt', 'C_M': 'M ', 'Status': 'Active ', 'Commodity': 'Crushed, Broken Stone NEC '}, {'Operator_ID': '1401575', 'Operator_name': 'Bender Sand & Dirt  ', 'Mine_name': 'BENDER SAND & DIRT', 'State': 'KS ', 'Mine_type': 'BENDER SAND & DIRT', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '5001797', 'Operator_name': 'Dirt Company  ', 'Mine_name': 'Bush Pilot', 'State': 'AK ', 'Mine_type': 'Bush Pilot', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}]
# -----------
# [{'Operator_ID': '3503598', 'Operator_name': 'Newberg Rock & Dirt  ', 'Mine_name': 'Newberg Rock & Dirt', 'State': 'OR ', 'Mine_type': 'Newberg Rock & Dirt', 'C_M': 'M ', 'Status': 'Active ', 'Commodity': 'Crushed, Broken Stone NEC '}, {'Operator_ID': '1401575', 'Operator_name': 'Bender Sand & Dirt  ', 'Mine_name': 'BENDER SAND & DIRT', 'State': 'KS ', 'Mine_type': 'BENDER SAND & DIRT', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '5001797', 'Operator_name': 'Dirt Company  ', 'Mine_name': 'Bush Pilot', 'State': 'AK ', 'Mine_type': 'Bush Pilot', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '2103723', 'Operator_name': 'Dirt Doctor Inc  ', 'Mine_name': 'Rock Lake Plant', 'State': 'MN ', 'Mine_type': 'Rock Lake Plant', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}]
# -----------
# [{'Operator_ID': '3503598', 'Operator_name': 'Newberg Rock & Dirt  ', 'Mine_name': 'Newberg Rock & Dirt', 'State': 'OR ', 'Mine_type': 'Newberg Rock & Dirt', 'C_M': 'M ', 'Status': 'Active ', 'Commodity': 'Crushed, Broken Stone NEC '}, {'Operator_ID': '1401575', 'Operator_name': 'Bender Sand & Dirt  ', 'Mine_name': 'BENDER SAND & DIRT', 'State': 'KS ', 'Mine_type': 'BENDER SAND & DIRT', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '5001797', 'Operator_name': 'Dirt Company  ', 'Mine_name': 'Bush Pilot', 'State': 'AK ', 'Mine_type': 'Bush Pilot', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '2103723', 'Operator_name': 'Dirt Doctor Inc  ', 'Mine_name': 'Rock Lake Plant', 'State': 'MN ', 'Mine_type': 'Rock Lake Plant', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '2103914', 'Operator_name': 'Dirt Work Specialists LLC  ', 'Mine_name': 'Astec Plant', 'State': 'MN ', 'Mine_type': 'Astec Plant', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}]
# -----------
# [{'Operator_ID': '3503598', 'Operator_name': 'Newberg Rock & Dirt  ', 'Mine_name': 'Newberg Rock & Dirt', 'State': 'OR ', 'Mine_type': 'Newberg Rock & Dirt', 'C_M': 'M ', 'Status': 'Active ', 'Commodity': 'Crushed, Broken Stone NEC '}, {'Operator_ID': '1401575', 'Operator_name': 'Bender Sand & Dirt  ', 'Mine_name': 'BENDER SAND & DIRT', 'State': 'KS ', 'Mine_type': 'BENDER SAND & DIRT', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '5001797', 'Operator_name': 'Dirt Company  ', 'Mine_name': 'Bush Pilot', 'State': 'AK ', 'Mine_type': 'Bush Pilot', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '2103723', 'Operator_name': 'Dirt Doctor Inc  ', 'Mine_name': 'Rock Lake Plant', 'State': 'MN ', 'Mine_type': 'Rock Lake Plant', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '2103914', 'Operator_name': 'Dirt Work Specialists LLC  ', 'Mine_name': 'Astec Plant', 'State': 'MN ', 'Mine_type': 'Astec Plant', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '4104757', 'Operator_name': 'Dirt Works  ', 'Mine_name': 'Portable #1', 'State': 'TX ', 'Mine_type': 'Portable #1', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}]
# -----------
# [{'Operator_ID': '3503598', 'Operator_name': 'Newberg Rock & Dirt  ', 'Mine_name': 'Newberg Rock & Dirt', 'State': 'OR ', 'Mine_type': 'Newberg Rock & Dirt', 'C_M': 'M ', 'Status': 'Active ', 'Commodity': 'Crushed, Broken Stone NEC '}, {'Operator_ID': '1401575', 'Operator_name': 'Bender Sand & Dirt  ', 'Mine_name': 'BENDER SAND & DIRT', 'State': 'KS ', 'Mine_type': 'BENDER SAND & DIRT', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '5001797', 'Operator_name': 'Dirt Company  ', 'Mine_name': 'Bush Pilot', 'State': 'AK ', 'Mine_type': 'Bush Pilot', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '2103723', 'Operator_name': 'Dirt Doctor Inc  ', 'Mine_name': 'Rock Lake Plant', 'State': 'MN ', 'Mine_type': 'Rock Lake Plant', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '2103914', 'Operator_name': 'Dirt Work Specialists LLC  ', 'Mine_name': 'Astec Plant', 'State': 'MN ', 'Mine_type': 'Astec Plant', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '4104757', 'Operator_name': 'Dirt Works  ', 'Mine_name': 'Portable #1', 'State': 'TX ', 'Mine_type': 'Portable #1', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '0801306', 'Operator_name': 'Holley Dirt Company, Inc  ', 'Mine_name': 'River Road Pit', 'State': 'FL ', 'Mine_type': 'River Road Pit', 'C_M': 'M ', 'Status': 'Active ', 'Commodity': 'Sand, Common '}]
# -----------
# [{'Operator_ID': '3503598', 'Operator_name': 'Newberg Rock & Dirt  ', 'Mine_name': 'Newberg Rock & Dirt', 'State': 'OR ', 'Mine_type': 'Newberg Rock & Dirt', 'C_M': 'M ', 'Status': 'Active ', 'Commodity': 'Crushed, Broken Stone NEC '}, {'Operator_ID': '1401575', 'Operator_name': 'Bender Sand & Dirt  ', 'Mine_name': 'BENDER SAND & DIRT', 'State': 'KS ', 'Mine_type': 'BENDER SAND & DIRT', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '5001797', 'Operator_name': 'Dirt Company  ', 'Mine_name': 'Bush Pilot', 'State': 'AK ', 'Mine_type': 'Bush Pilot', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '2103723', 'Operator_name': 'Dirt Doctor Inc  ', 'Mine_name': 'Rock Lake Plant', 'State': 'MN ', 'Mine_type': 'Rock Lake Plant', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '2103914', 'Operator_name': 'Dirt Work Specialists LLC  ', 'Mine_name': 'Astec Plant', 'State': 'MN ', 'Mine_type': 'Astec Plant', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '4104757', 'Operator_name': 'Dirt Works  ', 'Mine_name': 'Portable #1', 'State': 'TX ', 'Mine_type': 'Portable #1', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '0801306', 'Operator_name': 'Holley Dirt Company, Inc  ', 'Mine_name': 'River Road Pit', 'State': 'FL ', 'Mine_type': 'River Road Pit', 'C_M': 'M ', 'Status': 'Active ', 'Commodity': 'Sand, Common '}, {'Operator_ID': '3901432', 'Operator_name': 'Krueger Brothers Gravel & Dirt  ', 'Mine_name': 'PORTABLE SCREENER', 'State': 'SD ', 'Mine_type': 'PORTABLE SCREENER', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}]
# -----------
# [{'Operator_ID': '3503598', 'Operator_name': 'Newberg Rock & Dirt  ', 'Mine_name': 'Newberg Rock & Dirt', 'State': 'OR ', 'Mine_type': 'Newberg Rock & Dirt', 'C_M': 'M ', 'Status': 'Active ', 'Commodity': 'Crushed, Broken Stone NEC '}, {'Operator_ID': '1401575', 'Operator_name': 'Bender Sand & Dirt  ', 'Mine_name': 'BENDER SAND & DIRT', 'State': 'KS ', 'Mine_type': 'BENDER SAND & DIRT', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '5001797', 'Operator_name': 'Dirt Company  ', 'Mine_name': 'Bush Pilot', 'State': 'AK ', 'Mine_type': 'Bush Pilot', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '2103723', 'Operator_name': 'Dirt Doctor Inc  ', 'Mine_name': 'Rock Lake Plant', 'State': 'MN ', 'Mine_type': 'Rock Lake Plant', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '2103914', 'Operator_name': 'Dirt Work Specialists LLC  ', 'Mine_name': 'Astec Plant', 'State': 'MN ', 'Mine_type': 'Astec Plant', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '4104757', 'Operator_name': 'Dirt Works  ', 'Mine_name': 'Portable #1', 'State': 'TX ', 'Mine_type': 'Portable #1', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '0801306', 'Operator_name': 'Holley Dirt Company, Inc  ', 'Mine_name': 'River Road Pit', 'State': 'FL ', 'Mine_type': 'River Road Pit', 'C_M': 'M ', 'Status': 'Active ', 'Commodity': 'Sand, Common '}, {'Operator_ID': '3901432', 'Operator_name': 'Krueger Brothers Gravel & Dirt  ', 'Mine_name': 'PORTABLE SCREENER', 'State': 'SD ', 'Mine_type': 'PORTABLE SCREENER', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '3609624', 'Operator_name': 'M R Dirt  ', 'Mine_name': 'Forbes Pit', 'State': 'PA ', 'Mine_type': 'Forbes Pit', 'C_M': 'M ', 'Status': 'Temporarily Idled ', 'Commodity': 'Construction Sand and Gravel '}]
# -----------
# [{'Operator_ID': '3503598', 'Operator_name': 'Newberg Rock & Dirt  ', 'Mine_name': 'Newberg Rock & Dirt', 'State': 'OR ', 'Mine_type': 'Newberg Rock & Dirt', 'C_M': 'M ', 'Status': 'Active ', 'Commodity': 'Crushed, Broken Stone NEC '}, {'Operator_ID': '1401575', 'Operator_name': 'Bender Sand & Dirt  ', 'Mine_name': 'BENDER SAND & DIRT', 'State': 'KS ', 'Mine_type': 'BENDER SAND & DIRT', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '5001797', 'Operator_name': 'Dirt Company  ', 'Mine_name': 'Bush Pilot', 'State': 'AK ', 'Mine_type': 'Bush Pilot', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '2103723', 'Operator_name': 'Dirt Doctor Inc  ', 'Mine_name': 'Rock Lake Plant', 'State': 'MN ', 'Mine_type': 'Rock Lake Plant', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '2103914', 'Operator_name': 'Dirt Work Specialists LLC  ', 'Mine_name': 'Astec Plant', 'State': 'MN ', 'Mine_type': 'Astec Plant', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '4104757', 'Operator_name': 'Dirt Works  ', 'Mine_name': 'Portable #1', 'State': 'TX ', 'Mine_type': 'Portable #1', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '0801306', 'Operator_name': 'Holley Dirt Company, Inc  ', 'Mine_name': 'River Road Pit', 'State': 'FL ', 'Mine_type': 'River Road Pit', 'C_M': 'M ', 'Status': 'Active ', 'Commodity': 'Sand, Common '}, {'Operator_ID': '3901432', 'Operator_name': 'Krueger Brothers Gravel & Dirt  ', 'Mine_name': 'PORTABLE SCREENER', 'State': 'SD ', 'Mine_type': 'PORTABLE SCREENER', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '3609624', 'Operator_name': 'M R Dirt  ', 'Mine_name': 'Forbes Pit', 'State': 'PA ', 'Mine_type': 'Forbes Pit', 'C_M': 'M ', 'Status': 'Temporarily Idled ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '3609931', 'Operator_name': 'M.R. Dirt Inc.  ', 'Mine_name': 'Camptown Quarry', 'State': 'PA ', 'Mine_type': 'Camptown Quarry', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Dimension Stone NEC '}]
# -----------
# [{'Operator_ID': '3503598', 'Operator_name': 'Newberg Rock & Dirt  ', 'Mine_name': 'Newberg Rock & Dirt', 'State': 'OR ', 'Mine_type': 'Newberg Rock & Dirt', 'C_M': 'M ', 'Status': 'Active ', 'Commodity': 'Crushed, Broken Stone NEC '}, {'Operator_ID': '1401575', 'Operator_name': 'Bender Sand & Dirt  ', 'Mine_name': 'BENDER SAND & DIRT', 'State': 'KS ', 'Mine_type': 'BENDER SAND & DIRT', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '5001797', 'Operator_name': 'Dirt Company  ', 'Mine_name': 'Bush Pilot', 'State': 'AK ', 'Mine_type': 'Bush Pilot', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '2103723', 'Operator_name': 'Dirt Doctor Inc  ', 'Mine_name': 'Rock Lake Plant', 'State': 'MN ', 'Mine_type': 'Rock Lake Plant', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '2103914', 'Operator_name': 'Dirt Work Specialists LLC  ', 'Mine_name': 'Astec Plant', 'State': 'MN ', 'Mine_type': 'Astec Plant', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '4104757', 'Operator_name': 'Dirt Works  ', 'Mine_name': 'Portable #1', 'State': 'TX ', 'Mine_type': 'Portable #1', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '0801306', 'Operator_name': 'Holley Dirt Company, Inc  ', 'Mine_name': 'River Road Pit', 'State': 'FL ', 'Mine_type': 'River Road Pit', 'C_M': 'M ', 'Status': 'Active ', 'Commodity': 'Sand, Common '}, {'Operator_ID': '3901432', 'Operator_name': 'Krueger Brothers Gravel & Dirt  ', 'Mine_name': 'PORTABLE SCREENER', 'State': 'SD ', 'Mine_type': 'PORTABLE SCREENER', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '3609624', 'Operator_name': 'M R Dirt  ', 'Mine_name': 'Forbes Pit', 'State': 'PA ', 'Mine_type': 'Forbes Pit', 'C_M': 'M ', 'Status': 'Temporarily Idled ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '3609931', 'Operator_name': 'M.R. Dirt Inc.  ', 'Mine_name': 'Camptown Quarry', 'State': 'PA ', 'Mine_type': 'Camptown Quarry', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Dimension Stone NEC '}, {'Operator_ID': '1519799', 'Operator_name': 'P B Dirt Movers, Inc  ', 'Mine_name': 'Fedscreek Surface', 'State': 'KY ', 'Mine_type': 'Fedscreek Surface', 'C_M': 'C ', 'Status': 'Active ', 'Commodity': 'Coal (Bituminous) '}]
# -----------
# [{'Operator_ID': '3503598', 'Operator_name': 'Newberg Rock & Dirt  ', 'Mine_name': 'Newberg Rock & Dirt', 'State': 'OR ', 'Mine_type': 'Newberg Rock & Dirt', 'C_M': 'M ', 'Status': 'Active ', 'Commodity': 'Crushed, Broken Stone NEC '}, {'Operator_ID': '1401575', 'Operator_name': 'Bender Sand & Dirt  ', 'Mine_name': 'BENDER SAND & DIRT', 'State': 'KS ', 'Mine_type': 'BENDER SAND & DIRT', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '5001797', 'Operator_name': 'Dirt Company  ', 'Mine_name': 'Bush Pilot', 'State': 'AK ', 'Mine_type': 'Bush Pilot', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '2103723', 'Operator_name': 'Dirt Doctor Inc  ', 'Mine_name': 'Rock Lake Plant', 'State': 'MN ', 'Mine_type': 'Rock Lake Plant', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '2103914', 'Operator_name': 'Dirt Work Specialists LLC  ', 'Mine_name': 'Astec Plant', 'State': 'MN ', 'Mine_type': 'Astec Plant', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '4104757', 'Operator_name': 'Dirt Works  ', 'Mine_name': 'Portable #1', 'State': 'TX ', 'Mine_type': 'Portable #1', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '0801306', 'Operator_name': 'Holley Dirt Company, Inc  ', 'Mine_name': 'River Road Pit', 'State': 'FL ', 'Mine_type': 'River Road Pit', 'C_M': 'M ', 'Status': 'Active ', 'Commodity': 'Sand, Common '}, {'Operator_ID': '3901432', 'Operator_name': 'Krueger Brothers Gravel & Dirt  ', 'Mine_name': 'PORTABLE SCREENER', 'State': 'SD ', 'Mine_type': 'PORTABLE SCREENER', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '3609624', 'Operator_name': 'M R Dirt  ', 'Mine_name': 'Forbes Pit', 'State': 'PA ', 'Mine_type': 'Forbes Pit', 'C_M': 'M ', 'Status': 'Temporarily Idled ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '3609931', 'Operator_name': 'M.R. Dirt Inc.  ', 'Mine_name': 'Camptown Quarry', 'State': 'PA ', 'Mine_type': 'Camptown Quarry', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Dimension Stone NEC '}, {'Operator_ID': '1519799', 'Operator_name': 'P B Dirt Movers, Inc  ', 'Mine_name': 'Fedscreek Surface', 'State': 'KY ', 'Mine_type': 'Fedscreek Surface', 'C_M': 'C ', 'Status': 'Active ', 'Commodity': 'Coal (Bituminous) '}, {'Operator_ID': '4407379', 'Operator_name': 'P B Dirt Movers, Inc.  ', 'Mine_name': 'No. 3', 'State': 'VA ', 'Mine_type': 'No. 3', 'C_M': 'C ', 'Status': 'New Mine ', 'Commodity': ' '}]
# -----------
# [{'Operator_ID': '3503598', 'Operator_name': 'Newberg Rock & Dirt  ', 'Mine_name': 'Newberg Rock & Dirt', 'State': 'OR ', 'Mine_type': 'Newberg Rock & Dirt', 'C_M': 'M ', 'Status': 'Active ', 'Commodity': 'Crushed, Broken Stone NEC '}, {'Operator_ID': '1401575', 'Operator_name': 'Bender Sand & Dirt  ', 'Mine_name': 'BENDER SAND & DIRT', 'State': 'KS ', 'Mine_type': 'BENDER SAND & DIRT', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '5001797', 'Operator_name': 'Dirt Company  ', 'Mine_name': 'Bush Pilot', 'State': 'AK ', 'Mine_type': 'Bush Pilot', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '2103723', 'Operator_name': 'Dirt Doctor Inc  ', 'Mine_name': 'Rock Lake Plant', 'State': 'MN ', 'Mine_type': 'Rock Lake Plant', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '2103914', 'Operator_name': 'Dirt Work Specialists LLC  ', 'Mine_name': 'Astec Plant', 'State': 'MN ', 'Mine_type': 'Astec Plant', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '4104757', 'Operator_name': 'Dirt Works  ', 'Mine_name': 'Portable #1', 'State': 'TX ', 'Mine_type': 'Portable #1', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '0801306', 'Operator_name': 'Holley Dirt Company, Inc  ', 'Mine_name': 'River Road Pit', 'State': 'FL ', 'Mine_type': 'River Road Pit', 'C_M': 'M ', 'Status': 'Active ', 'Commodity': 'Sand, Common '}, {'Operator_ID': '3901432', 'Operator_name': 'Krueger Brothers Gravel & Dirt  ', 'Mine_name': 'PORTABLE SCREENER', 'State': 'SD ', 'Mine_type': 'PORTABLE SCREENER', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '3609624', 'Operator_name': 'M R Dirt  ', 'Mine_name': 'Forbes Pit', 'State': 'PA ', 'Mine_type': 'Forbes Pit', 'C_M': 'M ', 'Status': 'Temporarily Idled ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '3609931', 'Operator_name': 'M.R. Dirt Inc.  ', 'Mine_name': 'Camptown Quarry', 'State': 'PA ', 'Mine_type': 'Camptown Quarry', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Dimension Stone NEC '}, {'Operator_ID': '1519799', 'Operator_name': 'P B Dirt Movers, Inc  ', 'Mine_name': 'Fedscreek Surface', 'State': 'KY ', 'Mine_type': 'Fedscreek Surface', 'C_M': 'C ', 'Status': 'Active ', 'Commodity': 'Coal (Bituminous) '}, {'Operator_ID': '4407379', 'Operator_name': 'P B Dirt Movers, Inc.  ', 'Mine_name': 'No. 3', 'State': 'VA ', 'Mine_type': 'No. 3', 'C_M': 'C ', 'Status': 'New Mine ', 'Commodity': ' '}, {'Operator_ID': '4407296', 'Operator_name': 'PB Dirt Movers  ', 'Mine_name': 'Mine No. 6', 'State': 'VA ', 'Mine_type': 'Mine No. 6', 'C_M': 'C ', 'Status': 'Temporarily Idled ', 'Commodity': 'Coal (Bituminous) '}]
# -----------
# [{'Operator_ID': '3503598', 'Operator_name': 'Newberg Rock & Dirt  ', 'Mine_name': 'Newberg Rock & Dirt', 'State': 'OR ', 'Mine_type': 'Newberg Rock & Dirt', 'C_M': 'M ', 'Status': 'Active ', 'Commodity': 'Crushed, Broken Stone NEC '}, {'Operator_ID': '1401575', 'Operator_name': 'Bender Sand & Dirt  ', 'Mine_name': 'BENDER SAND & DIRT', 'State': 'KS ', 'Mine_type': 'BENDER SAND & DIRT', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '5001797', 'Operator_name': 'Dirt Company  ', 'Mine_name': 'Bush Pilot', 'State': 'AK ', 'Mine_type': 'Bush Pilot', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '2103723', 'Operator_name': 'Dirt Doctor Inc  ', 'Mine_name': 'Rock Lake Plant', 'State': 'MN ', 'Mine_type': 'Rock Lake Plant', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '2103914', 'Operator_name': 'Dirt Work Specialists LLC  ', 'Mine_name': 'Astec Plant', 'State': 'MN ', 'Mine_type': 'Astec Plant', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '4104757', 'Operator_name': 'Dirt Works  ', 'Mine_name': 'Portable #1', 'State': 'TX ', 'Mine_type': 'Portable #1', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '0801306', 'Operator_name': 'Holley Dirt Company, Inc  ', 'Mine_name': 'River Road Pit', 'State': 'FL ', 'Mine_type': 'River Road Pit', 'C_M': 'M ', 'Status': 'Active ', 'Commodity': 'Sand, Common '}, {'Operator_ID': '3901432', 'Operator_name': 'Krueger Brothers Gravel & Dirt  ', 'Mine_name': 'PORTABLE SCREENER', 'State': 'SD ', 'Mine_type': 'PORTABLE SCREENER', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '3609624', 'Operator_name': 'M R Dirt  ', 'Mine_name': 'Forbes Pit', 'State': 'PA ', 'Mine_type': 'Forbes Pit', 'C_M': 'M ', 'Status': 'Temporarily Idled ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '3609931', 'Operator_name': 'M.R. Dirt Inc.  ', 'Mine_name': 'Camptown Quarry', 'State': 'PA ', 'Mine_type': 'Camptown Quarry', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Dimension Stone NEC '}, {'Operator_ID': '1519799', 'Operator_name': 'P B Dirt Movers, Inc  ', 'Mine_name': 'Fedscreek Surface', 'State': 'KY ', 'Mine_type': 'Fedscreek Surface', 'C_M': 'C ', 'Status': 'Active ', 'Commodity': 'Coal (Bituminous) '}, {'Operator_ID': '4407379', 'Operator_name': 'P B Dirt Movers, Inc.  ', 'Mine_name': 'No. 3', 'State': 'VA ', 'Mine_type': 'No. 3', 'C_M': 'C ', 'Status': 'New Mine ', 'Commodity': ' '}, {'Operator_ID': '4407296', 'Operator_name': 'PB Dirt Movers  ', 'Mine_name': 'Mine No. 6', 'State': 'VA ', 'Mine_type': 'Mine No. 6', 'C_M': 'C ', 'Status': 'Temporarily Idled ', 'Commodity': 'Coal (Bituminous) '}, {'Operator_ID': '0203332', 'Operator_name': 'Prescott Dirt, LLC  ', 'Mine_name': 'Sandretto Drive', 'State': 'AZ ', 'Mine_type': 'Sandretto Drive', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}]
# -----------
# [{'Operator_ID': '3503598', 'Operator_name': 'Newberg Rock & Dirt  ', 'Mine_name': 'Newberg Rock & Dirt', 'State': 'OR ', 'Mine_type': 'Newberg Rock & Dirt', 'C_M': 'M ', 'Status': 'Active ', 'Commodity': 'Crushed, Broken Stone NEC '}, {'Operator_ID': '1401575', 'Operator_name': 'Bender Sand & Dirt  ', 'Mine_name': 'BENDER SAND & DIRT', 'State': 'KS ', 'Mine_type': 'BENDER SAND & DIRT', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '5001797', 'Operator_name': 'Dirt Company  ', 'Mine_name': 'Bush Pilot', 'State': 'AK ', 'Mine_type': 'Bush Pilot', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '2103723', 'Operator_name': 'Dirt Doctor Inc  ', 'Mine_name': 'Rock Lake Plant', 'State': 'MN ', 'Mine_type': 'Rock Lake Plant', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '2103914', 'Operator_name': 'Dirt Work Specialists LLC  ', 'Mine_name': 'Astec Plant', 'State': 'MN ', 'Mine_type': 'Astec Plant', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '4104757', 'Operator_name': 'Dirt Works  ', 'Mine_name': 'Portable #1', 'State': 'TX ', 'Mine_type': 'Portable #1', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '0801306', 'Operator_name': 'Holley Dirt Company, Inc  ', 'Mine_name': 'River Road Pit', 'State': 'FL ', 'Mine_type': 'River Road Pit', 'C_M': 'M ', 'Status': 'Active ', 'Commodity': 'Sand, Common '}, {'Operator_ID': '3901432', 'Operator_name': 'Krueger Brothers Gravel & Dirt  ', 'Mine_name': 'PORTABLE SCREENER', 'State': 'SD ', 'Mine_type': 'PORTABLE SCREENER', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '3609624', 'Operator_name': 'M R Dirt  ', 'Mine_name': 'Forbes Pit', 'State': 'PA ', 'Mine_type': 'Forbes Pit', 'C_M': 'M ', 'Status': 'Temporarily Idled ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '3609931', 'Operator_name': 'M.R. Dirt Inc.  ', 'Mine_name': 'Camptown Quarry', 'State': 'PA ', 'Mine_type': 'Camptown Quarry', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Dimension Stone NEC '}, {'Operator_ID': '1519799', 'Operator_name': 'P B Dirt Movers, Inc  ', 'Mine_name': 'Fedscreek Surface', 'State': 'KY ', 'Mine_type': 'Fedscreek Surface', 'C_M': 'C ', 'Status': 'Active ', 'Commodity': 'Coal (Bituminous) '}, {'Operator_ID': '4407379', 'Operator_name': 'P B Dirt Movers, Inc.  ', 'Mine_name': 'No. 3', 'State': 'VA ', 'Mine_type': 'No. 3', 'C_M': 'C ', 'Status': 'New Mine ', 'Commodity': ' '}, {'Operator_ID': '4407296', 'Operator_name': 'PB Dirt Movers  ', 'Mine_name': 'Mine No. 6', 'State': 'VA ', 'Mine_type': 'Mine No. 6', 'C_M': 'C ', 'Status': 'Temporarily Idled ', 'Commodity': 'Coal (Bituminous) '}, {'Operator_ID': '0203332', 'Operator_name': 'Prescott Dirt, LLC  ', 'Mine_name': 'Sandretto Drive', 'State': 'AZ ', 'Mine_type': 'Sandretto Drive', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '2901986', 'Operator_name': 'R D Blankenship Dirt Work LLC  ', 'Mine_name': 'R D BLANKENSHIP DIRT WORK', 'State': 'NM ', 'Mine_type': 'R D BLANKENSHIP DIRT WORK', 'C_M': 'M ', 'Status': 'Active ', 'Commodity': 'Construction Sand and Gravel '}]
# -----------
# [{'Operator_ID': '3503598', 'Operator_name': 'Newberg Rock & Dirt  ', 'Mine_name': 'Newberg Rock & Dirt', 'State': 'OR ', 'Mine_type': 'Newberg Rock & Dirt', 'C_M': 'M ', 'Status': 'Active ', 'Commodity': 'Crushed, Broken Stone NEC '}, {'Operator_ID': '1401575', 'Operator_name': 'Bender Sand & Dirt  ', 'Mine_name': 'BENDER SAND & DIRT', 'State': 'KS ', 'Mine_type': 'BENDER SAND & DIRT', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '5001797', 'Operator_name': 'Dirt Company  ', 'Mine_name': 'Bush Pilot', 'State': 'AK ', 'Mine_type': 'Bush Pilot', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '2103723', 'Operator_name': 'Dirt Doctor Inc  ', 'Mine_name': 'Rock Lake Plant', 'State': 'MN ', 'Mine_type': 'Rock Lake Plant', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '2103914', 'Operator_name': 'Dirt Work Specialists LLC  ', 'Mine_name': 'Astec Plant', 'State': 'MN ', 'Mine_type': 'Astec Plant', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '4104757', 'Operator_name': 'Dirt Works  ', 'Mine_name': 'Portable #1', 'State': 'TX ', 'Mine_type': 'Portable #1', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '0801306', 'Operator_name': 'Holley Dirt Company, Inc  ', 'Mine_name': 'River Road Pit', 'State': 'FL ', 'Mine_type': 'River Road Pit', 'C_M': 'M ', 'Status': 'Active ', 'Commodity': 'Sand, Common '}, {'Operator_ID': '3901432', 'Operator_name': 'Krueger Brothers Gravel & Dirt  ', 'Mine_name': 'PORTABLE SCREENER', 'State': 'SD ', 'Mine_type': 'PORTABLE SCREENER', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '3609624', 'Operator_name': 'M R Dirt  ', 'Mine_name': 'Forbes Pit', 'State': 'PA ', 'Mine_type': 'Forbes Pit', 'C_M': 'M ', 'Status': 'Temporarily Idled ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '3609931', 'Operator_name': 'M.R. Dirt Inc.  ', 'Mine_name': 'Camptown Quarry', 'State': 'PA ', 'Mine_type': 'Camptown Quarry', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Dimension Stone NEC '}, {'Operator_ID': '1519799', 'Operator_name': 'P B Dirt Movers, Inc  ', 'Mine_name': 'Fedscreek Surface', 'State': 'KY ', 'Mine_type': 'Fedscreek Surface', 'C_M': 'C ', 'Status': 'Active ', 'Commodity': 'Coal (Bituminous) '}, {'Operator_ID': '4407379', 'Operator_name': 'P B Dirt Movers, Inc.  ', 'Mine_name': 'No. 3', 'State': 'VA ', 'Mine_type': 'No. 3', 'C_M': 'C ', 'Status': 'New Mine ', 'Commodity': ' '}, {'Operator_ID': '4407296', 'Operator_name': 'PB Dirt Movers  ', 'Mine_name': 'Mine No. 6', 'State': 'VA ', 'Mine_type': 'Mine No. 6', 'C_M': 'C ', 'Status': 'Temporarily Idled ', 'Commodity': 'Coal (Bituminous) '}, {'Operator_ID': '0203332', 'Operator_name': 'Prescott Dirt, LLC  ', 'Mine_name': 'Sandretto Drive', 'State': 'AZ ', 'Mine_type': 'Sandretto Drive', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '2901986', 'Operator_name': 'R D Blankenship Dirt Work LLC  ', 'Mine_name': 'R D BLANKENSHIP DIRT WORK', 'State': 'NM ', 'Mine_type': 'R D BLANKENSHIP DIRT WORK', 'C_M': 'M ', 'Status': 'Active ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '0801417', 'Operator_name': 'Sand & Dirt, Inc  ', 'Mine_name': 'Molino Pit', 'State': 'FL ', 'Mine_type': 'Molino Pit', 'C_M': 'M ', 'Status': 'Active ', 'Commodity': 'Sand, Common '}]
# -----------
# [{'Operator_ID': '3503598', 'Operator_name': 'Newberg Rock & Dirt  ', 'Mine_name': 'Newberg Rock & Dirt', 'State': 'OR ', 'Mine_type': 'Newberg Rock & Dirt', 'C_M': 'M ', 'Status': 'Active ', 'Commodity': 'Crushed, Broken Stone NEC '}, {'Operator_ID': '1401575', 'Operator_name': 'Bender Sand & Dirt  ', 'Mine_name': 'BENDER SAND & DIRT', 'State': 'KS ', 'Mine_type': 'BENDER SAND & DIRT', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '5001797', 'Operator_name': 'Dirt Company  ', 'Mine_name': 'Bush Pilot', 'State': 'AK ', 'Mine_type': 'Bush Pilot', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '2103723', 'Operator_name': 'Dirt Doctor Inc  ', 'Mine_name': 'Rock Lake Plant', 'State': 'MN ', 'Mine_type': 'Rock Lake Plant', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '2103914', 'Operator_name': 'Dirt Work Specialists LLC  ', 'Mine_name': 'Astec Plant', 'State': 'MN ', 'Mine_type': 'Astec Plant', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '4104757', 'Operator_name': 'Dirt Works  ', 'Mine_name': 'Portable #1', 'State': 'TX ', 'Mine_type': 'Portable #1', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '0801306', 'Operator_name': 'Holley Dirt Company, Inc  ', 'Mine_name': 'River Road Pit', 'State': 'FL ', 'Mine_type': 'River Road Pit', 'C_M': 'M ', 'Status': 'Active ', 'Commodity': 'Sand, Common '}, {'Operator_ID': '3901432', 'Operator_name': 'Krueger Brothers Gravel & Dirt  ', 'Mine_name': 'PORTABLE SCREENER', 'State': 'SD ', 'Mine_type': 'PORTABLE SCREENER', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '3609624', 'Operator_name': 'M R Dirt  ', 'Mine_name': 'Forbes Pit', 'State': 'PA ', 'Mine_type': 'Forbes Pit', 'C_M': 'M ', 'Status': 'Temporarily Idled ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '3609931', 'Operator_name': 'M.R. Dirt Inc.  ', 'Mine_name': 'Camptown Quarry', 'State': 'PA ', 'Mine_type': 'Camptown Quarry', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Dimension Stone NEC '}, {'Operator_ID': '1519799', 'Operator_name': 'P B Dirt Movers, Inc  ', 'Mine_name': 'Fedscreek Surface', 'State': 'KY ', 'Mine_type': 'Fedscreek Surface', 'C_M': 'C ', 'Status': 'Active ', 'Commodity': 'Coal (Bituminous) '}, {'Operator_ID': '4407379', 'Operator_name': 'P B Dirt Movers, Inc.  ', 'Mine_name': 'No. 3', 'State': 'VA ', 'Mine_type': 'No. 3', 'C_M': 'C ', 'Status': 'New Mine ', 'Commodity': ' '}, {'Operator_ID': '4407296', 'Operator_name': 'PB Dirt Movers  ', 'Mine_name': 'Mine No. 6', 'State': 'VA ', 'Mine_type': 'Mine No. 6', 'C_M': 'C ', 'Status': 'Temporarily Idled ', 'Commodity': 'Coal (Bituminous) '}, {'Operator_ID': '0203332', 'Operator_name': 'Prescott Dirt, LLC  ', 'Mine_name': 'Sandretto Drive', 'State': 'AZ ', 'Mine_type': 'Sandretto Drive', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '2901986', 'Operator_name': 'R D Blankenship Dirt Work LLC  ', 'Mine_name': 'R D BLANKENSHIP DIRT WORK', 'State': 'NM ', 'Mine_type': 'R D BLANKENSHIP DIRT WORK', 'C_M': 'M ', 'Status': 'Active ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '0801417', 'Operator_name': 'Sand & Dirt, Inc  ', 'Mine_name': 'Molino Pit', 'State': 'FL ', 'Mine_type': 'Molino Pit', 'C_M': 'M ', 'Status': 'Active ', 'Commodity': 'Sand, Common '}, {'Operator_ID': '4300768', 'Operator_name': 'SIMPSON DIRTWORX LLC  ', 'Mine_name': 'Pettibone Jaw Crusher', 'State': 'VT ', 'Mine_type': 'Pettibone Jaw Crusher', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}]
# -----------
# [{'Operator_ID': '3503598', 'Operator_name': 'Newberg Rock & Dirt  ', 'Mine_name': 'Newberg Rock & Dirt', 'State': 'OR ', 'Mine_type': 'Newberg Rock & Dirt', 'C_M': 'M ', 'Status': 'Active ', 'Commodity': 'Crushed, Broken Stone NEC '}, {'Operator_ID': '1401575', 'Operator_name': 'Bender Sand & Dirt  ', 'Mine_name': 'BENDER SAND & DIRT', 'State': 'KS ', 'Mine_type': 'BENDER SAND & DIRT', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '5001797', 'Operator_name': 'Dirt Company  ', 'Mine_name': 'Bush Pilot', 'State': 'AK ', 'Mine_type': 'Bush Pilot', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '2103723', 'Operator_name': 'Dirt Doctor Inc  ', 'Mine_name': 'Rock Lake Plant', 'State': 'MN ', 'Mine_type': 'Rock Lake Plant', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '2103914', 'Operator_name': 'Dirt Work Specialists LLC  ', 'Mine_name': 'Astec Plant', 'State': 'MN ', 'Mine_type': 'Astec Plant', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '4104757', 'Operator_name': 'Dirt Works  ', 'Mine_name': 'Portable #1', 'State': 'TX ', 'Mine_type': 'Portable #1', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '0801306', 'Operator_name': 'Holley Dirt Company, Inc  ', 'Mine_name': 'River Road Pit', 'State': 'FL ', 'Mine_type': 'River Road Pit', 'C_M': 'M ', 'Status': 'Active ', 'Commodity': 'Sand, Common '}, {'Operator_ID': '3901432', 'Operator_name': 'Krueger Brothers Gravel & Dirt  ', 'Mine_name': 'PORTABLE SCREENER', 'State': 'SD ', 'Mine_type': 'PORTABLE SCREENER', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '3609624', 'Operator_name': 'M R Dirt  ', 'Mine_name': 'Forbes Pit', 'State': 'PA ', 'Mine_type': 'Forbes Pit', 'C_M': 'M ', 'Status': 'Temporarily Idled ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '3609931', 'Operator_name': 'M.R. Dirt Inc.  ', 'Mine_name': 'Camptown Quarry', 'State': 'PA ', 'Mine_type': 'Camptown Quarry', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Dimension Stone NEC '}, {'Operator_ID': '1519799', 'Operator_name': 'P B Dirt Movers, Inc  ', 'Mine_name': 'Fedscreek Surface', 'State': 'KY ', 'Mine_type': 'Fedscreek Surface', 'C_M': 'C ', 'Status': 'Active ', 'Commodity': 'Coal (Bituminous) '}, {'Operator_ID': '4407379', 'Operator_name': 'P B Dirt Movers, Inc.  ', 'Mine_name': 'No. 3', 'State': 'VA ', 'Mine_type': 'No. 3', 'C_M': 'C ', 'Status': 'New Mine ', 'Commodity': ' '}, {'Operator_ID': '4407296', 'Operator_name': 'PB Dirt Movers  ', 'Mine_name': 'Mine No. 6', 'State': 'VA ', 'Mine_type': 'Mine No. 6', 'C_M': 'C ', 'Status': 'Temporarily Idled ', 'Commodity': 'Coal (Bituminous) '}, {'Operator_ID': '0203332', 'Operator_name': 'Prescott Dirt, LLC  ', 'Mine_name': 'Sandretto Drive', 'State': 'AZ ', 'Mine_type': 'Sandretto Drive', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '2901986', 'Operator_name': 'R D Blankenship Dirt Work LLC  ', 'Mine_name': 'R D BLANKENSHIP DIRT WORK', 'State': 'NM ', 'Mine_type': 'R D BLANKENSHIP DIRT WORK', 'C_M': 'M ', 'Status': 'Active ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '0801417', 'Operator_name': 'Sand & Dirt, Inc  ', 'Mine_name': 'Molino Pit', 'State': 'FL ', 'Mine_type': 'Molino Pit', 'C_M': 'M ', 'Status': 'Active ', 'Commodity': 'Sand, Common '}, {'Operator_ID': '4300768', 'Operator_name': 'SIMPSON DIRTWORX LLC  ', 'Mine_name': 'Pettibone Jaw Crusher', 'State': 'VT ', 'Mine_type': 'Pettibone Jaw Crusher', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '4300776', 'Operator_name': 'SIMPSON DIRTWORX LLC  ', 'Mine_name': 'Chieftan 1400', 'State': 'VT ', 'Mine_type': 'Chieftan  ...
# -----------
# [{'Operator_ID': '3503598', 'Operator_name': 'Newberg Rock & Dirt  ', 'Mine_name': 'Newberg Rock & Dirt', 'State': 'OR ', 'Mine_type': 'Newberg Rock & Dirt', 'C_M': 'M ', 'Status': 'Active ', 'Commodity': 'Crushed, Broken Stone NEC '}, {'Operator_ID': '1401575', 'Operator_name': 'Bender Sand & Dirt  ', 'Mine_name': 'BENDER SAND & DIRT', 'State': 'KS ', 'Mine_type': 'BENDER SAND & DIRT', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '5001797', 'Operator_name': 'Dirt Company  ', 'Mine_name': 'Bush Pilot', 'State': 'AK ', 'Mine_type': 'Bush Pilot', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '2103723', 'Operator_name': 'Dirt Doctor Inc  ', 'Mine_name': 'Rock Lake Plant', 'State': 'MN ', 'Mine_type': 'Rock Lake Plant', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '2103914', 'Operator_name': 'Dirt Work Specialists LLC  ', 'Mine_name': 'Astec Plant', 'State': 'MN ', 'Mine_type': 'Astec Plant', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '4104757', 'Operator_name': 'Dirt Works  ', 'Mine_name': 'Portable #1', 'State': 'TX ', 'Mine_type': 'Portable #1', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '0801306', 'Operator_name': 'Holley Dirt Company, Inc  ', 'Mine_name': 'River Road Pit', 'State': 'FL ', 'Mine_type': 'River Road Pit', 'C_M': 'M ', 'Status': 'Active ', 'Commodity': 'Sand, Common '}, {'Operator_ID': '3901432', 'Operator_name': 'Krueger Brothers Gravel & Dirt  ', 'Mine_name': 'PORTABLE SCREENER', 'State': 'SD ', 'Mine_type': 'PORTABLE SCREENER', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '3609624', 'Operator_name': 'M R Dirt  ', 'Mine_name': 'Forbes Pit', 'State': 'PA ', 'Mine_type': 'Forbes Pit', 'C_M': 'M ', 'Status': 'Temporarily Idled ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '3609931', 'Operator_name': 'M.R. Dirt Inc.  ', 'Mine_name': 'Camptown Quarry', 'State': 'PA ', 'Mine_type': 'Camptown Quarry', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Dimension Stone NEC '}, {'Operator_ID': '1519799', 'Operator_name': 'P B Dirt Movers, Inc  ', 'Mine_name': 'Fedscreek Surface', 'State': 'KY ', 'Mine_type': 'Fedscreek Surface', 'C_M': 'C ', 'Status': 'Active ', 'Commodity': 'Coal (Bituminous) '}, {'Operator_ID': '4407379', 'Operator_name': 'P B Dirt Movers, Inc.  ', 'Mine_name': 'No. 3', 'State': 'VA ', 'Mine_type': 'No. 3', 'C_M': 'C ', 'Status': 'New Mine ', 'Commodity': ' '}, {'Operator_ID': '4407296', 'Operator_name': 'PB Dirt Movers  ', 'Mine_name': 'Mine No. 6', 'State': 'VA ', 'Mine_type': 'Mine No. 6', 'C_M': 'C ', 'Status': 'Temporarily Idled ', 'Commodity': 'Coal (Bituminous) '}, {'Operator_ID': '0203332', 'Operator_name': 'Prescott Dirt, LLC  ', 'Mine_name': 'Sandretto Drive', 'State': 'AZ ', 'Mine_type': 'Sandretto Drive', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '2901986', 'Operator_name': 'R D Blankenship Dirt Work LLC  ', 'Mine_name': 'R D BLANKENSHIP DIRT WORK', 'State': 'NM ', 'Mine_type': 'R D BLANKENSHIP DIRT WORK', 'C_M': 'M ', 'Status': 'Active ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '0801417', 'Operator_name': 'Sand & Dirt, Inc  ', 'Mine_name': 'Molino Pit', 'State': 'FL ', 'Mine_type': 'Molino Pit', 'C_M': 'M ', 'Status': 'Active ', 'Commodity': 'Sand, Common '}, {'Operator_ID': '4300768', 'Operator_name': 'SIMPSON DIRTWORX LLC  ', 'Mine_name': 'Pettibone Jaw Crusher', 'State': 'VT ', 'Mine_type': 'Pettibone Jaw Crusher', 'C_M': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator_ID': '4300776', 'Operator_name': 'SIMPSON DIRTWORX LLC  ', 'Mine_name': 'Chieftan 1400', 'State': 'VT ', 'Mine_type': 'Chieftan  ...

# %% [markdown]
# ### Save that to a CSV named `dirt-operators.csv`

# %%
df = pd.DataFrame(rows)
df.head(10)
df
# Out:
#    C_M                      Commodity                  Mine_name  \
# 0   M      Crushed, Broken Stone NEC         Newberg Rock & Dirt
# 1   M   Construction Sand and Gravel          BENDER SAND & DIRT
# 2   M   Construction Sand and Gravel                  Bush Pilot
# 3   M   Construction Sand and Gravel             Rock Lake Plant
# 4   M   Construction Sand and Gravel                 Astec Plant
# 5   M   Construction Sand and Gravel                 Portable #1
# 6   M                   Sand, Common              River Road Pit
# 7   M   Construction Sand and Gravel           PORTABLE SCREENER
# 8   M   Construction Sand and Gravel                  Forbes Pit
# 9   M            Dimension Stone NEC             Camptown Quarry
# 10  C              Coal (Bituminous)           Fedscreek Surface
# 11  C                                                      No. 3
# 12  C              Coal (Bituminous)                  Mine No. 6
# 13  M   Construction Sand and Gravel             Sandretto Drive
# 14  M   Construction Sand and Gravel   R D BLANKENSHIP DIRT WORK
# 15  M                   Sand, Common                  Molino Pit
# 16  M   Construction Sand and Gravel       Pettibone Jaw Crusher
# 17  M   Construction Sand and Gravel               Chieftan 1400
# 18  M   Construction Sand and Gravel            Mike's Money Pit
# 19  M   Construction Sand and Gravel                     Crusher
#
#                     Mine_type Operator_ID                     Operator_name  \
# 0         Newberg Rock & Dirt     3503598             Newberg Rock & Dirt
# 1          BENDER SAND & DIRT     1401575              Bender Sand & Dirt
# 2                  Bush Pilot     5001797                    Dirt Company
# 3             Rock Lake Plant     2103723                 Dirt Doctor Inc
# 4                 Astec Plant     2103914       Dirt Work Specialists LLC
# 5                 Portable #1     4104757                      Dirt Works
# 6              River Road Pit     0801306        Holley Dirt Company, Inc
# 7           PORTABLE SCREENER     3901432  Krueger Brothers Gravel & Dirt
# 8                  Forbes Pit     3609624                        M R Dirt
# 9             Camptown Quarry     3609931                  M.R. Dirt Inc.
# 10          Fedscreek Surface     1519799            P B Dirt Movers, Inc
# 11                      No. 3     4407379           P B Dirt Movers, Inc.
# 12                 Mine No. 6     4407296                  PB Dirt Movers
# 13            Sandretto Drive     0203332              Prescott Dirt, LLC
# 14  R D BLANKENSHIP DIRT WORK     2901986   R D Blankenship Dirt Work LLC
# 15                 Molino Pit     0801417                Sand & Dirt, Inc
# 16      Pettibone Jaw Crusher     4300768            SIMPSON DIRTWORX LLC
# 17              Chieftan 1400     4300776            SIMPSON DIRTWORX LLC
# 18           Mike's Money Pit     2302283      Spry's Dirt & Gravel, Inc.
# 19                    Crusher     2103518               Vogt Dirt Service
#
#    State              Status
# 0    OR              Active
# 1    KS        Intermittent
# 2    AK        Intermittent
# 3    MN        Intermittent
# 4    MN        Intermittent
# 5    TX        Intermittent
# 6    FL              Active
# 7    SD        Intermittent
# 8    PA   Temporarily Idled
# 9    PA        Intermittent
# 10   KY              Active
# 11   VA            New Mine
# 12   VA   Temporarily Idled
# 13   AZ        Intermittent
# 14   NM              Active
# 15   FL              Active
# 16   VT        Intermittent
# 17   VT        Intermittent
# 18   MO        Intermittent
# 19   MN        Intermittent

# %%
df.to_csv("mines.csv", index=False)

# %% [markdown]
# ### Open the CSV file and examine the first few.
#
# Make sure you didn't save that extra weird unnamed index column.

# %%
pd.read_csv('mines.csv')
df = pd.read_csv('mines.csv')
df.head(3)
# Out:
#   C_M                      Commodity            Mine_name  \
# 0  M      Crushed, Broken Stone NEC   Newberg Rock & Dirt
# 1  M   Construction Sand and Gravel    BENDER SAND & DIRT
# 2  M   Construction Sand and Gravel            Bush Pilot
#
#              Mine_type  Operator_ID          Operator_name State  \
# 0  Newberg Rock & Dirt      3503598  Newberg Rock & Dirt     OR
# 1   BENDER SAND & DIRT      1401575   Bender Sand & Dirt     KS
# 2           Bush Pilot      5001797         Dirt Company     AK
#
#           Status
# 0        Active
# 1  Intermittent
# 2  Intermittent
