# %% [markdown]
# # Scraping Maryland Business Licenses with Selenium
#
# Maryland has a [great portal](https://jportal.mdcourts.gov/license/pbPublicSearch.jsp) for searching business licenses, but the only problem is you have to check a box in order to get in.
#
# 1. Try to visit [the public search page](https://jportal.mdcourts.gov/license/pbPublicSearch.jsp)
# 2. Get redirected to a "I agree to this" page. Click that you've read the disclaimer, click Enter the Site.
# 3. Click "Search License Records" down at the bottom of the page
# 4. You're now on the search page! From the "Jurisdiction" dropdown, select "Statewide"
# 5. In the "Trade Name" field, type "Vap%" to try to find vape shops
# 6. Click "Next" in the bottom right-hand corner to go to the next page
# 7. Click "Click for detail" to see the details for a specific business license.
#
# That's a lot of stuff! **Let's get to work.**

# %% [markdown]
# ## Import what you need

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait

import pandas as pd
import time

# %% [markdown]
# ## Preparation
#
# ### When you search for a business license, what URL should Selenium try to visit first?

# %%
driver = webdriver.Chrome()

driver.get("https://jportal.mdcourts.gov/license/pbPublicSearch.jsp?slcJurisdiction=50&txtTradeName=Vap%25&txtOwnerName=&txtLocationStreetName=&slcYear=2018&slcSortBy=ownername")

# %% [markdown]
# **It isn't going to work, though! It's going to redirect to that intro page.** You can use *Incognito mode* to go back through the "Check the box, etc" series of pages, or you can close and re-open Chrome.
#
# - Check the checkbox, then submit the form to accept their terms of service
#
# Selenium can submit forms by either
#
# - Selecting the form and using `.submit()`, or
# - Selecting the button and using `.click()`
#
# You only need to be able to get **one, not both.**
#
# - *TIP: if something doesn't have anything special about it, xpath might be your best bet*

# %%
check_box = driver.find_element_by_xpath('//*[@id="checkbox"]')
check_box.click()

# %%
enter = driver.find_element_by_xpath('/html/body/table/tbody/tr[7]/td/form/div/input[2]')
enter.click()

# %% [markdown]
# Now click the **Search License Records** link up top in the navigation to get to the search page.
#
# - *TIP: Honestly you could also just visit the URL directly now since you filled out that terms of service thing*

# %%
search_license_rec = driver.find_element_by_xpath('/html/body/table[2]/tbody/tr[6]/td[2]/a[2]')
search_license_rec.click()

# %% [markdown]
# ### Perform your search
#
# Pick "Statewide" for the jurisdiction dropdown, and `VAP%` into the Trade Name field. The `%` is a wildcard.

# %%
dropdown= Select(driver.find_element_by_xpath('//*[@id="slcJurisdiction"]'))
dropdown.select_by_visible_text('Statewide')

# %%
driver.find_element_by_xpath('//*[@id="txtTradeName"]').click()

# %%
text_input = driver.find_element_by_xpath('//*[@id="txtTradeName"]')

# %%
text_input.send_keys('VAP%')

# %% [markdown]
# And now, of course, **submit the form**.
#
# - *TIP: Since scrolling to buttons can be a pain, sometimes it's easier to select the form and use `.submit()` instead of `.click()`ing the button*

# %%
submit_button = driver.find_element_by_xpath('/html/body/table[2]/tbody/tr[4]/td[2]/form/table/tbody/tr[14]/td/input[1]')
submit_button.click()

# %% [markdown]
# ## (Try to) scrape the results
#
# Let's start by just **printing this stuff**. We'll save it as a dataframe later on.
#
# For now, just scrape **each store's name**, then cry a little. Fact: this is an impossible and miserable page.

# %%
#/html/body/table[2]/tbody/tr[4]/td[2]/table[1]/tbody/tr[3]/td[2]

# %%
#store_name = driver.find_element_by_class_name('searchlistitem')
#print(store_name)
store_names = driver.find_elements_by_class_name('searchlistitem')

for name in store_names:
    print(name.text)
# Out:
# VAPE IT STORE II
# VAPE IT STORE I
# VAPEPAD THE
# VAPE FROG
# VAPE FROG

# %% [markdown]
# To avoid struggling with the search results page, we're going to use the **detail page** instead. Try to figure out how to select it and click it inside of your `for` loop.
#
# - *TIP: Instead of just looking for an `a` or an `img`, you might want to look for one of its parents first, then click. This might affect the way you print out the shop's name, too*
# - *TIP: Not all of them have links! You can wrap in try/except to skip it, or you can check to see if the shop's status is Pending.*

# %%
detail_button = driver.find_element_by_xpath('/html/body/table[2]/tbody/tr[4]/td[2]/table[1]/tbody/tr[3]/td[3]/a')
detail_button.click()

# %% [markdown]
# Okay, now let's get to action. For each result, **click the link to the detail page** and print out the following information:
#
# - Mailing address
# - Location address
# - License information (you can keep it as one field)
# - Total amount paid
# - Issued by
# - If you're feeling crazy, get the licenses, too.
#
# If it doesn't have a detail page, just print out the name and that's all we need.
#
# - *TIP: When you're done getting the information, you probably want to click back to the search results*
# - *TIP: You might enjoy `find_element_by_partial_link_text` to do that*
# - *TIP: Licenses can be acquired by doing some really odd list slicing - think about where it starts and where it ends, relative to the beginning and end of everything.*
#
# > **IMPORTANT NOTE:** This is doomed. It's useful to do, but your current process is doomed. Once you get a `stale element reference` error move on to the next cell.

# %%
#/html/body/table[2]/tbody/tr[4]/td[2]/table[1]/tbody/tr[3]/td[3]/a
#/html/body/table[2]/tbody/tr[4]/td[2]/table[1]/tbody/tr[8]/td[3]/a

#pages = driver.find_element_by_xpath('/html/body/table[2]/tbody/tr[4]/td[2]/table[1]')
#print(pages.text)

#for page in pages:
store_links = driver.find_elements_by_class_name('searchfieldtitle')

for link in store_links:
    detail_button = link.find_element_by_tag_name('a')
    detail_button.click()
    
    info = driver.find_elements_by_class_name('tablecelltext')
    mail_address = info[0].find_elements_by_tag_name('td')[0]
    location_address = info[1].find_elements_by_tag_name('td')[0]
    total_paid = info[7].find_elements_by_tag_name('td')[1]
    issued_by = info[8].find_elements_by_tag_name('td')[0]
    license_one = info[2].find_elements_by_tag_name('td')[2]
    license_two = info[3].find_elements_by_tag_name('td')[2]
    license_third = info[4].find_elements_by_tag_name('td')[2]
    
    print(mail_address.text)
    print(location_address.text)
    print(total_paid.text)
    print(issued_by.text)
    print(license_one.text)
    print(license_two.text)
    print(license_third.text)
    
    click_back = driver.find_element_by_xpath('/html/body/table[2]/tbody/tr[4]/td[2]/table[4]/tbody/tr/td[1]')
    click_back.click()
    
  

   #If youre feeling crazy, get the licenses, too.

#detail_button=driver.find_element_by_xpath('/html/body/table[2]/tbody/tr[4]/td[2]/table[1]/tbody/tr[3]/td[3]/a')
#detail_button = driver.find_element_by_partial_link_text('click for detail')
#detail_button.click() 
    
   
    
  #  print(mail.text)
    
    #Mailing address
#Location address
#License information (you can keep it as one field)
#Total amount paid
#Issued by
#detail_buttons.click()
# Out:
# AMIN NARGIS
# 1104 PLANTERS PLACE
# SALISBURY, MD 21804
# VAPE IT STORE II
# 1015 S SALISBURY BLVD
# SALISBURY, MD 21801
# $ 41.00
# WICOMICO COUNTY, CLERK OF CIRCUIT COURT
# P.O. BOX 198
# SALISBURY, MARYLAND 21803-0198
# OTHER TOBACCO PROD RETLR
# CHAIN STORE
# TRADER'S LICENSE
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# <ipython-input-18-a87bbec567de> in <module>()
#       9
#      10 for link in store_links:
# ---> 11     detail_button = link.find_element_by_tag_name('a')
#      12     detail_button.click()
#      13
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\selenium\webdriver\remote\webelement.py in find_element_by_tag_name(self, name)
#     303             element = element.find_element_by_tag_name('h1')
#     304         """
# --> 305         return self.find_element(by=By.TAG_NAME, value=name)
#     306
#     307     def find_elements_by_tag_name(self, name):
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\selenium\webdriver\remote\webelement.py in find_element(self, by, value)
#     651
#     652         return self._execute(Command.FIND_CHILD_ELEMENT,
# --> 653                              {"using": by, "value": value})['value']
#     654
#     655     def find_elements(self, by=By.ID, value=None):
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     626             params = {}
#     627         params['id'] = self._id
# --> 628         return self._parent.execute(command, params)
#     629
#     630     def find_element(self, by=By.ID, value=None):
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     312         response = self.command_executor.execute(driver_command, params)
#     313         if response:
# --> 314             self.error_handler.check_response(response)
#     315             response['value'] = self._unwrap_value(
#     316                 response.get('value', None))
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# StaleElementReferenceException: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=67.0.3396.87)
#   (Driver info: chromedriver=2.40.565498 (ea082db3280dd6843ebfb08a625e3eb905c4f5ab),platform=Windows NT 10.0.17134 x86_64)

# %% [markdown]
# ### Stale message reference
#
# Once you navigate away from a page, and you go back to it, you can't use the variables from the first time you were on the page. So, we got a list of results when we first visited, clicked to the details page, clicked back, and now our original list is "stale."
#
# This is sad.
#
# Let's try this again: loop through the results and create a dataframe with `name` and `url` columns. And yes, some of them won't have URLs.

# %%
#store_names = driver.find_elements_by_class_name('searchlistitem')
stores = []

store_urls = driver.find_elements_by_class_name('searchfieldtitle')

for info in store_urls:
    name = info.find_element_by_class_name('searchlistitem')
    
    print(name.text)
    try:
        url = info.find_element_by_tag_name('a')
        print(url.get_attribute('href'))
    
    except: 
        print("There is not a url.")
# Out:
# VAPE IT STORE II
# https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=bmDExzf4ZDw%3D
# VAPE IT STORE I
# https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=glqAu7o7gJE%3D
# VAPEPAD THE
# https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=zjsVR%2F6x1p8%3D
# VAPE FROG
# There is not a url.
# VAPE FROG
# There is not a url.

# %%
#store_names = driver.find_elements_by_class_name('searchlistitem')
stores = []

store_urls = driver.find_elements_by_class_name('searchfieldtitle')

for info in store_urls:
        
    print('-----------')
    
    dictio = {}
    
    name = info.find_element_by_class_name('searchlistitem')
    dictio['name'] = name.text
    
    #print(name.text)
    
    try:
        url = info.find_element_by_tag_name('a').get_attribute('href')
        #print(url.get_attribute('href'))
        dictio['url'] = url
    
    except: 
        dictio['url'] = "There is not a url."
    
    print(dictio)
    stores.append(dictio)
# Out:
# -----------
# {'name': 'VAPE IT STORE II', 'url': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=bmDExzf4ZDw%3D'}
# -----------
# {'name': 'VAPE IT STORE I', 'url': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=glqAu7o7gJE%3D'}
# -----------
# {'name': 'VAPEPAD THE', 'url': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=zjsVR%2F6x1p8%3D'}
# -----------
# {'name': 'VAPE FROG', 'url': 'There is not a url.'}
# -----------
# {'name': 'VAPE FROG', 'url': 'There is not a url.'}

# %%
stores_df = pd.DataFrame(stores)
stores_df
# Out:
#                name                                                url
# 0  VAPE IT STORE II  https://jportal.mdcourts.gov/license/pbLicense...
# 1   VAPE IT STORE I  https://jportal.mdcourts.gov/license/pbLicense...
# 2       VAPEPAD THE  https://jportal.mdcourts.gov/license/pbLicense...
# 3         VAPE FROG                                There is not a url.
# 4         VAPE FROG                                There is not a url.

# %% [markdown]
# ### Getting all of the results
#
# After you've looped through the results on one page, we're going to want to go to the next page! Add a line to make it click the 'Next' button down at the bottom
#
# - *Tip: `find_element_by_partial_link_text` will be your friend*
# - *Tip: You might need to do the scrolling thing to get it onto the screen (and by that I mean, you WILL need to, so you should)*
#
# Confirm that it moves to the next page (it doesn't need to scrape anything yet)

# %%
#store_urls = driver.find_elements_by_class_name('searchfieldtitle')
#store_urls[0].text

# %%
stores = []

store_urls = driver.find_elements_by_class_name('searchfieldtitle')

for info in store_urls:
        
    #print('-----------')
    
    dictio = {}
    
    name = info.find_element_by_class_name('searchlistitem')
    dictio['name'] = name.text
    
    #print(name.text)
    
    try:
        url = info.find_element_by_tag_name('a').get_attribute('href')
        #print(url.get_attribute('href'))
        dictio['url'] = url
    
    except: 
        dictio['url'] = "There is not a url."
    
    #print(dictio)
    stores.append(dictio)
    
next_button = driver.find_element_by_partial_link_text('Next')
#print(next_button)
next_button.click()

print('Yes, I moved to the next page!')
# Out:
# Yes, I moved to the next page!

# %% [markdown]
# ### Wrapping with `while`
#
# > Go back to the first page of results before you try to run this
#
# You have a bunch of scraping code. It clicks the next button, then it stops. But you'd like it to go back up to the top! You can make that happen with a special `while` loop.
#
# ```python
# while True:
#     # Scrape your stuff
#     # Click next button
# ```
#
# This will go on FOREVER AND EVER until there is an error (when it can't find the Next button on the last page of results, you'll get an error).
#
# - *Tip: Print out "Scraping a new page" every time you visit a new page, just to check that it's working*

# %%
stores = []

while True:

    store_urls = driver.find_elements_by_class_name('searchfieldtitle')


    for info in store_urls:

        #print('-----------')

        dictio = {}

        name = info.find_element_by_class_name('searchlistitem')
        dictio['name'] = name.text

        #print(name.text)

        try:
            url = info.find_element_by_tag_name('a').get_attribute('href')
            #print(url.get_attribute('href'))
            dictio['url'] = url

        except: 
            dictio['url'] = "There is not a url."

    print('-------Scraping a new page--------')
    stores.append(dictio)

    next_button = driver.find_element_by_partial_link_text('Next')
    #print(next_button)
    next_button.click()
    
#print('There is no other page.')
# Out:
# -------Scraping a new page--------
# -------Scraping a new page--------
# -------Scraping a new page--------
# -------Scraping a new page--------
# -------Scraping a new page--------
# -------Scraping a new page--------
# -------Scraping a new page--------
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-24-e649c7f05d82> in <module>()
#      28     stores.append(dictio)
#      29
# ---> 30     next_button = driver.find_element_by_partial_link_text('Next')
#      31     #print(next_button)
#      32     next_button.click()
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_partial_link_text(self, link_text)
#     453             element = driver.find_element_by_partial_link_text('Sign')
#     454         """
# --> 455         return self.find_element(by=By.PARTIAL_LINK_TEXT, value=link_text)
#     456
#     457     def find_elements_by_partial_link_text(self, link_text):
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     955         return self.execute(Command.FIND_ELEMENT, {
#     956             'using': by,
# --> 957             'value': value})['value']
#     958
#     959     def find_elements(self, by=By.ID, value=None):
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     312         response = self.command_executor.execute(driver_command, params)
#     313         if response:
# --> 314             self.error_handler.check_response(response)
#     315             response['value'] = self._unwrap_value(
#     316                 response.get('value', None))
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"partial link text","selector":"Next"}
#   (Session info: chrome=67.0.3396.87)
#   (Driver info: chromedriver=2.40.565498 (ea082db3280dd6843ebfb08a625e3eb905c4f5ab),platform=Windows NT 10.0.17134 x86_64)

# %% [markdown]
# ### Making it perfect
#
# > Go back to the first page of results before you try to run this
#
# Wrap all of your code in a `try`/`except` so that it doesn't finish with an error and you'll be good to go.
#
# **Confirm your list has all of the vape shops in it.** If not, check where you are creating your empty list (`[]`) - if you do it in the wrong spot, it will overwrite your list every time you visit a page.

# %%
stores = []

try:
    
    while True:

        store_urls = driver.find_elements_by_class_name('searchfieldtitle')


        for info in store_urls:

            #print('-----------')

            dictio = {}

            name = info.find_element_by_class_name('searchlistitem')
            dictio['name'] = name.text

            #print(name.text)

            try:
                url = info.find_element_by_tag_name('a').get_attribute('href')
                #print(url.get_attribute('href'))
                dictio['url'] = url

            except: 
                dictio['url'] = "There is not a url."

            #print(dictio)
            print('-------Scraping data--------')
            stores.append(dictio)
        #print(stores)
            

        next_button = driver.find_element_by_partial_link_text('Next')
        #print(next_button)
        next_button.click()
        
except:
    print("There is no other page.")
# Out:
# -------Scraping data--------
# -------Scraping data--------
# -------Scraping data--------
# -------Scraping data--------
# -------Scraping data--------
# -------Scraping data--------
# -------Scraping data--------
# -------Scraping data--------
# -------Scraping data--------
# -------Scraping data--------
# -------Scraping data--------
# -------Scraping data--------
# -------Scraping data--------
# -------Scraping data--------
# -------Scraping data--------
# -------Scraping data--------
# -------Scraping data--------
# -------Scraping data--------
# -------Scraping data--------
# -------Scraping data--------
# -------Scraping data--------
# -------Scraping data--------
# -------Scraping data--------
# -------Scraping data--------
# -------Scraping data--------
# -------Scraping data--------
# -------Scraping data--------
# -------Scraping data--------
# -------Scraping data--------
# -------Scraping data--------
# -------Scraping data--------
# -------Scraping data--------
# -------Scraping data--------
# -------Scraping data--------
# There is no other page.

# %%
len(stores)
# Out:
# 34

# %% [markdown]
# ### Save this data as a csv
#
# The filename should be `vape-shops-basic.csv`.

# %%
stores_df = pd.DataFrame(stores)
stores_df
# Out:
#                  name                                                url
# 0    VAPE IT STORE II  https://jportal.mdcourts.gov/license/pbLicense...
# 1     VAPE IT STORE I  https://jportal.mdcourts.gov/license/pbLicense...
# 2         VAPEPAD THE  https://jportal.mdcourts.gov/license/pbLicense...
# 3           VAPE FROG                                There is not a url.
# 4           VAPE FROG                                There is not a url.
# 5       VAPE LOFT THE  https://jportal.mdcourts.gov/license/pbLicense...
# 6        VAPE N CIGAR  https://jportal.mdcourts.gov/license/pbLicense...
# 7           VAPE DOJO  https://jportal.mdcourts.gov/license/pbLicense...
# 8          VAPE HAVEN                                There is not a url.
# 9       VAPORS LOUNGE                                There is not a url.
# 10  VAPORFI SOUTHSIDE  https://jportal.mdcourts.gov/license/pbLicense...
# 11         VAPE DO JO  https://jportal.mdcourts.gov/license/pbLicense...
# 12         VAPERTETMD                                There is not a url.
# 13         VAPERTEKMD  https://jportal.mdcourts.gov/license/pbLicense...
# 14           VAPORIOT                                There is not a url.
# 15          VAPE PLUS  https://jportal.mdcourts.gov/license/pbLicense...
# 16        VAPE SOCIAL  https://jportal.mdcourts.gov/license/pbLicense...
# 17        VAPE JUNGLE  https://jportal.mdcourts.gov/license/pbLicense...
# 18          VAPE TIME                                There is not a url.
# 19     VAPEBAR EXPESS                                There is not a url.
# 20          VAPEWERKS  https://jportal.mdcourts.gov/license/pbLicense...
# 21          VAPIST MD  https://jportal.mdcourts.gov/license/pbLicense...
# 22           VAPOR 99                                There is not a url.
# 23        VAPOR ALLEY  https://jportal.mdcourts.gov/license/pbLicense...
# 24     VAPOR EMPORIUM  https://jportal.mdcourts.gov/license/pbLicense...
# 25        VAPOR VILLA  https://jportal.mdcourts.gov/license/pbLicense...
# 26        VAPOR VILLA  https://jportal.mdcourts.gov/license/pbLicense...
# 27      VAPORS LOUNGE  https://jportal.mdcourts.gov/license/pbLicense...
# 28          VAPE DOJO  https://jportal.mdcourts.gov/license/pbLicense...
# 29          VAPE DOJO  https://jportal.mdcourts.gov/license/pbLicense...
# 30          VAPE DOJO  https://jportal.mdcourts.gov/license/pbLicense...
# 31          VAPE DOJO  https://jportal.mdcourts.gov/license/pbLicense...
# 32    VAPEZ YARDHOUSE                                There is not a url.
# 33        VAPERS RING  https://jportal.mdcourts.gov/license/pbLicense...

# %%
stores_df.to_csv("vape-shops.csv", index=False)
stores_df = pd.read_csv('vape-shops.csv')
stores_df.head()
# Out:
#                name  \
# 0  VAPE IT STORE II
# 1  VAPE IT STORE I
# 2  VAPEPAD THE
# 3  VAPE FROG
# 4  VAPE FROG
#
#                                                                              url
# 0  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=bmDExzf4ZDw%3D
# 1  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=glqAu7o7gJE%3D
# 2  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=zjsVR%2F6x1p8%3D
# 3  There is not a url.
# 4  There is not a url.

# %% [markdown]
# # Okay, let's scrape!
#
# All right, get the actual data!
#
# ### Look at the URL of your first row
#
# - *TIP: Remember `pd.set_option('display.max_colwidth', -1)` will let you see alllll of your strings*

# %%
pd.set_option('display.max_colwidth', -1)

# %%
stores_df['url'].head(1)
# Out:
# 0    https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=bmDExzf4ZDw%3D
# Name: url, dtype: object

# %%
#stores_df['url'].tail(1)

# %% [markdown]
# ### Use Selenium to visit that page

# %%
#driver.get('https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=74s9PXdmgq0%3D')

# %%
#driver.get('https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=plY4eVvXtD8%3D')

# %%
driver.get(stores_df.url[0])

# %% [markdown]
# ### Now, just like you did before, grab the additional data
#
# You should probably save it into a dictionary! Don't try to put it into the dataframe yet, though. You want:
#
# - Mailing address
# - Location address
# - License information (you can keep it as one field)
# - Total amount paid
# - Issued by
# - If you're feeling crazy, get the licenses, too.
#
# .
#
# - *TIP: Licenses can be acquired by doing some really odd list slicing - think about where it starts and where it ends, relative to the beginning and end of everything.*
# - *TIP: If you've gotten addicted to xpath, total amount paid and issued by might not work with it when doing other shops. You'll want to test it!*

# %%
#store_links = driver.find_elements_by_class_name('searchfieldtitle')
info = driver.find_elements_by_class_name('tablecelltext')

mail = info[0].find_elements_by_tag_name('td')[0]
location = info[1].find_elements_by_tag_name('td')[0]
total = info[7].find_elements_by_tag_name('td')[1]
issued = info[8].find_elements_by_tag_name('td')[0]
license = info[2].find_elements_by_tag_name('td')[2]
license_second = info[3].find_elements_by_tag_name('td')[2]
license_more = info[4].find_elements_by_tag_name('td')[2]

print(mail.text)
print(location.text)
print(total.text)
print(issued.text)
print(license.text)
print(license_second.text)
print(license_more.text)
# Out:
# AMIN NARGIS
# 1104 PLANTERS PLACE
# SALISBURY, MD 21804
# VAPE IT STORE II
# 1015 S SALISBURY BLVD
# SALISBURY, MD 21801
# $ 41.00
# WICOMICO COUNTY, CLERK OF CIRCUIT COURT
# P.O. BOX 198
# SALISBURY, MARYLAND 21803-0198
# OTHER TOBACCO PROD RETLR
# CHAIN STORE
# TRADER'S LICENSE

# %% [markdown]
# ### Move all of this into one cell
#
# It should visit the URL, then grab the data and put it into a dictionary.

# %%
#driver.get('https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=plY4eVvXtD8%3D')

info = driver.find_elements_by_class_name('tablecelltext')

print('-----------')
    
dictio = {}

mail = info[0].find_elements_by_tag_name('td')[0]
dictio['mail'] = mail.text

location = info[1].find_elements_by_tag_name('td')[0]
dictio['location'] = location.text 

total = info[7].find_elements_by_tag_name('td')[1]
dictio['total'] = total.text 

issued = info[8].find_elements_by_tag_name('td')[0]
dictio['issued'] = issued.text 

license = info[2].find_elements_by_tag_name('td')[2]
dictio['license'] = license.text 

license_second = info[3].find_elements_by_tag_name('td')[2]
dictio['license_second'] = license_second.text 

license_more = info[4].find_elements_by_tag_name('td')[2]
dictio['license_more'] = license_more.text 

#mail = info[0].find_elements_by_tag_name('td')[0]
#location = info[1].find_elements_by_tag_name('td')[0]
#total = info[7].find_elements_by_tag_name('td')[1]
#issued = info[8].find_elements_by_tag_name('td')[0]
#license = info[2].find_elements_by_tag_name('td')[2]
#license_second = info[3].find_elements_by_tag_name('td')[2]
#license_more = info[4].find_elements_by_tag_name('td')[2]

print(dictio)
# Out:
# -----------
# {'mail': 'YEAGER ONE INC\n545 HIGGINS DR\nODENTON, MD 21113', 'location': 'VAPERS RING\n545 BENFIELD RD\nSEVERNA PARK, MD 21146', 'total': '$ 116.00', 'issued': 'ROBERT P. DUCKWORTH, CLERK OF CIRCUIT COURT\n8 CHURCH CIRCLE, ROOM H-101\nANNAPOLIS, MARYLAND 21401', 'license': "TRADER'S LICENSE", 'license_second': 'CHAIN STORE', 'license_more': 'VAPE SHOP VENDOR'}

# %% [markdown]
# ### Change it into a function
#
# You'll want to have this function accept a `row`, and send back a `pd.Series`. You can just use `pd.Series(your_dictionary)` (but it better have a better name than `your_dictionary`!).
#
# - *TIP: Make sure you `return` something!*
# - *TIP: Make sure you change everything to reflect the row's url, not the URL you typed in*

# %%
def get_vapestores(row): 
    try:
        driver.get(row['url'])
        
        #info = driver.find_elements_by_class_name('tablecelltext')

        mail = info[0].find_elements_by_tag_name('td')[0].text
        location = info[1].find_elements_by_tag_name('td')[0].text
        total = info[7].find_elements_by_tag_name('td')[1].text
        issued = info[8].find_elements_by_tag_name('td')[0].text
        license = info[2].find_elements_by_tag_name('td')[2].text
        #license_second = info[3].find_elements_by_tag_name('td')[2].text
        #license_more = info[4].find_elements_by_tag_name('td')[2].text

        return pd.Series({
                'mail': mail,
                'location': location,
                'total': total,
                'issued': issued,
                'license': license,
                #'license_second': license_second,
                #'license_more': license_more     
            })
        
    except:
        print('There is no url.')

# %%
#final_test_df = stores_df.apply(get_vapestores, axis=1).join(stores_df)
#final_test_df
##############################################################################################################

#USING def get_vapestores(row) & tag_names, results seem to be messed up. 
#That is why I am going with xpaths into a new function, including only license_status and one type of license 
#(the first one each time). Please see the following cells for my solution.

# %%
def get_vapeshops(row): 
    try:
        driver.get(row['url'])
        
        #info = driver.find_elements_by_class_name('tablecelltext')

        mail_address = driver.find_element_by_xpath('/html/body/table[2]/tbody/tr[4]/td[2]/table[1]/tbody/tr[3]/td[1]').text
        location_address = driver.find_element_by_xpath('/html/body/table[2]/tbody/tr[4]/td[2]/table[1]/tbody/tr[5]/td').text
        total_cost = driver.find_element_by_xpath('/html/body/table[2]/tbody/tr[4]/td[2]/table[2]/tbody/tr[7]/td[2]').text
        issued_info = driver.find_element_by_xpath('/html/body/table[2]/tbody/tr[4]/td[2]/table[3]/tbody/tr[2]').text
        license_status = driver.find_element_by_xpath('/html/body/table[2]/tbody/tr[4]/td[2]/table[1]/tbody/tr[3]/td[2]').text
        license_a = driver.find_element_by_xpath('/html/body/table[2]/tbody/tr[4]/td[2]/table[2]/tbody/tr[2]/td[3]/a').text          
        #license_second = info[3].find_elements_by_tag_name('td')[2].text
        #license_more = info[4].find_elements_by_tag_name('td')[2].text

        return pd.Series({
                'mail_address': mail_address,
                'location_address': location_address,
                'total_cost': total_cost,
                'issued_info': issued_info,
                'license_status': license_status,
                'license_a': license_a
                #'license_second': license_second,
                #'license_more': license_more     
            })
        
    except:
        print('There is no url.')

# %%
#vape_df = stores_df.apply(get_vapeshops, axis=1).join(stores_df)
#vape_df

# %% [markdown]
# ### Use your dataframe and `.apply` to pull all of the data from the vape shops
#
# Once you know it's working, use the whole
#
# - *TIP: Try using it with `.head(3)` first*
# - *TIP: You'll want to use `.apply` with your new function*
# - *TIP: Issued By and Total Paid are goign to give you problems if you tried to use xpath! Try checking the classes and think about find_elementSSSSS and working backwards instead of forwards.*
# - *TIP: You might need a `try`/`except`*
# - *TIP: Make sure you're using `axis=1`*
# - *TIP: Use `.join` the big thing with all of the `dfs` - make sure you name them right!*

# %%
stores_df.head()
#stores_df
# Out:
#                name  \
# 0  VAPE IT STORE II
# 1  VAPE IT STORE I
# 2  VAPEPAD THE
# 3  VAPE FROG
# 4  VAPE FROG
#
#                                                                              url
# 0  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=bmDExzf4ZDw%3D
# 1  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=glqAu7o7gJE%3D
# 2  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=zjsVR%2F6x1p8%3D
# 3  There is not a url.
# 4  There is not a url.

# %%
vape_df = stores_df.apply(get_vapeshops, axis=1).join(stores_df)
vape_df
# Out:
# There is no url.
# There is no url.
# There is no url.
# There is no url.
# There is no url.
# There is no url.
# There is no url.
# There is no url.
# There is no url.
# There is no url.
# There is no url.
# There is no url.
#                                                                             mail_address  \
# 0   AMIN NARGIS\n1104 PLANTERS PLACE\nSALISBURY, MD 21804
# 1   AMIN NARGIS\n1104 PLANTERS PLACE\nSALISBURY, MD 21804
# 2   ANJ DISTRIBUTIONS LLC\n2504 ORCHARD KNOLL WAY\nODENTON, MD 21113
# 3   None
# 4   None
# 5   DISBROW II EMERSON HARRINGTON
# 6   DISCOUNT TOBACCO ESSEX LLC
# 7   FAIRGROUND VILLAGE LLC
# 8   None
# 9   None
# 10  JENS VAPOR LLC
# 11  MONROE LLC
# 12  None
# 13  SHIN JENNY YOUNG\n6800 GUEST CALL SUITE 425\nELKRIDGE, MD 21075
# 14  None
# 15  TRUE ENTERPRISE INC\n5967 OXBRIDGE DRIVE\nSALISBURY, MD 21801
# 16  None
# 17  None
# 18  None
# 19  None
# 20  VAPEWERKS LLC\n155 WILLOW AVENUE\nKEYSER, WV 26726
# 21  VAPIST MD LLC\n2119 CREEKS EDGE LANE\nWALDORF, MD 20601
# 22  None
# 23  VAPOR ALLEY LLC\n8117 OCEAN GATEWAY UNIT #4\nEASTON, MARYLAND 21601
# 24  VAPOR EMPORIUM MD LLC
# 25  VAPOR VILLA CORP
# 26  VAPOR VILLA CORP
# 27  VAPORS LOUNGE LLC
# 28  WALKER TRADING CO INC\n11600 CROSSROADS CIRCLE\nSUITE E\nMIDDLE RIVER, MD 21220
# 29  WALKER TRADING COMPANY INC\n11600 CROSSROADS CIRCLE\nSUITE E\nMIDDLE RIVER, MD 21220
# 30  WALKER TRADING COMPANY INC
# 31  WALKER TRADING COMPANY INC\n11600 CROSSROADS CIRCLE\nSUITE E\nMIDDLE RIVER, MD 21220
# 32  None
# 33  YEAGER ONE INC\n545 HIGGINS DR\nODENTON, MD 21113
#
#                                                           location_address  \
# 0   VAPE IT STORE II\n1015 S SALISBURY BLVD\nSALISBURY, MD 21801
# 1   VAPE IT STORE I\n1724 N SALISBURY BLVD UNIT 2\nSALISBURY, MD 21801
# 2   VAPEPAD THE\n2299 JOHNS HOPKINS ROAD\nGAMBRILLS, MD 21054
# 3   None
# 4   None
# 5   VAPE LOFT THE\n185 MITCHELLS CHANCE RD\nEDGEWATER, MD 21037
# 6   VAPE N CIGAR\n7104 MINSTREL UNIT #7\nCOLUMBIA, MD 21045
# 7   VAPE DOJO\n330 ONE FORTY VILLAGE ROAD\nUNIT 15\nWESTMINSTER, MD 21157
# 8   None
# 9   None
# 10  VAPORFI SOUTHSIDE\n853 EAST FORT AVE\nBALTIMORE, MD 21230
# 11  VAPE DO JO\n2021 LIBERTY ROAD\nSYKESVILLE, MD 21784
# 12  None
# 13  VAPERTEKMD\n6325 WASHINGTON BLVD STE N\nELKRIDGE, MD 21075
# 14  None
# 15  VAPE PLUS\n519 LINDEN AVENUE UNIT 6\nPOCOMOKE CITY, MD 21851
# 16  None
# 17  None
# 18  None
# 19  None
# 20  VAPEWERKS\n16115 MCMULLEN HWY SW\nUNIT 7\nCUMBERLAND, MD 21502
# 21  VAPIST MD\n6321 OLD BRANCH AVE\nCAMP SPRINGS, MD 20748
# 22  None
# 23  VAPOR ALLEY\n8117 OCEAN GATEWAY UNIT #4\nEASTON, MD 21601
# 24  VAPOR EMPORIUM\n11717 OLD NATIONAL PIKE\nUNIT 3B\nNEW MARKET, MD 21774
# 25  VAPOR VILLA\n1913 LANSDOWNE ROAD\nSUITE E\nBALTIMORE, MD 21227
# 26  VAPOR VILLA\n730 FREDERICK ROAD\nSUITE 202\nCATONSVILLE, MD 21228
# 27  VAPORS LOUNGE\n28943 THREE NOTCH ROAD\nMECHANICSVILLE, MD 20659
# 28  VAPE DOJO\n138 N BOND STREET\nBEL AIR, MD 21014
# 29  VAPE DOJO\n331 GAMBRILLS ROAD\nGAMBRILLS, MD 21054
# 30  VAPE DOJO\n11600 CROSSROAD CIR STE E\nBALTIMORE, MD 21220
# 31  VAPE DOJO\n3570 SAINT JOHNS LANE, SUITE 109\nELLICOTT CITY, MD 21042
# 32  None
# 33  VAPERS RING\n545 BENFIELD RD\nSEVERNA PARK, MD 21146
#
#    total_cost  \
# 0   35.00
# 1   $ 24.00
# 2   $ 94.00
# 3   None
# 4   None
# 5   $ 154.00
# 6   $ 84.00
# 7   $ 179.00
# 8   None
# 9   None
# 10  $ 189.00
# 11  $ 154.00
# 12  None
# 13  $ 34.00
# 14  None
# 15  $ 37.00
# 16  None
# 17  None
# 18  None
# 19  None
# 20  115.00
# 21  $ 69.00
# 22  None
# 23  $ 229.00
# 24  $ 229.00
# 25  117.00
# 26  117.00
# 27  $ 94.00
# 28  62.50
# 29  112.50
# 30  408.33
# 31  72.50
# 32  None
# 33  110.00
#
#                                                                                                        issued_info  \
# 0   WICOMICO COUNTY, CLERK OF CIRCUIT COURT\nP.O. BOX 198\nSALISBURY, MARYLAND 21803-0198
# 1   WICOMICO COUNTY, CLERK OF CIRCUIT COURT\nP.O. BOX 198\nSALISBURY, MARYLAND 21803-0198
# 2   ROBERT P. DUCKWORTH, CLERK OF CIRCUIT COURT\n8 CHURCH CIRCLE, ROOM H-101\nANNAPOLIS, MARYLAND 21401
# 3   None
# 4   None
# 5   ROBERT P. DUCKWORTH, CLERK OF CIRCUIT COURT\n8 CHURCH CIRCLE, ROOM H-101\nANNAPOLIS, MARYLAND 21401
# 6   WAYNE A. ROBEY, CLERK OF CIRCUIT COURT\n9250 BENDIX ROAD\nCOLUMBIA, MARYLAND 21045
# 7   DONALD B. SEALING II, CLERK OF CIRCUIT COURT\n55 NORTH COURT STREET\nWESTMINSTER, MARYLAND 21157-5155
# 8   None
# 9   None
# 10  MARILYN BENTLEY, CLERK CIRCUIT COURT\n100 N. CALVERT STREET, ROOM 627\nBALTIMORE, MARYLAND 21202
# 11  DONALD B. SEALING II, CLERK OF CIRCUIT COURT\n55 NORTH COURT STREET\nWESTMINSTER, MARYLAND 21157-5155
# 12  None
# 13  WAYNE A. ROBEY, CLERK OF CIRCUIT COURT\n9250 BENDIX ROAD\nCOLUMBIA, MARYLAND 21045
# 14  None
# 15  SUSAN R. BRANIECKI, CLERK OF CIRCUIT COURT\n1 West Market Street, Room 104\nSNOW HILL, MARYLAND 21863
# 16  None
# 17  None
# 18  None
# 19  None
# 20  DAWNE D. LINDSEY, CLERK OF CIRCUIT COURT\n30 WASHINGTON STREET\nCUMBERLAND, MARYLAND 21502
# 21  SYDNEY J. HARRISON, CLERK OF CIRCUIT COURT\n14735 MAIN STREET\nUPPER MARLBORO, MARYLAND 20772-9987
# 22  None
# 23  MARY ANN SHORTALL, CLERK OF CIRCUIT COURT\n11 NORTH WASHINGTON ST., STE 16\nEASTON, MARYLAND 21601
# 24  SANDRA DALTON, CLERK OF CIRCUIT COURT\n100 WEST PATRICK STREET\nFREDERICK, MARYLAND 21701
# 25  JULIE L. ENSOR, CLERK OF CIRCUIT COURT\nP.O. Box 6754\nTOWSON, MARYLAND 21285-6754
# 26  JULIE L. ENSOR, CLERK OF CIRCUIT COURT\nP.O. Box 6754\nTOWSON, MARYLAND 21285-6754
# 27  TRACY CANTRELL, ACTING CLERK OF CIRCUIT COURT\n41605 COURTHOUSE DRIVE, PO BOX 676\nLEONARDTOWN, MARYLAND 20650
# 28  JAMES J. REILLY, CLERK OF CIRCUIT COURT\n20 WEST COURTLAND STREET\nBEL AIR, MARYLAND 21014
# 29  ROBERT P. DUCKWORTH, CLERK OF CIRCUIT COURT\n8 CHURCH CIRCLE, ROOM H-101\nANNAPOLIS, MARYLAND 21401
# 30  JULIE L. ENSOR, CLERK OF CIRCUIT COURT\nP.O. Box 6754\nTOWSON, MARYLAND 21285-6754
# 31  WAYNE A. ROBEY, CLERK OF CIRCUIT COURT\n9250 BENDIX ROAD\nCOLUMBIA, MARYLAND 21045
# 32  None
# 33  ROBERT P. DUCKWORTH, CLERK OF CIRCUIT COURT\n8 CHURCH CIRCLE, ROOM H-101\nANNAPOLIS, MARYLAND 21401
#
#                                                                                                                                                                    license_status  \
# 0   License Status: Issued\nLicense No.: 22375606\nControl No.: 22884439\nDate of Issue: 4/27/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 22 Salisbury
# 1   License Status: Issued\nLicense No.: 22375605\nControl No.: 22591855\nDate of Issue: 4/27/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 22 Salisbury
# 2   License Status: Issued\nLicense No.: 02304705\nControl No.: 02685930\nDate of Issue: 4/05/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 02 Anne Arundel County
# 3   None
# 4   None
# 5   License Status: Issued\nLicense No.: 02310799\nControl No.: 02686069\nDate of Issue: 4/03/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 02 Anne Arundel County
# 6   License Status: Issued\nLicense No.: 13343011\nControl No.: 13856368\nDate of Issue: 4/30/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 13 Howard County
# 7   License Status: Issued\nLicense No.: 06327188\nControl No.: 06946760\nDate of Issue: 4/05/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 06 Westminster
# 8   None
# 9   None
# 10  License Status: Issued\nLicense No.: 30390631\nControl No.: 30190160\nDate of Issue: 4/20/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 30 Baltimore City
# 11  License Status: Issued\nLicense No.: 06328812\nControl No.: 06328812\nDate of Issue: 5/03/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 06 Sykesville
# 12  None
# 13  License Status: Issued\nLicense No.: 13342043\nControl No.: 13961721\nDate of Issue: 5/07/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 13 Howard County
# 14  None
# 15  License Status: Issued\nLicense No.: 23380005\nControl No.: 23990202\nDate of Issue: 5/31/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 23 Pocomoke
# 16  None
# 17  None
# 18  None
# 19  None
# 20  License Status: Issued\nLicense No.: 01302079\nControl No.: 01102169\nDate of Issue: 6/07/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 01 Allegany County
# 21  License Status: Issued\nLicense No.: 16366948\nControl No.: 16166805\nDate of Issue: 5/05/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 16 Prince George's County
# 22  None
# 23  License Status: Issued\nLicense No.: 20372618\nControl No.: 20739879\nDate of Issue: 4/24/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 20 Easton
# 24  License Status: Issued\nLicense No.: 10336513\nControl No.: 10954003\nDate of Issue: 5/04/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 10 Frederick County
# 25  License Status: Issued\nLicense No.: 03322784\nControl No.: 03696574\nDate of Issue: 4/26/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 03 Baltimore County
# 26  License Status: Issued\nLicense No.: 03322785\nControl No.: 03696931\nDate of Issue: 4/26/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 03 Baltimore County
# 27  License Status: Issued\nLicense No.: 18369505\nControl No.: 18877819\nDate of Issue: 4/17/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 18 St. Mary's County
# 28  License Status: Issued\nLicense No.: 12341351\nControl No.: 12958340\nDate of Issue: 5/29/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 12 Bel Air
# 29  License Status: Issued\nLicense No.: 02310917\nControl No.: 02111914\nDate of Issue: 6/01/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 02 Anne Arundel County
# 30  License Status: Issued\nLicense No.: 03322944\nControl No.: 03837488\nDate of Issue: 5/30/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 03 Baltimore County
# 31  License Status: Issued\nLicense No.: 13345355\nControl No.: 13563224\nDate of Issue: 5/23/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 13 Howard County
# 32  None
# 33  License Status: Issued\nLicense No.: 02311125\nControl No.: 02111865\nDate of Issue: 5/22/2018\nMonths Paid: 12\nExp. Date: 4/30/2019\nSubdivision: 02 Anne Arundel County
#
#                    license_a               name  \
# 0   OTHER TOBACCO PROD RETLR  VAPE IT STORE II
# 1   TRADER'S LICENSE          VAPE IT STORE I
# 2   TRADER'S LICENSE          VAPEPAD THE
# 3   None                      VAPE FROG
# 4   None                      VAPE FROG
# 5   TRADER'S LICENSE          VAPE LOFT THE
# 6   TRADER'S LICENSE          VAPE N CIGAR
# 7   TRADER'S LICENSE          VAPE DOJO
# 8   None                      VAPE HAVEN
# 9   None                      VAPORS LOUNGE
# 10  TRADER'S LICENSE          VAPORFI SOUTHSIDE
# 11  TRADER'S LICENSE          VAPE DO JO
# 12  None                      VAPERTETMD
# 13  CHAIN STORE               VAPERTEKMD
# 14  None                      VAPORIOT
# 15  TRADER'S LICENSE          VAPE PLUS
# 16  None                      VAPE SOCIAL
# 17  None                      VAPE JUNGLE
# 18  None                      VAPE TIME
# 19  None                      VAPEBAR EXPESS
# 20  VAPE SHOP VENDOR          VAPEWERKS
# 21  TRADER'S LICENSE          VAPIST MD
# 22  None                      VAPOR 99
# 23  TRADER'S LICENSE          VAPOR ALLEY
# 24  VAPE SHOP VENDOR          VAPOR EMPORIUM
# 25  TRADER'S LICENSE          VAPOR VILLA
# 26  TRADER'S LICENSE          VAPOR VILLA
# 27  TRADER'S LICENSE          VAPORS LOUNGE
# 28  CHAIN STORE               VAPE DOJO
# 29  CHAIN STORE               VAPE DOJO
# 30  CHAIN STORE               VAPE DOJO
# 31  CHAIN STORE               VAPE DOJO
# 32  None                      VAPEZ YARDHOUSE
# 33  TRADER'S LICENSE          VAPERS RING
#
#                                                                                 url
# 0   https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=bmDExzf4ZDw%3D
# 1   https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=glqAu7o7gJE%3D
# 2   https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=zjsVR%2F6x1p8%3D
# 3   There is not a url.
# 4   There is not a url.
# 5   https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=%2BlPU%2F8mjjj8%3D
# 6   https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=rGdKgh3sllo%3D
# 7   https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=2NDDt0T4zOs%3D
# 8   There is not a url.
# 9   There is not a url.
# 10  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=pCof3aaX%2FUE%3D
# 11  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=bw3%2B0tFjXPs%3D
# 12  There is not a url.
# 13  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=%2F9s1kI8bGz4%3D
# 14  There is not a url.
# 15  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=x8Vd4xxywj0%3D
# 16  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=%2FODDnghKIhA%3D
# 17  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=mpgmehKTqqM%3D
# 18  There is not a url.
# 19  There is not a url.
# 20  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=4pxdegkiD9c%3D
# 21  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=kk9O5GBXwK8%3D
# 22  There is not a url.
# 23  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=KY%2Bl6bI4Upc%3D
# 24  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=Dd4fWHd8Ugw%3D
# 25  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=yxSN89SvtSc%3D
# 26  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=r9K0HsjeGRw%3D
# 27  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=42AylWf%2BWfw%3D
# 28  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=DBPF%2BWdXTbU%3D
# 29  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=0T6cxGK0K7s%3D
# 30  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=4elqKZcsWPg%3D
# 31  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=%2FZw0DsqbR5Y%3D
# 32  There is not a url.
# 33  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=0vA2xgF7VjM%3D

# %% [markdown]
# ## Save as `vape-total.csv`
#
# Make sure you don't save the index! Open it up in a text editor or Excel to make sure it's correct.

# %%
vape_df.to_csv("vape-total.csv", index=False)

# %%
vape_df = pd.read_csv('vape-total.csv')
vape_df.head()
# Out:
#                                                            mail_address  \
# 0  AMIN NARGIS\r\n1104 PLANTERS PLACE\r\nSALISBURY, MD 21804
# 1  AMIN NARGIS\r\n1104 PLANTERS PLACE\r\nSALISBURY, MD 21804
# 2  ANJ DISTRIBUTIONS LLC\r\n2504 ORCHARD KNOLL WAY\r\nODENTON, MD 21113
# 3  NaN
# 4  NaN
#
#                                                          location_address  \
# 0  VAPE IT STORE II\r\n1015 S SALISBURY BLVD\r\nSALISBURY, MD 21801
# 1  VAPE IT STORE I\r\n1724 N SALISBURY BLVD UNIT 2\r\nSALISBURY, MD 21801
# 2  VAPEPAD THE\r\n2299 JOHNS HOPKINS ROAD\r\nGAMBRILLS, MD 21054
# 3  NaN
# 4  NaN
#
#   total_cost  \
# 0  35.00
# 1  $ 24.00
# 2  $ 94.00
# 3  NaN
# 4  NaN
#
#                                                                                                issued_info  \
# 0  WICOMICO COUNTY, CLERK OF CIRCUIT COURT\r\nP.O. BOX 198\r\nSALISBURY, MARYLAND 21803-0198
# 1  WICOMICO COUNTY, CLERK OF CIRCUIT COURT\r\nP.O. BOX 198\r\nSALISBURY, MARYLAND 21803-0198
# 2  ROBERT P. DUCKWORTH, CLERK OF CIRCUIT COURT\r\n8 CHURCH CIRCLE, ROOM H-101\r\nANNAPOLIS, MARYLAND 21401
# 3  NaN
# 4  NaN
#
#                                                                                                                                                                            license_status  \
# 0  License Status: Issued\r\nLicense No.: 22375606\r\nControl No.: 22884439\r\nDate of Issue: 4/27/2018\r\nMonths Paid: 12\r\nExp. Date: 4/30/2019\r\nSubdivision: 22 Salisbury
# 1  License Status: Issued\r\nLicense No.: 22375605\r\nControl No.: 22591855\r\nDate of Issue: 4/27/2018\r\nMonths Paid: 12\r\nExp. Date: 4/30/2019\r\nSubdivision: 22 Salisbury
# 2  License Status: Issued\r\nLicense No.: 02304705\r\nControl No.: 02685930\r\nDate of Issue: 4/05/2018\r\nMonths Paid: 12\r\nExp. Date: 4/30/2019\r\nSubdivision: 02 Anne Arundel County
# 3  NaN
# 4  NaN
#
#                   license_a              name  \
# 0  OTHER TOBACCO PROD RETLR  VAPE IT STORE II
# 1  TRADER'S LICENSE          VAPE IT STORE I
# 2  TRADER'S LICENSE          VAPEPAD THE
# 3  NaN                       VAPE FROG
# 4  NaN                       VAPE FROG
#
#                                                                              url
# 0  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=bmDExzf4ZDw%3D
# 1  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=glqAu7o7gJE%3D
# 2  https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=zjsVR%2F6x1p8%3D
# 3  There is not a url.
# 4  There is not a url.
