# %% [markdown]
# # Scraping mine data with `.apply`
#
# ## The pages we'll be looking at
#
# If I wanted to read specific information about a specfic mine, it takes a few steps. **Do these steps with your browser before you try any programming.**
#
# 1. Visit the [Mine Data Retrieval System](https://arlweb.msha.gov/drs/drshome.htm)
# 2. Scroll down to **Mine Identification Number (ID) Search**
# 3. Type in a mine ID number, such as `3503598`, click **Search**
# 4. I'm on a page! It lists the MINE NAME and MINE OWNER.
#
# After searching for and finding a mine, I can use this page to **find reports about this mine**. Some of the reports are on accidents, violations, inspections, health samples and more. To get those reports:
#
# 1. Search for a mine (if you haven't already)
# 2. Scroll down and change **Beginning Date** to `1/1/1995` (violation reports begin in 1995, accidents begin in 1983)
# 3. Select the report type of `Violations`
# 4. Click **Get Report**
# 5. I'm on a page! It lists ALL OF THE MINE'S VIOLATIONS.
#
# By changing the report type you're searching for you can find all sorts of different data.

# %% [markdown]
# # Doing this programmatically
#
# ## First, scraping a single page
#
# ### Import your imports

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait

import pandas as pd
import time

# %% [markdown]
# ### Searching for a mine
#
# Visit the [Mine Data Retrieval System](https://arlweb.msha.gov/drs/drshome.htm) and use Selenium to search for `3503598`
#
# - *TIP: You might need to use the Selenium code to scroll down to the right spot on the page. Or not!*
# - *TIP: Use `.send_keys` to type into the box*
# - *TIP: On pages that never change, you can usually just use XPath if you're feeling lazy*

# %%
driver = webdriver.Chrome()

driver.get("https://arlweb.msha.gov/drs/drshome.htm")

# %%
search_field = driver.find_element_by_name('MineId')
driver.execute_script("arguments[0].scrollIntoView(true)", search_field)
search_field.send_keys('3503598')
driver.find_element_by_xpath('//*[@id="content"]/table[3]/tbody/tr[3]/td[2]/input').click()

# %% [markdown]
# ### Finding reports
#
# On the "Report Selection Page" (where you should be after you search), use Selenium to...
#
# - Change the **Beginning Date** to `1/1/1995`
# - Select the report type of `Violations`
# - Click **Get Report**
#
# .
#
# - *TIP: Remember, if someone isn't on the page Selenium can't click it!*

# %%
bdate = driver.find_element_by_name('BDate')
bdate.send_keys('1/1/1995')

# %%
type_button = driver.find_element_by_xpath('//*[@id="content"]/form[1]/table[3]/tbody/tr[2]/td[2]/table/tbody/tr[1]/td/input')
type_button.click()

# %%
get_report_button = driver.find_element_by_xpath('//*[@id="content"]/form[1]/table[3]/tbody/tr[3]/td[2]/input')
get_report_button.click()

# %% [markdown]
# ### Saving reports
#
# Save all of the rows of data on that page into a new dataframe. Each column is its own column, **and you also need to save the URL under the 'Standard' column.** Here, I even made you a blank dictionary:
#
# ```python
# data = {}
# data['violator'] = ''
# data['contract_id'] = ''
# data['citation_no'] = ''
# data['case_no'] = ''
# data['date_issues'] = ''
# data['final_order_date'] = ''
# data['section_of_act'] = ''
# data['date_terminated'] = ''
# data['citation'] = ''
# data['s_and_s'] = ''
# data['standard'] = ''
# data['standard_url'] = ''
# data['proposed_penalty'] = ''
# data['citation_status'] = ''
# data['current_penalty'] = ''
# data['amount_paid'] = ''
# ```
#
# - *TIP: Some of those table rows aren't what you want. How can you tell them apart from the good ones? (the previous mine owner ones are okay, I just mean the weird headers)*
# - *TIP: I sense `.find_elements` + a lot of square brackets*
# - *TIP: This is just like scraping a search results page!*
# - *TIP: For the URL, you'll need to find the `a` inside of the cell*
# - *TIP: class name is sadly not going to save your life here, because some of the `tr`s and `td`s have the same class! It's stupid. But there's a trick: CSS selectors! Something like `div#container` finds a `div` with the id of `container`, while `span.important` finds a `span` with the class of `important`. It should be helpful! And use `.find_elements_by_` + tab to see what the command is*

# %%
reports = driver.find_elements_by_xpath('//*[@id="content"]/table[5]/tbody/tr')
#print(reports)

violations = []

for report in reports[1:]:
    
    print('---------')

    data = {}
    
    if len(report.find_elements_by_class_name('drsviols')) != 0:
        print(report.find_element_by_class_name('drsviols').text)

#row = report.find_elements_by_class_name('drsviols')

        data['violator'] = report.find_elements_by_class_name('drsviols')[0].text
        print(report.find_elements_by_class_name('drsviols')[0].text)

        data['contract_id'] = report.find_elements_by_class_name('drsviols')[1].text
        print(report.find_elements_by_class_name('drsviols')[1].text)

        data['citation_no'] = report.find_elements_by_class_name('drsviols')[2].text
        print(report.find_elements_by_class_name('drsviols')[2].text)

        data['case_no'] = report.find_elements_by_class_name('drsviols')[3].text
        print(report.find_elements_by_class_name('drsviols')[3].text)

        data['date_issues'] = report.find_elements_by_class_name('drsviols')[4].text
        print(report.find_elements_by_class_name('drsviols')[4].text)

        data['final_order_date'] = report.find_elements_by_class_name('drsviols')[5].text
        print(report.find_elements_by_class_name('drsviols')[5].text)

        data['section_of_act'] = report.find_elements_by_class_name('drsviols')[6].text
        print(report.find_elements_by_class_name('drsviols')[6].text)

        data['date_terminated'] = report.find_elements_by_class_name('drsviols')[7].text
        print(report.find_elements_by_class_name('drsviols')[7].text)

        data['citation'] = report.find_elements_by_class_name('drsviols')[8].text
        print(report.find_elements_by_class_name('drsviols')[8].text)

        data['s_and_s'] = report.find_elements_by_class_name('drsviols')[9].text
        print(report.find_elements_by_class_name('drsviols')[9].text)

        data['standard'] = report.find_elements_by_class_name('drsviols')[10].text
        print(report.find_elements_by_class_name('drsviols')[10].text)

        data['standard_url'] = report.find_elements_by_class_name('drsviols')[10].find_element_by_tag_name('a').get_attribute('href')
        print(report.find_elements_by_class_name('drsviols')[10].find_element_by_tag_name('a').get_attribute('href'))

        data['proposed_penalty'] = report.find_elements_by_class_name('drsviols')[11].text
        print(report.find_elements_by_class_name('drsviols')[11].text)

        data['citation_status'] = report.find_elements_by_class_name('drsviols')[12].text
        print(report.find_elements_by_class_name('drsviols')[12].text)

        data['current_penalty'] = report.find_elements_by_class_name('drsviols')[13].text
        print(report.find_elements_by_class_name('drsviols')[13].text)

        data['amount_paid'] = report.find_elements_by_class_name('drsviols')[14].text
        print(report.find_elements_by_class_name('drsviols')[14].text)

        violations.append(data)
# Out:
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8992368
# 000440809
# 5/2/2017
# 7/23/2017
# 104(a)
# 5/2/2017
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2017-title30-vol1/pdf/CFR-2017-title30-vol1-sec56-14107.pdf
# 116.00
# Closed
# 116.00
# 116.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8992214
# 000435717
# 2/7/2017
# 5/21/2017
# 104(a)
# 2/8/2017
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2017-title30-vol1/pdf/CFR-2017-title30-vol1-sec56-14107.pdf
# 116.00
# Closed
# 116.00
# 116.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8872462
# 000398910
# 10/21/2015
# 1/13/2016
# 104(a)
# 10/27/2015
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2015-title30-vol1/pdf/CFR-2015-title30-vol1-sec56-14107.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8872461
# 000398910
# 10/21/2015
# 1/13/2016
# 104(a)
# 10/27/2015
# C
# N
# 56.12004
# http://www.gpo.gov/fdsys/pkg/CFR-2015-title30-vol1/pdf/CFR-2015-title30-vol1-sec56-12004.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8790965
# 000383840
# 4/15/2015
# 7/17/2015
# 104(a)
# 4/15/2015
# C
# N
# 56.13015
# http://www.gpo.gov/fdsys/pkg/CFR-2015-title30-vol1/pdf/CFR-2015-title30-vol1-sec56-13015.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8790964
# 000383840
# 4/13/2015
# 7/17/2015
# 104(a)
# 4/15/2015
# C
# N
# 56.4101
# http://www.gpo.gov/fdsys/pkg/CFR-2015-title30-vol1/pdf/CFR-2015-title30-vol1-sec56-4101.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8790963
# 000383840
# 4/10/2015
# 7/17/2015
# 104(a)
# 4/13/2015
# C
# Y
# 56.15020
# http://www.gpo.gov/fdsys/pkg/CFR-2015-title30-vol1/pdf/CFR-2015-title30-vol1-sec56-15020.pdf
# 873.00
# Closed
# 873.00
# 873.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8790962
# 000383840
# 4/10/2015
# 7/17/2015
# 104(a)
# 4/10/2015
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2015-title30-vol1/pdf/CFR-2015-title30-vol1-sec56-14107.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8694458
# 000345066
# 1/29/2014
# 4/12/2014
# 104(a)
# 1/29/2014
# C
# N
# 56.12018
# http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-vol1/pdf/CFR-2014-title30-vol1-sec56-12018.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8694457
# 000345066
# 1/29/2014
# 4/12/2014
# 104(a)
# 1/29/2014
# C
# N
# 56.12004
# http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-vol1/pdf/CFR-2014-title30-vol1-sec56-12004.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8694455
# 000345066
# 1/28/2014
# 4/12/2014
# 104(a)
# 1/29/2014
# C
# N
# 56.12004
# http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-vol1/pdf/CFR-2014-title30-vol1-sec56-12004.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8694453
# 000345066
# 1/28/2014
# 4/12/2014
# 104(a)
# 1/29/2014
# C
# N
# 56.4201(a)(1)
# http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-vol1/pdf/CFR-2014-title30-vol1-sec56-4201.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8694452
# 000345066
# 1/28/2014
# 4/12/2014
# 104(a)
# 1/29/2014
# C
# N
# 56.14132(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-vol1/pdf/CFR-2014-title30-vol1-sec56-14132.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8694451
# 000347758
# 1/28/2014
# 5/14/2014
# 104(a)
# 1/29/2014
# C
# N
# 56.14100(b)
# http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-vol1/pdf/CFR-2014-title30-vol1-sec56-14100.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8694450
# 000345066
# 1/28/2014
# 4/12/2014
# 104(a)
# 1/29/2014
# C
# N
# 56.14132(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-vol1/pdf/CFR-2014-title30-vol1-sec56-14132.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8694456
# 000345066
# 1/28/2014
# 4/12/2014
# 104(a)
# 1/29/2014
# C
# N
# 56.14132(b)(1)
# http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-vol1/pdf/CFR-2014-title30-vol1-sec56-14132.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8694454
# 000345066
# 1/28/2014
# 4/12/2014
# 104(a)
# 1/29/2014
# C
# Y
# 56.12032
# http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-vol1/pdf/CFR-2014-title30-vol1-sec56-12032.pdf
# 243.00
# Closed
# 243.00
# 243.00
# ---------
# ---------
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8599787
# 000291331
# 5/1/2012
# 7/13/2012
# 104(a)
# 5/7/2012
# C
# N
# 56.14108
# http://www.gpo.gov/fdsys/pkg/CFR-2012-title30-vol1/pdf/CFR-2012-title30-vol1-sec56-14108.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8599788
# 000291331
# 5/1/2012
# 7/13/2012
# 104(a)
# 5/7/2012
# C
# N
# 56.12004
# http://www.gpo.gov/fdsys/pkg/CFR-2012-title30-vol1/pdf/CFR-2012-title30-vol1-sec56-12004.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8599789
# 000297041
# 5/1/2012
# 9/13/2012
# 104(a)
# 5/7/2012
# C
# Y
# 56.14101(a)(2)
# http://www.gpo.gov/fdsys/pkg/CFR-2012-title30-vol1/pdf/CFR-2012-title30-vol1-sec56-14101.pdf
# 243.00
# Closed
# 243.00
# 243.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8599107
# 000269626
# 9/7/2011
# 11/18/2011
# 104(a)
# 9/19/2011
# C
# N
# 50.30(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2011-title30-vol1/pdf/CFR-2011-title30-vol1-sec50-30.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8599025
# 000239613
# 10/7/2010
# 1/5/2011
# 104(a)
# 10/7/2010
# C
# N
# 56.12004
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec56-12004.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8599026
# 000239613
# 10/7/2010
# 1/5/2011
# 104(a)
# 10/7/2010
# C
# N
# 56.12004
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec56-12004.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6398905
# 000220925
# 4/20/2010
# 7/9/2010
# 104(a)
# 6/8/2010
# C
# Y
# 56.11001
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec56-11001.pdf
# 117.00
# Closed
# 117.00
# 117.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6338508
# 000210055
# 12/29/2009
# 1/10/2013
# 104(a)
# 12/30/2009
# C
# N
# 56.11002
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-11002.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6338509
# 000210055
# 12/29/2009
# 1/10/2013
# 104(a)
# 1/11/2010
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-14107.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6338510
# 000210055
# 12/29/2009
# 1/10/2013
# 104(a)
# 12/30/2009
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-14107.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6338512
# 000210055
# 12/29/2009
# 1/10/2013
# 104(a)
# 12/29/2009
# C
# N
# 56.12004
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-12004.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6338511
# 000210055
# 12/29/2009
# 1/10/2013
# 104(a)
# 1/11/2010
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-14107.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6338507
# 000210055
# 12/29/2009
# 1/10/2013
# 104(a)
# 1/11/2010
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-14107.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6479614
# 000180614
# 2/26/2009
# 5/22/2010
# 104(a)
# 3/4/2009
# C
# N
# 56.14100(d)
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-14100.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6479620
# 000180614
# 2/26/2009
# 5/8/2009
# 104(a)
# 3/4/2009
# C
# N
# 56.12028
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-12028.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6479618
# 000180614
# 2/26/2009
# 5/22/2010
# 104(a)
# 3/4/2009
# C
# N
# 56.14130(i)
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-14130.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6479612
# 000180614
# 2/26/2009
# 5/22/2010
# 104(a)
# 3/4/2009
# C
# Y
# 56.9200(d)
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-9200.pdf
# 263.00
# Closed
# 263.00
# 263.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6479619
# 000180614
# 2/26/2009
# 5/22/2010
# 104(a)
# 2/26/2009
# C
# N
# 56.14100(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-14100.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6479616
# 000180614
# 2/26/2009
# 5/22/2010
# 104(a)
# 3/4/2009
# C
# N
# 56.14103(b)
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-14103.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6479617
# 000180614
# 2/26/2009
# 5/8/2009
# 104(a)
# 3/4/2009
# C
# N
# 56.4201(a)(2)
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-4201.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6479615
# 000180614
# 2/26/2009
# 5/22/2010
# 104(a)
# 3/4/2009
# C
# N
# 56.14100(b)
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-14100.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6479613
# 000180614
# 2/26/2009
# 5/22/2010
# 104(a)
# 2/26/2009
# C
# Y
# 56.3200
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-3200.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6430326
# 000152001
# 4/2/2008
# 7/10/2008
# 104(a)
# 4/3/2008
# C
# N
# 56.14100(b)
# http://www.gpo.gov/fdsys/pkg/CFR-2008-title30-vol1/pdf/CFR-2008-title30-vol1-sec56-14100.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6430325
# 000152001
# 4/2/2008
# 7/10/2008
# 104(a)
# 4/3/2008
# C
# N
# 56.14112(a)(1)
# http://www.gpo.gov/fdsys/pkg/CFR-2008-title30-vol1/pdf/CFR-2008-title30-vol1-sec56-14112.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6342892
# 000121048
# 5/23/2007
# 8/17/2007
# 104(a)
# 5/24/2007
# C
# N
# 56.14100(b)
# http://www.gpo.gov/fdsys/pkg/CFR-2007-title30-vol1/pdf/CFR-2007-title30-vol1-sec56-14100.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6342893
# 000121048
# 5/23/2007
# 8/17/2007
# 104(a)
# 5/24/2007
# C
# N
# 56.14100(b)
# http://www.gpo.gov/fdsys/pkg/CFR-2007-title30-vol1/pdf/CFR-2007-title30-vol1-sec56-14100.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6342894
# 000121048
# 5/23/2007
# 8/17/2007
# 104(a)
# 5/24/2007
# C
# N
# 56.14132(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2007-title30-vol1/pdf/CFR-2007-title30-vol1-sec56-14132.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6342895
# 000121048
# 5/23/2007
# 8/17/2007
# 104(a)
# 5/24/2007
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2007-title30-vol1/pdf/CFR-2007-title30-vol1-sec56-14107.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6383438
# 000086543
# 3/1/2006
# 6/16/2006
# 104(a)
# 3/2/2006
# C
# N
# 56.11002
# http://www.gpo.gov/fdsys/pkg/CFR-2006-title30-vol1/pdf/CFR-2006-title30-vol1-sec56-11002.pdf
# 60.00
# Closed
# 60.00
# 60.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6383437
# 000086543
# 3/1/2006
# 6/16/2006
# 104(a)
# 3/2/2006
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2006-title30-vol1/pdf/CFR-2006-title30-vol1-sec56-14107.pdf
# 60.00
# Closed
# 60.00
# 60.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6368407
# 000051247
# 10/27/2004
# 7/23/2005
# 104(a)
# 1/21/2005
# C
# N
# 62.120
# http://www.gpo.gov/fdsys/pkg/CFR-2004-title30-vol1/pdf/CFR-2004-title30-vol1-sec62-120.pdf
# 60.00
# Closed
# 60.00
# 60.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6368406
# 000044260
# 10/25/2004
# 1/12/2005
# 104(a)
# 10/27/2004
# C
# Y
# 56.14131(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2004-title30-vol1/pdf/CFR-2004-title30-vol1-sec56-14131.pdf
# 99.00
# Closed
# 99.00
# 99.00

# %%
len(violations)
# Out:
# 49

# %% [markdown]
# ### Saving that data
#
# Save the dataframe to a CSV file called `3503598-violations.csv` (that's the TDLR code)

# %%
df = pd.DataFrame(violations)
df.head()
# Out:
#   amount_paid    case_no citation citation_no citation_status contract_id  \
# 0     116.00   000440809        C   8992368            Closed
# 1     116.00   000435717        C   8992214            Closed
# 2     100.00   000398910        C   8872462            Closed
# 3     100.00   000398910        C   8872461            Closed
# 4     100.00   000383840        C   8790965            Closed
#
#   current_penalty date_issues date_terminated final_order_date  \
# 0         116.00     5/2/2017        5/2/2017       7/23/2017
# 1         116.00     2/7/2017        2/8/2017       5/21/2017
# 2         100.00   10/21/2015      10/27/2015       1/13/2016
# 3         100.00   10/21/2015      10/27/2015       1/13/2016
# 4         100.00    4/15/2015       4/15/2015       7/17/2015
#
#   proposed_penalty s_and_s section_of_act     standard  \
# 0           116.00       N         104(a)  56.14107(a)
# 1           116.00       N         104(a)  56.14107(a)
# 2           100.00       N         104(a)  56.14107(a)
# 3           100.00       N         104(a)     56.12004
# 4           100.00       N         104(a)     56.13015
#
#                                         standard_url             violator
# 0  http://www.gpo.gov/fdsys/pkg/CFR-2017-title30-...  Newberg Rock & Dirt
# 1  http://www.gpo.gov/fdsys/pkg/CFR-2017-title30-...  Newberg Rock & Dirt
# 2  http://www.gpo.gov/fdsys/pkg/CFR-2015-title30-...  Newberg Rock & Dirt
# 3  http://www.gpo.gov/fdsys/pkg/CFR-2015-title30-...  Newberg Rock & Dirt
# 4  http://www.gpo.gov/fdsys/pkg/CFR-2015-title30-...  Newberg Rock & Dirt

# %% [markdown]
# ## Put that all in ONE cell that runs correctly
#
# The **entire process**, from searching to saving as a CSV

# %%
driver.get("https://arlweb.msha.gov/drs/drshome.htm")

search_field = driver.find_element_by_name('MineId')
driver.execute_script("arguments[0].scrollIntoView(true)", search_field)
search_field.send_keys('3503598')
driver.find_element_by_xpath('//*[@id="content"]/table[3]/tbody/tr[3]/td[2]/input').click()

time.sleep(1)

bdate = driver.find_element_by_name('BDate')
bdate.send_keys('1/1/1995')

type_button = driver.find_element_by_xpath('//*[@id="content"]/form[1]/table[3]/tbody/tr[2]/td[2]/table/tbody/tr[1]/td/input')
type_button.click()

get_report_button = driver.find_element_by_xpath('//*[@id="content"]/form[1]/table[3]/tbody/tr[3]/td[2]/input')
get_report_button.click()

time.sleep(1)

reports = driver.find_elements_by_xpath('//*[@id="content"]/table[5]/tbody/tr')
#print(reports)

violations = []

for report in reports[1:]:
    
    print('---------')

    data = {}
    
    if len(report.find_elements_by_class_name('drsviols')) != 0:
        print(report.find_element_by_class_name('drsviols').text)

#row = report.find_elements_by_class_name('drsviols')

        data['violator'] = report.find_elements_by_class_name('drsviols')[0].text
        print(report.find_elements_by_class_name('drsviols')[0].text)

        data['contract_id'] = report.find_elements_by_class_name('drsviols')[1].text
        print(report.find_elements_by_class_name('drsviols')[1].text)

        data['citation_no'] = report.find_elements_by_class_name('drsviols')[2].text
        print(report.find_elements_by_class_name('drsviols')[2].text)

        data['case_no'] = report.find_elements_by_class_name('drsviols')[3].text
        print(report.find_elements_by_class_name('drsviols')[3].text)

        data['date_issues'] = report.find_elements_by_class_name('drsviols')[4].text
        print(report.find_elements_by_class_name('drsviols')[4].text)

        data['final_order_date'] = report.find_elements_by_class_name('drsviols')[5].text
        print(report.find_elements_by_class_name('drsviols')[5].text)

        data['section_of_act'] = report.find_elements_by_class_name('drsviols')[6].text
        print(report.find_elements_by_class_name('drsviols')[6].text)

        data['date_terminated'] = report.find_elements_by_class_name('drsviols')[7].text
        print(report.find_elements_by_class_name('drsviols')[7].text)

        data['citation'] = report.find_elements_by_class_name('drsviols')[8].text
        print(report.find_elements_by_class_name('drsviols')[8].text)

        data['s_and_s'] = report.find_elements_by_class_name('drsviols')[9].text
        print(report.find_elements_by_class_name('drsviols')[9].text)

        data['standard'] = report.find_elements_by_class_name('drsviols')[10].text
        print(report.find_elements_by_class_name('drsviols')[10].text)

        data['standard_url'] = report.find_elements_by_class_name('drsviols')[10].find_element_by_tag_name('a').get_attribute('href')
        print(report.find_elements_by_class_name('drsviols')[10].find_element_by_tag_name('a').get_attribute('href'))

        data['proposed_penalty'] = report.find_elements_by_class_name('drsviols')[11].text
        print(report.find_elements_by_class_name('drsviols')[11].text)

        data['citation_status'] = report.find_elements_by_class_name('drsviols')[12].text
        print(report.find_elements_by_class_name('drsviols')[12].text)

        data['current_penalty'] = report.find_elements_by_class_name('drsviols')[13].text
        print(report.find_elements_by_class_name('drsviols')[13].text)

        data['amount_paid'] = report.find_elements_by_class_name('drsviols')[14].text
        print(report.find_elements_by_class_name('drsviols')[14].text)

        violations.append(data)

df = pd.DataFrame(violations)

df.to_csv("violations_data.csv", index=False)
# Out:
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8992368
# 000440809
# 5/2/2017
# 7/23/2017
# 104(a)
# 5/2/2017
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2017-title30-vol1/pdf/CFR-2017-title30-vol1-sec56-14107.pdf
# 116.00
# Closed
# 116.00
# 116.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8992214
# 000435717
# 2/7/2017
# 5/21/2017
# 104(a)
# 2/8/2017
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2017-title30-vol1/pdf/CFR-2017-title30-vol1-sec56-14107.pdf
# 116.00
# Closed
# 116.00
# 116.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8872461
# 000398910
# 10/21/2015
# 1/13/2016
# 104(a)
# 10/27/2015
# C
# N
# 56.12004
# http://www.gpo.gov/fdsys/pkg/CFR-2015-title30-vol1/pdf/CFR-2015-title30-vol1-sec56-12004.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8872462
# 000398910
# 10/21/2015
# 1/13/2016
# 104(a)
# 10/27/2015
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2015-title30-vol1/pdf/CFR-2015-title30-vol1-sec56-14107.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8790965
# 000383840
# 4/15/2015
# 7/17/2015
# 104(a)
# 4/15/2015
# C
# N
# 56.13015
# http://www.gpo.gov/fdsys/pkg/CFR-2015-title30-vol1/pdf/CFR-2015-title30-vol1-sec56-13015.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8790964
# 000383840
# 4/13/2015
# 7/17/2015
# 104(a)
# 4/15/2015
# C
# N
# 56.4101
# http://www.gpo.gov/fdsys/pkg/CFR-2015-title30-vol1/pdf/CFR-2015-title30-vol1-sec56-4101.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8790963
# 000383840
# 4/10/2015
# 7/17/2015
# 104(a)
# 4/13/2015
# C
# Y
# 56.15020
# http://www.gpo.gov/fdsys/pkg/CFR-2015-title30-vol1/pdf/CFR-2015-title30-vol1-sec56-15020.pdf
# 873.00
# Closed
# 873.00
# 873.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8790962
# 000383840
# 4/10/2015
# 7/17/2015
# 104(a)
# 4/10/2015
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2015-title30-vol1/pdf/CFR-2015-title30-vol1-sec56-14107.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8694457
# 000345066
# 1/29/2014
# 4/12/2014
# 104(a)
# 1/29/2014
# C
# N
# 56.12004
# http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-vol1/pdf/CFR-2014-title30-vol1-sec56-12004.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8694458
# 000345066
# 1/29/2014
# 4/12/2014
# 104(a)
# 1/29/2014
# C
# N
# 56.12018
# http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-vol1/pdf/CFR-2014-title30-vol1-sec56-12018.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8694453
# 000345066
# 1/28/2014
# 4/12/2014
# 104(a)
# 1/29/2014
# C
# N
# 56.4201(a)(1)
# http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-vol1/pdf/CFR-2014-title30-vol1-sec56-4201.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8694452
# 000345066
# 1/28/2014
# 4/12/2014
# 104(a)
# 1/29/2014
# C
# N
# 56.14132(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-vol1/pdf/CFR-2014-title30-vol1-sec56-14132.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8694451
# 000347758
# 1/28/2014
# 5/14/2014
# 104(a)
# 1/29/2014
# C
# N
# 56.14100(b)
# http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-vol1/pdf/CFR-2014-title30-vol1-sec56-14100.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8694455
# 000345066
# 1/28/2014
# 4/12/2014
# 104(a)
# 1/29/2014
# C
# N
# 56.12004
# http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-vol1/pdf/CFR-2014-title30-vol1-sec56-12004.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8694450
# 000345066
# 1/28/2014
# 4/12/2014
# 104(a)
# 1/29/2014
# C
# N
# 56.14132(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-vol1/pdf/CFR-2014-title30-vol1-sec56-14132.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8694456
# 000345066
# 1/28/2014
# 4/12/2014
# 104(a)
# 1/29/2014
# C
# N
# 56.14132(b)(1)
# http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-vol1/pdf/CFR-2014-title30-vol1-sec56-14132.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8694454
# 000345066
# 1/28/2014
# 4/12/2014
# 104(a)
# 1/29/2014
# C
# Y
# 56.12032
# http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-vol1/pdf/CFR-2014-title30-vol1-sec56-12032.pdf
# 243.00
# Closed
# 243.00
# 243.00
# ---------
# ---------
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8599787
# 000291331
# 5/1/2012
# 7/13/2012
# 104(a)
# 5/7/2012
# C
# N
# 56.14108
# http://www.gpo.gov/fdsys/pkg/CFR-2012-title30-vol1/pdf/CFR-2012-title30-vol1-sec56-14108.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8599788
# 000291331
# 5/1/2012
# 7/13/2012
# 104(a)
# 5/7/2012
# C
# N
# 56.12004
# http://www.gpo.gov/fdsys/pkg/CFR-2012-title30-vol1/pdf/CFR-2012-title30-vol1-sec56-12004.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8599789
# 000297041
# 5/1/2012
# 9/13/2012
# 104(a)
# 5/7/2012
# C
# Y
# 56.14101(a)(2)
# http://www.gpo.gov/fdsys/pkg/CFR-2012-title30-vol1/pdf/CFR-2012-title30-vol1-sec56-14101.pdf
# 243.00
# Closed
# 243.00
# 243.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8599107
# 000269626
# 9/7/2011
# 11/18/2011
# 104(a)
# 9/19/2011
# C
# N
# 50.30(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2011-title30-vol1/pdf/CFR-2011-title30-vol1-sec50-30.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8599025
# 000239613
# 10/7/2010
# 1/5/2011
# 104(a)
# 10/7/2010
# C
# N
# 56.12004
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec56-12004.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8599026
# 000239613
# 10/7/2010
# 1/5/2011
# 104(a)
# 10/7/2010
# C
# N
# 56.12004
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec56-12004.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6398905
# 000220925
# 4/20/2010
# 7/9/2010
# 104(a)
# 6/8/2010
# C
# Y
# 56.11001
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec56-11001.pdf
# 117.00
# Closed
# 117.00
# 117.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6338512
# 000210055
# 12/29/2009
# 1/10/2013
# 104(a)
# 12/29/2009
# C
# N
# 56.12004
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-12004.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6338511
# 000210055
# 12/29/2009
# 1/10/2013
# 104(a)
# 1/11/2010
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-14107.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6338507
# 000210055
# 12/29/2009
# 1/10/2013
# 104(a)
# 1/11/2010
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-14107.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6338509
# 000210055
# 12/29/2009
# 1/10/2013
# 104(a)
# 1/11/2010
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-14107.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6338510
# 000210055
# 12/29/2009
# 1/10/2013
# 104(a)
# 12/30/2009
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-14107.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6338508
# 000210055
# 12/29/2009
# 1/10/2013
# 104(a)
# 12/30/2009
# C
# N
# 56.11002
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-11002.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6479616
# 000180614
# 2/26/2009
# 5/22/2010
# 104(a)
# 3/4/2009
# C
# N
# 56.14103(b)
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-14103.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6479614
# 000180614
# 2/26/2009
# 5/22/2010
# 104(a)
# 3/4/2009
# C
# N
# 56.14100(d)
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-14100.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6479618
# 000180614
# 2/26/2009
# 5/22/2010
# 104(a)
# 3/4/2009
# C
# N
# 56.14130(i)
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-14130.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6479620
# 000180614
# 2/26/2009
# 5/8/2009
# 104(a)
# 3/4/2009
# C
# N
# 56.12028
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-12028.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6479615
# 000180614
# 2/26/2009
# 5/22/2010
# 104(a)
# 3/4/2009
# C
# N
# 56.14100(b)
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-14100.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6479617
# 000180614
# 2/26/2009
# 5/8/2009
# 104(a)
# 3/4/2009
# C
# N
# 56.4201(a)(2)
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-4201.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6479613
# 000180614
# 2/26/2009
# 5/22/2010
# 104(a)
# 2/26/2009
# C
# Y
# 56.3200
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-3200.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6479612
# 000180614
# 2/26/2009
# 5/22/2010
# 104(a)
# 3/4/2009
# C
# Y
# 56.9200(d)
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-9200.pdf
# 263.00
# Closed
# 263.00
# 263.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6479619
# 000180614
# 2/26/2009
# 5/22/2010
# 104(a)
# 2/26/2009
# C
# N
# 56.14100(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-14100.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6430325
# 000152001
# 4/2/2008
# 7/10/2008
# 104(a)
# 4/3/2008
# C
# N
# 56.14112(a)(1)
# http://www.gpo.gov/fdsys/pkg/CFR-2008-title30-vol1/pdf/CFR-2008-title30-vol1-sec56-14112.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6430326
# 000152001
# 4/2/2008
# 7/10/2008
# 104(a)
# 4/3/2008
# C
# N
# 56.14100(b)
# http://www.gpo.gov/fdsys/pkg/CFR-2008-title30-vol1/pdf/CFR-2008-title30-vol1-sec56-14100.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6342893
# 000121048
# 5/23/2007
# 8/17/2007
# 104(a)
# 5/24/2007
# C
# N
# 56.14100(b)
# http://www.gpo.gov/fdsys/pkg/CFR-2007-title30-vol1/pdf/CFR-2007-title30-vol1-sec56-14100.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6342895
# 000121048
# 5/23/2007
# 8/17/2007
# 104(a)
# 5/24/2007
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2007-title30-vol1/pdf/CFR-2007-title30-vol1-sec56-14107.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6342894
# 000121048
# 5/23/2007
# 8/17/2007
# 104(a)
# 5/24/2007
# C
# N
# 56.14132(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2007-title30-vol1/pdf/CFR-2007-title30-vol1-sec56-14132.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6342892
# 000121048
# 5/23/2007
# 8/17/2007
# 104(a)
# 5/24/2007
# C
# N
# 56.14100(b)
# http://www.gpo.gov/fdsys/pkg/CFR-2007-title30-vol1/pdf/CFR-2007-title30-vol1-sec56-14100.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6383437
# 000086543
# 3/1/2006
# 6/16/2006
# 104(a)
# 3/2/2006
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2006-title30-vol1/pdf/CFR-2006-title30-vol1-sec56-14107.pdf
# 60.00
# Closed
# 60.00
# 60.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6383438
# 000086543
# 3/1/2006
# 6/16/2006
# 104(a)
# 3/2/2006
# C
# N
# 56.11002
# http://www.gpo.gov/fdsys/pkg/CFR-2006-title30-vol1/pdf/CFR-2006-title30-vol1-sec56-11002.pdf
# 60.00
# Closed
# 60.00
# 60.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6368407
# 000051247
# 10/27/2004
# 7/23/2005
# 104(a)
# 1/21/2005
# C
# N
# 62.120
# http://www.gpo.gov/fdsys/pkg/CFR-2004-title30-vol1/pdf/CFR-2004-title30-vol1-sec62-120.pdf
# 60.00
# Closed
# 60.00
# 60.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6368406
# 000044260
# 10/25/2004
# 1/12/2005
# 104(a)
# 10/27/2004
# C
# Y
# 56.14131(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2004-title30-vol1/pdf/CFR-2004-title30-vol1-sec56-14131.pdf
# 99.00
# Closed
# 99.00
# 99.00

# %% [markdown]
# # Using .apply to find data about SEVERAL mines
#
# The file `mines-subset.csv` has a list of mine IDs. We're going to scrape the operator's name for each of those mines.
#
# ### Open up `mines-subset.csv` and save it into a dataframe

# %%
mines_df = pd.read_csv('mines-subset.csv')
mines_df.head()
# Out:
#         id
# 0  4104757
# 1   801306
# 2  3609931

# %%
mines_df.dtypes
# Out:
# id    int64
# dtype: object

# %% [markdown]
# ### Open up `mines-subset.csv` in a text editor, then look at your dataframe. Is something different about them? If so, make them match.
#
# - *TIP: You can zero fill if you want, but another option is that when reading in a CSV, `dtype='str'` will force everything to be a string*

# %%
mines_df = pd.read_csv('mines-subset.csv', dtype={'id': str})
mines_df.head()
# Out:
#         id
# 0  4104757
# 1  0801306
# 2  3609931

# %%
mines_df.dtypes
# Out:
# id    object
# dtype: object

# %% [markdown]
# ### Convert your one-cell scraper into a function, and use it on each row of our dataset
#
# - *TIP: You'll be using `.apply`*
# - *TIP: You won't be joining this back into your dataframe, so you don't need to `return` anything or `join` or any of that.*
# - *TIP: Be careful of your **other variable names** - if you're calling the thing you're sending your function `row`, you can't use it anywhere else (like in your loop)*
# - *TIP: **BE CAREFUL WHAT YOU NAME YOUR DATAFRAMES.** If you name the citations dataframe `df` it can overwrite your mine ID `df`*
# - *TIP: You'll be saving a dataframe each time*
# - *TIP: Be sure you change everything that refers to the mine ID to refer to the current row's ID instead of `3503598`*
# - *TIP: BE SURE TO CHANGE EVERYTHING THAT REFERS TO THE MINE ID*
# - *TIP: EVERYTHING, EVERYTHING, EVERYTHING! Look at the end of your function! Maybe I'm overreacting, I don't know.*
# - *TIP: If you hit an error about list index out of range, see what line it's happening on and go look at the page. What's different about this page than the previous ones? (answer: the last three columns!) If you assign those columns later using `try`/`except` you should be able to get some data from those rows without throwing it all out. If you can't figure it out, just wrap it all in try/except and give up on those rows*
# - *TIP: Some of the standards might not have links, either, so you might want to wrap that in a `try`/`except`, too!*

# %%
def get_violations(row):

    driver.get("https://arlweb.msha.gov/drs/drshome.htm")

    search_field = driver.find_element_by_name('MineId')
    driver.execute_script("arguments[0].scrollIntoView(true)", search_field)
    search_field.send_keys(row['id'])
    driver.find_element_by_xpath('//*[@id="content"]/table[3]/tbody/tr[3]/td[2]/input').click()

    time.sleep(1)

    bdate = driver.find_element_by_name('BDate')
    bdate.send_keys('1/1/1995')

    type_button = driver.find_element_by_xpath('//*[@id="content"]/form[1]/table[3]/tbody/tr[2]/td[2]/table/tbody/tr[1]/td/input')
    type_button.click()

    get_report_button = driver.find_element_by_xpath('//*[@id="content"]/form[1]/table[3]/tbody/tr[3]/td[2]/input')
    get_report_button.click()

    time.sleep(1)

    reports = driver.find_elements_by_xpath('//*[@id="content"]/table[5]/tbody/tr')
    #print(reports)

    violations = []

    for report in reports[1:]:

        print('---------')

        data = {}

        if len(report.find_elements_by_class_name('drsviols')) != 0:
            print(report.find_element_by_class_name('drsviols').text)

    #row = report.find_elements_by_class_name('drsviols')

            data['violator'] = report.find_elements_by_class_name('drsviols')[0].text
            print(report.find_elements_by_class_name('drsviols')[0].text)

            data['contract_id'] = report.find_elements_by_class_name('drsviols')[1].text
            print(report.find_elements_by_class_name('drsviols')[1].text)

            data['citation_no'] = report.find_elements_by_class_name('drsviols')[2].text
            print(report.find_elements_by_class_name('drsviols')[2].text)

            data['case_no'] = report.find_elements_by_class_name('drsviols')[3].text
            print(report.find_elements_by_class_name('drsviols')[3].text)

            data['date_issues'] = report.find_elements_by_class_name('drsviols')[4].text
            print(report.find_elements_by_class_name('drsviols')[4].text)

            data['final_order_date'] = report.find_elements_by_class_name('drsviols')[5].text
            print(report.find_elements_by_class_name('drsviols')[5].text)

            data['section_of_act'] = report.find_elements_by_class_name('drsviols')[6].text
            print(report.find_elements_by_class_name('drsviols')[6].text)

            data['date_terminated'] = report.find_elements_by_class_name('drsviols')[7].text
            print(report.find_elements_by_class_name('drsviols')[7].text)

            data['citation'] = report.find_elements_by_class_name('drsviols')[8].text
            print(report.find_elements_by_class_name('drsviols')[8].text)

            data['s_and_s'] = report.find_elements_by_class_name('drsviols')[9].text
            print(report.find_elements_by_class_name('drsviols')[9].text)
            
            try:
                data['standard'] = report.find_elements_by_class_name('drsviols')[10].text
                print(report.find_elements_by_class_name('drsviols')[10].text)

                data['standard_url'] = report.find_elements_by_class_name('drsviols')[10].find_element_by_tag_name('a').get_attribute('href')
                print(report.find_elements_by_class_name('drsviols')[10].find_element_by_tag_name('a').get_attribute('href'))
                
            except:
                print('Missing url')

            data['proposed_penalty'] = report.find_elements_by_class_name('drsviols')[11].text
            print(report.find_elements_by_class_name('drsviols')[11].text)

            data['citation_status'] = report.find_elements_by_class_name('drsviols')[12].text
            print(report.find_elements_by_class_name('drsviols')[12].text)

            data['current_penalty'] = report.find_elements_by_class_name('drsviols')[13].text
            print(report.find_elements_by_class_name('drsviols')[13].text)

            data['amount_paid'] = report.find_elements_by_class_name('drsviols')[14].text
            print(report.find_elements_by_class_name('drsviols')[14].text)

            violations.append(data)

    new_df = pd.DataFrame(violations)

    new_df.to_csv(row['id']+"_violations_data.csv", index=False)

# %%
mines_df.apply(get_violations, axis=1)
# Out:
# ---------
# Dirt Works
# Dirt Works
#
# 8778046
# 000374480
# 10/14/2014
# 3/27/2015
# 104(a)
# 10/14/2014
# C
# N
# 56.14132(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-vol1/pdf/CFR-2014-title30-vol1-sec56-14132.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Dirt Works
# Dirt Works
#
# 8778047
# 000374480
# 10/14/2014
# 3/27/2015
# 104(a)
# 11/4/2014
# C
# N
# 56.18010
# http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-vol1/pdf/CFR-2014-title30-vol1-sec56-18010.pdf
# 162.00
# Closed
# 162.00
# 162.00
# ---------
# Dirt Works
# Dirt Works
#
# 8771783
# 000345454
# 1/22/2014
# 4/20/2014
# 104(a)
# 1/22/2014
# C
# Y
# 56.9300(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-vol1/pdf/CFR-2014-title30-vol1-sec56-9300.pdf
# 243.00
# Closed
# 243.00
# 243.00
# ---------
# Dirt Works
# Dirt Works
#
# 8771781
# 000348280
# 1/22/2014
# 5/21/2014
# 104(a)
# 1/22/2014
# C
# N
# 56.14100(b)
# http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-vol1/pdf/CFR-2014-title30-vol1-sec56-14100.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Dirt Works
# Dirt Works
#
# 8771784
# 000345454
# 1/22/2014
# 4/20/2014
# 104(a)
# 1/22/2014
# C
# N
# 50.30(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-vol1/pdf/CFR-2014-title30-vol1-sec50-30.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Dirt Works
# Dirt Works
#
# 8771782
# 000345454
# 1/22/2014
# 4/20/2014
# 104(a)
# 1/22/2014
# C
# Y
# 56.9300(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-vol1/pdf/CFR-2014-title30-vol1-sec56-9300.pdf
# 243.00
# Closed
# 243.00
# 243.00
# ---------
# Dirt Works
# Dirt Works
#
# 8688404
# 000316329
# 1/29/2013
# 4/19/2013
# 104(a)
# 1/29/2013
# C
# N
# 50.30(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2013-title30-vol1/pdf/CFR-2013-title30-vol1-sec50-30.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Dirt Works
# Dirt Works
#
# 8681995
# 000316329
# 1/28/2013
# 4/19/2013
# 104(a)
# 2/1/2013
# C
# N
# 56.14132(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2013-title30-vol1/pdf/CFR-2013-title30-vol1-sec56-14132.pdf
# 162.00
# Closed
# 162.00
# 162.00
# ---------
# Dirt Works
# Dirt Works
#
# 8681996
# 000316329
# 1/28/2013
# 4/19/2013
# 104(a)
# 2/1/2013
# C
# N
# 56.12028
# http://www.gpo.gov/fdsys/pkg/CFR-2013-title30-vol1/pdf/CFR-2013-title30-vol1-sec56-12028.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Dirt Works
# Dirt Works
#
# 8681997
# 000316329
# 1/28/2013
# 4/19/2013
# 104(a)
# 2/1/2013
# C
# N
# 47.31(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2013-title30-vol1/pdf/CFR-2013-title30-vol1-sec47-31.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Dirt Works
# Dirt Works
#
# 8681998
# 000316329
# 1/28/2013
# 4/19/2013
# 104(a)
# 2/1/2013
# C
# Y
# 56.9300(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2013-title30-vol1/pdf/CFR-2013-title30-vol1-sec56-9300.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Dirt Works
# Dirt Works
#
# 6315027
# 000303884
# 8/23/2012
# 11/22/2012
# 104(g)(1)
# 9/10/2012
# O
# N
# 46.8(a)(2)
# http://www.gpo.gov/fdsys/pkg/CFR-2012-title30-vol1/pdf/CFR-2012-title30-vol1-sec46-8.pdf
# 112.00
# Closed
# 112.00
# 112.00
# ---------
# Dirt Works
# Dirt Works
#
# 6576571
# 000246930
# 12/13/2010
# 3/23/2011
# 104(a)
# 12/13/2010
# C
# N
# 56.9300(b)
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec56-9300.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Dirt Works
# Dirt Works
#
# 6576574
# 000246930
# 12/13/2010
# 3/23/2011
# 104(a)
# 1/3/2011
# C
# Y
# 56.15001
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec56-15001.pdf
# 243.00
# Closed
# 243.00
# 243.00
# ---------
# Dirt Works
# Dirt Works
#
# 6576573
# 000246930
# 12/13/2010
# 3/23/2011
# 104(a)
# 1/3/2011
# C
# N
# 56.20002(b)
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec56-20002.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Dirt Works
# Dirt Works
#
# 6576572
# 000246930
# 12/13/2010
# 3/23/2011
# 104(a)
# 1/3/2011
# C
# N
# 56.18013
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec56-18013.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Dirt Works
# Dirt Works
#
# 6466145
# 000206354
# 11/3/2009
# 1/20/2010
# 104(a)
# 11/3/2009
# C
# N
# 41.12
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec41-12.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Dirt Works
# Dirt Works
#
# 6466144
# 000206354
# 11/3/2009
# 1/20/2010
# 104(a)
# 11/3/2009
# C
# Y
# 56.9300(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-9300.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Holley Dirt Company, Inc
# Holley Dirt Company, Inc
#
# 9421625
#
# 5/15/2018
# 104(a)
# 5/15/2018
# C
# Y
# 56.20003(a)
# Not Assessed Yet
# Missing url
# ---------
# Dirt Works
# Dirt Works
#
# 8778047
# 000374480
# 10/14/2014
# 3/27/2015
# 104(a)
# 11/4/2014
# C
# N
# 56.18010
# http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-vol1/pdf/CFR-2014-title30-vol1-sec56-18010.pdf
# 162.00
# Closed
# 162.00
# 162.00
# ---------
# Dirt Works
# Dirt Works
#
# 8778046
# 000374480
# 10/14/2014
# 3/27/2015
# 104(a)
# 10/14/2014
# C
# N
# 56.14132(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-vol1/pdf/CFR-2014-title30-vol1-sec56-14132.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Dirt Works
# Dirt Works
#
# 8771783
# 000345454
# 1/22/2014
# 4/20/2014
# 104(a)
# 1/22/2014
# C
# Y
# 56.9300(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-vol1/pdf/CFR-2014-title30-vol1-sec56-9300.pdf
# 243.00
# Closed
# 243.00
# 243.00
# ---------
# Dirt Works
# Dirt Works
#
# 8771784
# 000345454
# 1/22/2014
# 4/20/2014
# 104(a)
# 1/22/2014
# C
# N
# 50.30(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-vol1/pdf/CFR-2014-title30-vol1-sec50-30.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Dirt Works
# Dirt Works
#
# 8771782
# 000345454
# 1/22/2014
# 4/20/2014
# 104(a)
# 1/22/2014
# C
# Y
# 56.9300(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-vol1/pdf/CFR-2014-title30-vol1-sec56-9300.pdf
# 243.00
# Closed
# 243.00
# 243.00
# ---------
# Dirt Works
# Dirt Works
#
# 8771781
# 000348280
# 1/22/2014
# 5/21/2014
# 104(a)
# 1/22/2014
# C
# N
# 56.14100(b)
# http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-vol1/pdf/CFR-2014-title30-vol1-sec56-14100.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Dirt Works
# Dirt Works
#
# 8688404
# 000316329
# 1/29/2013
# 4/19/2013
# 104(a)
# 1/29/2013
# C
# N
# 50.30(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2013-title30-vol1/pdf/CFR-2013-title30-vol1-sec50-30.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Dirt Works
# Dirt Works
#
# 8681998
# 000316329
# 1/28/2013
# 4/19/2013
# 104(a)
# 2/1/2013
# C
# Y
# 56.9300(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2013-title30-vol1/pdf/CFR-2013-title30-vol1-sec56-9300.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Dirt Works
# Dirt Works
#
# 8681996
# 000316329
# 1/28/2013
# 4/19/2013
# 104(a)
# 2/1/2013
# C
# N
# 56.12028
# http://www.gpo.gov/fdsys/pkg/CFR-2013-title30-vol1/pdf/CFR-2013-title30-vol1-sec56-12028.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Dirt Works
# Dirt Works
#
# 8681997
# 000316329
# 1/28/2013
# 4/19/2013
# 104(a)
# 2/1/2013
# C
# N
# 47.31(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2013-title30-vol1/pdf/CFR-2013-title30-vol1-sec47-31.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Dirt Works
# Dirt Works
#
# 8681995
# 000316329
# 1/28/2013
# 4/19/2013
# 104(a)
# 2/1/2013
# C
# N
# 56.14132(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2013-title30-vol1/pdf/CFR-2013-title30-vol1-sec56-14132.pdf
# 162.00
# Closed
# 162.00
# 162.00
# ---------
# Dirt Works
# Dirt Works
#
# 6315027
# 000303884
# 8/23/2012
# 11/22/2012
# 104(g)(1)
# 9/10/2012
# O
# N
# 46.8(a)(2)
# http://www.gpo.gov/fdsys/pkg/CFR-2012-title30-vol1/pdf/CFR-2012-title30-vol1-sec46-8.pdf
# 112.00
# Closed
# 112.00
# 112.00
# ---------
# Dirt Works
# Dirt Works
#
# 6576572
# 000246930
# 12/13/2010
# 3/23/2011
# 104(a)
# 1/3/2011
# C
# N
# 56.18013
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec56-18013.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Dirt Works
# Dirt Works
#
# 6576573
# 000246930
# 12/13/2010
# 3/23/2011
# 104(a)
# 1/3/2011
# C
# N
# 56.20002(b)
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec56-20002.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Dirt Works
# Dirt Works
#
# 6576574
# 000246930
# 12/13/2010
# 3/23/2011
# 104(a)
# 1/3/2011
# C
# Y
# 56.15001
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec56-15001.pdf
# 243.00
# Closed
# 243.00
# 243.00
# ---------
# Dirt Works
# Dirt Works
#
# 6576571
# 000246930
# 12/13/2010
# 3/23/2011
# 104(a)
# 12/13/2010
# C
# N
# 56.9300(b)
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec56-9300.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Dirt Works
# Dirt Works
#
# 6466145
# 000206354
# 11/3/2009
# 1/20/2010
# 104(a)
# 11/3/2009
# C
# N
# 41.12
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec41-12.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Dirt Works
# Dirt Works
# 6466144
# 000206354
# 11/3/2009
# 1/20/2010
# 104(a)
# 11/3/2009
# C
# Y
# 56.9300(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-9300.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Holley Dirt Company, Inc
# Holley Dirt Company, Inc
#
# 9421625
#
# 5/15/2018
# 104(a)
# 5/15/2018
# C
# Y
# 56.20003(a)
# Not Assessed Yet
# Missing url
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-18-d9ca85606d2d> in <module>()
# ----> 1 mines_df.apply(get_violations, axis=1)
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6002                          args=args,
#    6003                          kwds=kwds)
# -> 6004         return op.get_result()
#    6005
#    6006     def applymap(self, func):
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\pandas\core\apply.py in get_result(self)
#     140             return self.apply_raw()
#     141
# --> 142         return self.apply_standard()
#     143
#     144     def apply_empty_result(self):
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     246
#     247         # compute the result using the series generator
# --> 248         self.apply_series_generator()
#     249
#     250         # wrap results
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     275             try:
#     276                 for i, v in enumerate(series_gen):
# --> 277                     results[i] = self.f(v)
#     278                     keys.append(v.name)
#     279             except Exception as e:
#
# <ipython-input-17-30736609cdeb> in get_violations(row)
#      77                 print('Missing url')
#      78
# ---> 79             data['proposed_penalty'] = report.find_elements_by_class_name('drsviols')[11].text
#      80             print(report.find_elements_by_class_name('drsviols')[11].text)
#      81
#
# IndexError: ('list index out of range', 'occurred at index 1')

# %% [markdown]
# # Okay, now do it for ALL of the mines
#
# Open up `mines.csv` using pandas and do the same thing, it will just be for more mines this time.

# %%
pd.read_csv('mines.csv')
# Out:
#          id
# 0   3503598
# 1   4801789
# 2   5001797
# 3   4608254
# 4   2103723
# 5   4104757
# 6    801306
# 7   3901432
# 8   3609624
# 9   3609931
# 10  1519799
# 11  4407296
# 12  4407270
# 13   203332
# 14  2901986
# 15  4300768
# 16  4300776
# 17  2302283
# 18  2103518

# %%
all_df = pd.read_csv('mines.csv')
all_df.head()
# Out:
#         id
# 0  3503598
# 1  4801789
# 2  5001797
# 3  4608254
# 4  2103723

# %%
all_df.dtypes
# Out:
# id    int64
# dtype: object

# %%
all_df = pd.read_csv('mines.csv', dtype={'id': str})
all_df.head()
# Out:
#         id
# 0  3503598
# 1  4801789
# 2  5001797
# 3  4608254
# 4  2103723

# %%
all_df.dtypes
# Out:
# id    object
# dtype: object

# %%
#all_df.apply(get_moreviolations, axis=1)

# %%
all_df = pd.read_csv('mines.csv', dtype={'id': str})
all_df
# Out:
#          id
# 0   3503598
# 1   4801789
# 2   5001797
# 3   4608254
# 4   2103723
# 5   4104757
# 6   0801306
# 7   3901432
# 8   3609624
# 9   3609931
# 10  1519799
# 11  4407296
# 12  4407270
# 13  0203332
# 14  2901986
# 15  4300768
# 16  4300776
# 17  2302283
# 18  2103518

# %%
all_df.apply(get_violations, axis=1)
# Out:
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8992368
# 000440809
# 5/2/2017
# 7/23/2017
# 104(a)
# 5/2/2017
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2017-title30-vol1/pdf/CFR-2017-title30-vol1-sec56-14107.pdf
# 116.00
# Closed
# 116.00
# 116.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8992214
# 000435717
# 2/7/2017
# 5/21/2017
# 104(a)
# 2/8/2017
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2017-title30-vol1/pdf/CFR-2017-title30-vol1-sec56-14107.pdf
# 116.00
# Closed
# 116.00
# 116.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8872461
# 000398910
# 10/21/2015
# 1/13/2016
# 104(a)
# 10/27/2015
# C
# N
# 56.12004
# http://www.gpo.gov/fdsys/pkg/CFR-2015-title30-vol1/pdf/CFR-2015-title30-vol1-sec56-12004.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8872462
# 000398910
# 10/21/2015
# 1/13/2016
# 104(a)
# 10/27/2015
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2015-title30-vol1/pdf/CFR-2015-title30-vol1-sec56-14107.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8790965
# 000383840
# 4/15/2015
# 7/17/2015
# 104(a)
# 4/15/2015
# C
# N
# 56.13015
# http://www.gpo.gov/fdsys/pkg/CFR-2015-title30-vol1/pdf/CFR-2015-title30-vol1-sec56-13015.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8790964
# 000383840
# 4/13/2015
# 7/17/2015
# 104(a)
# 4/15/2015
# C
# N
# 56.4101
# http://www.gpo.gov/fdsys/pkg/CFR-2015-title30-vol1/pdf/CFR-2015-title30-vol1-sec56-4101.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8790962
# 000383840
# 4/10/2015
# 7/17/2015
# 104(a)
# 4/10/2015
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2015-title30-vol1/pdf/CFR-2015-title30-vol1-sec56-14107.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8790963
# 000383840
# 4/10/2015
# 7/17/2015
# 104(a)
# 4/13/2015
# C
# Y
# 56.15020
# http://www.gpo.gov/fdsys/pkg/CFR-2015-title30-vol1/pdf/CFR-2015-title30-vol1-sec56-15020.pdf
# 873.00
# Closed
# 873.00
# 873.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8694458
# 000345066
# 1/29/2014
# 4/12/2014
# 104(a)
# 1/29/2014
# C
# N
# 56.12018
# http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-vol1/pdf/CFR-2014-title30-vol1-sec56-12018.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8694457
# 000345066
# 1/29/2014
# 4/12/2014
# 104(a)
# 1/29/2014
# C
# N
# 56.12004
# http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-vol1/pdf/CFR-2014-title30-vol1-sec56-12004.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8694455
# 000345066
# 1/28/2014
# 4/12/2014
# 104(a)
# 1/29/2014
# C
# N
# 56.12004
# http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-vol1/pdf/CFR-2014-title30-vol1-sec56-12004.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8694456
# 000345066
# 1/28/2014
# 4/12/2014
# 104(a)
# 1/29/2014
# C
# N
# 56.14132(b)(1)
# http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-vol1/pdf/CFR-2014-title30-vol1-sec56-14132.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8694452
# 000345066
# 1/28/2014
# 4/12/2014
# 104(a)
# 1/29/2014
# C
# N
# 56.14132(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-vol1/pdf/CFR-2014-title30-vol1-sec56-14132.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8694453
# 000345066
# 1/28/2014
# 4/12/2014
# 104(a)
# 1/29/2014
# C
# N
# 56.4201(a)(1)
# http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-vol1/pdf/CFR-2014-title30-vol1-sec56-4201.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8694451
# 000347758
# 1/28/2014
# 5/14/2014
# 104(a)
# 1/29/2014
# C
# N
# 56.14100(b)
# http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-vol1/pdf/CFR-2014-title30-vol1-sec56-14100.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8694450
# 000345066
# 1/28/2014
# 4/12/2014
# 104(a)
# 1/29/2014
# C
# N
# 56.14132(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-vol1/pdf/CFR-2014-title30-vol1-sec56-14132.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8694454
# 000345066
# 1/28/2014
# 4/12/2014
# 104(a)
# 1/29/2014
# C
# Y
# 56.12032
# http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-vol1/pdf/CFR-2014-title30-vol1-sec56-12032.pdf
# 243.00
# Closed
# 243.00
# 243.00
# ---------
# ---------
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8599788
# 000291331
# 5/1/2012
# 7/13/2012
# 104(a)
# 5/7/2012
# C
# N
# 56.12004
# http://www.gpo.gov/fdsys/pkg/CFR-2012-title30-vol1/pdf/CFR-2012-title30-vol1-sec56-12004.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8599787
# 000291331
# 5/1/2012
# 7/13/2012
# 104(a)
# 5/7/2012
# C
# N
# 56.14108
# http://www.gpo.gov/fdsys/pkg/CFR-2012-title30-vol1/pdf/CFR-2012-title30-vol1-sec56-14108.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8599789
# 000297041
# 5/1/2012
# 9/13/2012
# 104(a)
# 5/7/2012
# C
# Y
# 56.14101(a)(2)
# http://www.gpo.gov/fdsys/pkg/CFR-2012-title30-vol1/pdf/CFR-2012-title30-vol1-sec56-14101.pdf
# 243.00
# Closed
# 243.00
# 243.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8599107
# 000269626
# 9/7/2011
# 11/18/2011
# 104(a)
# 9/19/2011
# C
# N
# 50.30(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2011-title30-vol1/pdf/CFR-2011-title30-vol1-sec50-30.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8599025
# 000239613
# 10/7/2010
# 1/5/2011
# 104(a)
# 10/7/2010
# C
# N
# 56.12004
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec56-12004.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8599026
# 000239613
# 10/7/2010
# 1/5/2011
# 104(a)
# 10/7/2010
# C
# N
# 56.12004
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec56-12004.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6398905
# 000220925
# 4/20/2010
# 7/9/2010
# 104(a)
# 6/8/2010
# C
# Y
# 56.11001
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec56-11001.pdf
# 117.00
# Closed
# 117.00
# 117.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6338512
# 000210055
# 12/29/2009
# 1/10/2013
# 104(a)
# 12/29/2009
# C
# N
# 56.12004
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-12004.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6338511
# 000210055
# 12/29/2009
# 1/10/2013
# 104(a)
# 1/11/2010
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-14107.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6338508
# 000210055
# 12/29/2009
# 1/10/2013
# 104(a)
# 12/30/2009
# C
# N
# 56.11002
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-11002.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6338510
# 000210055
# 12/29/2009
# 1/10/2013
# 104(a)
# 12/30/2009
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-14107.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6338509
# 000210055
# 12/29/2009
# 1/10/2013
# 104(a)
# 1/11/2010
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-14107.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6338507
# 000210055
# 12/29/2009
# 1/10/2013
# 104(a)
# 1/11/2010
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-14107.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6479615
# 000180614
# 2/26/2009
# 5/22/2010
# 104(a)
# 3/4/2009
# C
# N
# 56.14100(b)
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-14100.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6479618
# 000180614
# 2/26/2009
# 5/22/2010
# 104(a)
# 3/4/2009
# C
# N
# 56.14130(i)
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-14130.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6479614
# 000180614
# 2/26/2009
# 5/22/2010
# 104(a)
# 3/4/2009
# C
# N
# 56.14100(d)
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-14100.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6479620
# 000180614
# 2/26/2009
# 5/8/2009
# 104(a)
# 3/4/2009
# C
# N
# 56.12028
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-12028.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6479613
# 000180614
# 2/26/2009
# 5/22/2010
# 104(a)
# 2/26/2009
# C
# Y
# 56.3200
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-3200.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6479612
# 000180614
# 2/26/2009
# 5/22/2010
# 104(a)
# 3/4/2009
# C
# Y
# 56.9200(d)
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-9200.pdf
# 263.00
# Closed
# 263.00
# 263.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6479617
# 000180614
# 2/26/2009
# 5/8/2009
# 104(a)
# 3/4/2009
# C
# N
# 56.4201(a)(2)
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-4201.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6479616
# 000180614
# 2/26/2009
# 5/22/2010
# 104(a)
# 3/4/2009
# C
# N
# 56.14103(b)
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-14103.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6479619
# 000180614
# 2/26/2009
# 5/22/2010
# 104(a)
# 2/26/2009
# C
# N
# 56.14100(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-14100.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6430326
# 000152001
# 4/2/2008
# 7/10/2008
# 104(a)
# 4/3/2008
# C
# N
# 56.14100(b)
# http://www.gpo.gov/fdsys/pkg/CFR-2008-title30-vol1/pdf/CFR-2008-title30-vol1-sec56-14100.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6430325
# 000152001
# 4/2/2008
# 7/10/2008
# 104(a)
# 4/3/2008
# C
# N
# 56.14112(a)(1)
# http://www.gpo.gov/fdsys/pkg/CFR-2008-title30-vol1/pdf/CFR-2008-title30-vol1-sec56-14112.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6342892
# 000121048
# 5/23/2007
# 8/17/2007
# 104(a)
# 5/24/2007
# C
# N
# 56.14100(b)
# http://www.gpo.gov/fdsys/pkg/CFR-2007-title30-vol1/pdf/CFR-2007-title30-vol1-sec56-14100.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6342893
# 000121048
# 5/23/2007
# 8/17/2007
# 104(a)
# 5/24/2007
# C
# N
# 56.14100(b)
# http://www.gpo.gov/fdsys/pkg/CFR-2007-title30-vol1/pdf/CFR-2007-title30-vol1-sec56-14100.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6342894
# 000121048
# 5/23/2007
# 8/17/2007
# 104(a)
# 5/24/2007
# C
# N
# 56.14132(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2007-title30-vol1/pdf/CFR-2007-title30-vol1-sec56-14132.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6342895
# 000121048
# 5/23/2007
# 8/17/2007
# 104(a)
# 5/24/2007
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2007-title30-vol1/pdf/CFR-2007-title30-vol1-sec56-14107.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6383438
# 000086543
# 3/1/2006
# 6/16/2006
# 104(a)
# 3/2/2006
# C
# N
# 56.11002
# http://www.gpo.gov/fdsys/pkg/CFR-2006-title30-vol1/pdf/CFR-2006-title30-vol1-sec56-11002.pdf
# 60.00
# Closed
# 60.00
# 60.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6383437
# 000086543
# 3/1/2006
# 6/16/2006
# 104(a)
# 3/2/2006
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2006-title30-vol1/pdf/CFR-2006-title30-vol1-sec56-14107.pdf
# 60.00
# Closed
# 60.00
# 60.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6368407
# 000051247
# 10/27/2004
# 7/23/2005
# 104(a)
# 1/21/2005
# C
# N
# 62.120
# http://www.gpo.gov/fdsys/pkg/CFR-2004-title30-vol1/pdf/CFR-2004-title30-vol1-sec62-120.pdf
# 60.00
# Closed
# 60.00
# 60.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6368406
# 000044260
# 10/25/2004
# 1/12/2005
# 104(a)
# 10/27/2004
# C
# Y
# 56.14131(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2004-title30-vol1/pdf/CFR-2004-title30-vol1-sec56-14131.pdf
# 99.00
# Closed
# 99.00
# 99.00
# ---------
# AM Dirtworks & Aggregate Sales
# AM Dirtworks & Aggregate Sales
#
# 8933510
# 000426827
# 11/1/2016
# 1/20/2017
# 104(a)
# 1/11/2017
# C
# N
# 56.1000
# http://www.gpo.gov/fdsys/pkg/CFR-2016-title30-vol1/pdf/CFR-2016-title30-vol1-sec56-1000.pdf
# 114.00
# Delinquent
# 114.00
# 0.00
# ---------
# AM Dirtworks & Aggregate Sales
# AM Dirtworks & Aggregate Sales
#
# 8753190
# 000407999
# 3/3/2016
# 6/24/2016
# 104(a)
# 3/3/2016
# C
# Y
# 56.14115(b)
# http://www.gpo.gov/fdsys/pkg/CFR-2016-title30-vol1/pdf/CFR-2016-title30-vol1-sec56-14115.pdf
# 108.00
# Closed
# 108.00
# 108.00
# ---------
# AM Dirtworks & Aggregate Sales
# AM Dirtworks & Aggregate Sales
#
# 8753189
# 000407999
# 3/3/2016
# 6/24/2016
# 104(a)
# 3/3/2016
# C
# N
# 46.9(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2016-title30-vol1/pdf/CFR-2016-title30-vol1-sec46-9.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# AM Dirtworks & Aggregate Sales
# AM Dirtworks & Aggregate Sales
#
# 8753188
# 000407999
# 3/2/2016
# 6/24/2016
# 104(a)
# 3/24/2016
# C
# Y
# 56.11001
# http://www.gpo.gov/fdsys/pkg/CFR-2016-title30-vol1/pdf/CFR-2016-title30-vol1-sec56-11001.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# AM Dirtworks & Aggregate Sales
# AM Dirtworks & Aggregate Sales
#
# 8753187
# 000407999
# 3/2/2016
# 6/24/2016
# 104(a)
# 3/2/2016
# C
# Y
# 56.9300(b)
# http://www.gpo.gov/fdsys/pkg/CFR-2016-title30-vol1/pdf/CFR-2016-title30-vol1-sec56-9300.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# AM Dirtworks & Aggregate Sales
# AM Dirtworks & Aggregate Sales
#
# 8825833
# 000376854
# 2/4/2015
# 5/19/2015
# 104(a)
# 2/10/2015
# C
# N
# 50.30(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2015-title30-vol1/pdf/CFR-2015-title30-vol1-sec50-30.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Dirt Company
# Dirt Company
#
# 8601716
# 000423303
# 10/1/2016
# 12/16/2016
# 104(a)
# 10/28/2016
# C
# N
# 56.14103(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2016-title30-vol1/pdf/CFR-2016-title30-vol1-sec56-14103.pdf
# 114.00
# Closed
# 114.00
# 114.00
# ---------
# Dirt Company
# Dirt Company
#
# 8601712
# 000423303
# 10/1/2016
# 12/16/2016
# 104(a)
# 10/28/2016
# C
# N
# 56.14112(a)(1)
# http://www.gpo.gov/fdsys/pkg/CFR-2016-title30-vol1/pdf/CFR-2016-title30-vol1-sec56-14112.pdf
# 114.00
# Closed
# 114.00
# 114.00
# ---------
# Dirt Company
# Dirt Company
#
# 8601715
# 000423303
# 10/1/2016
# 12/16/2016
# 104(a)
# 10/28/2016
# C
# N
# 56.14132(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2016-title30-vol1/pdf/CFR-2016-title30-vol1-sec56-14132.pdf
# 114.00
# Closed
# 114.00
# 114.00
# ---------
# Dirt Company
# Dirt Company
#
# 8601714
# 000423303
# 10/1/2016
# 12/16/2016
# 104(a)
# 10/28/2016
# C
# N
# 56.14132(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2016-title30-vol1/pdf/CFR-2016-title30-vol1-sec56-14132.pdf
# 114.00
# Closed
# 114.00
# 114.00
# ---------
# Dirt Company
# Dirt Company
#
# 8601713
# 000423303
# 10/1/2016
# 12/16/2016
# 104(a)
# 10/28/2016
# C
# N
# 56.9300(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2016-title30-vol1/pdf/CFR-2016-title30-vol1-sec56-9300.pdf
# 114.00
# Closed
# 114.00
# 114.00
# ---------
# Dirt Company
# Dirt Company
#
# 6356396
# 000416201
# 6/28/2016
# 9/16/2016
# 104(a)
# 6/28/2016
# C
# N
# 56.14132(b)(2)
# http://www.gpo.gov/fdsys/pkg/CFR-2016-title30-vol1/pdf/CFR-2016-title30-vol1-sec56-14132.pdf
# 114.00
# Closed
# 114.00
# 114.00
# ---------
# Dirt Company
# Dirt Company
#
# 6356395
# 000416201
# 6/28/2016
# 9/16/2016
# 104(a)
# 6/30/2016
# C
# N
# 56.14112(b)
# http://www.gpo.gov/fdsys/pkg/CFR-2016-title30-vol1/pdf/CFR-2016-title30-vol1-sec56-14112.pdf
# 114.00
# Closed
# 114.00
# 114.00
# ---------
# Dirt Company
# Dirt Company
#
# 8601414
# 000390299
# 7/2/2015
# 10/8/2015
# 104(a)
# 8/25/2015
# C
# Y
# 56.11002
# http://www.gpo.gov/fdsys/pkg/CFR-2015-title30-vol1/pdf/CFR-2015-title30-vol1-sec56-11002.pdf
# 108.00
# Closed
# 108.00
# 108.00
# ---------
# Dirt Company
# Dirt Company
#
# 8601395
# 000390299
# 7/2/2015
# 10/8/2015
# 104(a)
# 8/25/2015
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2015-title30-vol1/pdf/CFR-2015-title30-vol1-sec56-14107.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Dirt Company
# Dirt Company
#
# 8601400
# 000390299
# 7/2/2015
# 10/8/2015
# 104(a)
# 8/25/2015
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2015-title30-vol1/pdf/CFR-2015-title30-vol1-sec56-14107.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Dirt Company
# Dirt Company
#
# 8601413
# 000390299
# 7/2/2015
# 10/8/2015
# 104(a)
# 8/25/2015
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2015-title30-vol1/pdf/CFR-2015-title30-vol1-sec56-14107.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Dirt Company
# Dirt Company
# 8601402
# 000357404
# 6/17/2014
# 9/3/2014
# 104(a)
# 6/17/2014
# C
# N
# 56.4201(a)(1)
# http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-vol1/pdf/CFR-2014-title30-vol1-sec56-4201.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Dirt Company
# Dirt Company
#
# 8601222
# 000293537
# 5/31/2012
# 8/9/2012
# 104(a)
# 5/31/2012
# C
# Y
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2012-title30-vol1/pdf/CFR-2012-title30-vol1-sec56-14107.pdf
# 108.00
# Closed
# 108.00
# 108.00
# ---------
# Dirt Company
# Dirt Company
#
# 8601223
# 000293537
# 5/31/2012
# 8/9/2012
# 104(a)
# 5/31/2012
# C
# Y
# 56.14100(d)
# http://www.gpo.gov/fdsys/pkg/CFR-2012-title30-vol1/pdf/CFR-2012-title30-vol1-sec56-14100.pdf
# 243.00
# Closed
# 243.00
# 243.00
# ---------
# Dirt Company
# Dirt Company
#
# 8601224
# 000293537
# 5/31/2012
# 8/9/2012
# 104(a)
# 5/31/2012
# C
# N
# 56.4201(a)(1)
# http://www.gpo.gov/fdsys/pkg/CFR-2012-title30-vol1/pdf/CFR-2012-title30-vol1-sec56-4201.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Dirt Company
# Dirt Company
#
# 8601228
# 000293537
# 5/31/2012
# 8/9/2012
# 104(a)
# 5/31/2012
# C
# Y
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2012-title30-vol1/pdf/CFR-2012-title30-vol1-sec56-14107.pdf
# 807.00
# Closed
# 807.00
# 807.00
# ---------
# Dirt Company
# Dirt Company
#
# 8601226
# 000293537
# 5/31/2012
# 8/9/2012
# 104(a)
# 5/31/2012
# C
# Y
# 56.11002
# http://www.gpo.gov/fdsys/pkg/CFR-2012-title30-vol1/pdf/CFR-2012-title30-vol1-sec56-11002.pdf
# 108.00
# Closed
# 108.00
# 108.00
# ---------
# Dirt Company
# Dirt Company
#
# 8601225
# 000293537
# 5/31/2012
# 8/9/2012
# 104(a)
# 5/31/2012
# C
# Y
# 56.15001
# http://www.gpo.gov/fdsys/pkg/CFR-2012-title30-vol1/pdf/CFR-2012-title30-vol1-sec56-15001.pdf
# 108.00
# Closed
# 108.00
# 108.00
# ---------
# Dirt Company
# Dirt Company
#
# 8601038
# 000270890
# 9/8/2011
# 12/7/2011
# 104(a)
# 9/8/2011
# C
# N
# 50.30(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2011-title30-vol1/pdf/CFR-2011-title30-vol1-sec50-30.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Dirt Company
# Dirt Company
#
# 8601037
# 000270890
# 9/8/2011
# 12/7/2011
# 104(a)
# 9/8/2011
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2011-title30-vol1/pdf/CFR-2011-title30-vol1-sec56-14107.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Dirt Company
# Dirt Company
#
# 6478924
# 000207313
# 11/20/2009
# 2/6/2010
# 104(a)
# 11/20/2009
# C
# N
# 41.12
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec41-12.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Dirt Company
# Dirt Company
#
# 6478923
# 000207313
# 11/20/2009
# 2/6/2010
# 104(a)
# 11/20/2009
# C
# N
# 56.1000
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-1000.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Dirt Company
# Dirt Company
#
# 6444512
# 000198763
# 8/24/2009
# 10/30/2010
# 104(a)
# 9/21/2009
# C
# N
# 50.30(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec50-30.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Dirt Company
# Dirt Company
#
# 6358298
# 000041449
# 8/11/2004
# 12/23/2004
# 104(a)
# 8/15/2004
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2004-title30-vol1/pdf/CFR-2004-title30-vol1-sec56-14107.pdf
# 60.00
# Closed
# 60.00
# 60.00
# ---------
# Dirt Company
# Dirt Company
#
# 6358301
# 000041449
# 8/11/2004
# 12/23/2004
# 104(a)
# 8/26/2004
# C
# Y
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2004-title30-vol1/pdf/CFR-2004-title30-vol1-sec56-14107.pdf
# 99.00
# Closed
# 99.00
# 99.00
# ---------
# Dirt Company
# Dirt Company
#
# 6358296
# 000041449
# 8/11/2004
# 12/23/2004
# 104(a)
# 8/12/2004
# C
# Y
# 56.12032
# http://www.gpo.gov/fdsys/pkg/CFR-2004-title30-vol1/pdf/CFR-2004-title30-vol1-sec56-12032.pdf
# 124.00
# Closed
# 124.00
# 124.00
# ---------
# Dirt Company
# Dirt Company
#
# 6358297
# 000041449
# 8/11/2004
# 12/23/2004
# 104(a)
# 8/12/2004
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2004-title30-vol1/pdf/CFR-2004-title30-vol1-sec56-14107.pdf
# 60.00
# Closed
# 60.00
# 60.00
# ---------
# Dirt Company
# Dirt Company
#
# 6358299
# 000041449
# 8/11/2004
# 12/23/2004
# 104(a)
# 8/15/2004
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2004-title30-vol1/pdf/CFR-2004-title30-vol1-sec56-14107.pdf
# 60.00
# Closed
# 60.00
# 60.00
# ---------
# Dirt Company
# Dirt Company
#
# 6358295
# 000041449
# 8/11/2004
# 12/23/2004
# 104(a)
# 8/26/2004
# C
# Y
# 56.14130(a)(1)
# http://www.gpo.gov/fdsys/pkg/CFR-2004-title30-vol1/pdf/CFR-2004-title30-vol1-sec56-14130.pdf
# 124.00
# Closed
# 124.00
# 124.00
# ---------
# Dirt Company
# Dirt Company
#
# 6358300
# 000041449
# 8/11/2004
# 12/23/2004
# 104(a)
# 8/15/2004
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2004-title30-vol1/pdf/CFR-2004-title30-vol1-sec56-14107.pdf
# 60.00
# Closed
# 60.00
# 60.00
# ---------
# Dirt Company
# Dirt Company
#
# 6358302
# 000046666
# 8/11/2004
# 2/24/2005
# 104(g)(1)
# 8/26/2004
# O
# Y
# 46.8(a)(1)
# http://www.gpo.gov/fdsys/pkg/CFR-2004-title30-vol1/pdf/CFR-2004-title30-vol1-sec46-8.pdf
# 101.00
# Closed
# 101.00
# 101.00
# ---------
# ---------
# ---------
# Sunshine Reclamation Inc.
# Sunshine Reclamation Inc.
#
# 8657164
# 000291395
# 5/1/2012
# 7/25/2012
# 104(a)
# 5/2/2012
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2012-title30-vol1/pdf/CFR-2012-title30-vol1-sec56-14107.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Sunshine Reclamation Inc.
# Sunshine Reclamation Inc.
#
# 8657165
# 000291395
# 5/1/2012
# 7/25/2012
# 104(a)
# 5/1/2012
# C
# Y
# 56.9300(b)
# http://www.gpo.gov/fdsys/pkg/CFR-2012-title30-vol1/pdf/CFR-2012-title30-vol1-sec56-9300.pdf
# 108.00
# Closed
# 108.00
# 108.00
# ---------
# Dirt Con
# Dirt Con
# J392
# 8580031
# 000242289
# 10/27/2010
# 1/30/2011
# 104(a)
# 10/27/2010
# C
# Y
# 56.14100(d)
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec56-14100.pdf
# 585.00
# Closed
# 585.00
# 585.00
# ---------
# Dirt Con
# Dirt Con
# J392
# 8580030
# 000242289
# 10/27/2010
# 1/30/2011
# 104(a)
# 10/27/2010
# C
# Y
# 56.14100(c)
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec56-14100.pdf
# 585.00
# Closed
# 585.00
# 585.00
# ---------
# Dirt Con
# Dirt Con
# J392
# 8580028
# 000239419
# 10/26/2010
# 1/2/2011
# 104(a)
# 10/26/2010
# C
# Y
# 56.14132(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec56-14132.pdf
# 585.00
# Closed
# 585.00
# 585.00
# ---------
# Dirt Con
# Dirt Con
# J392
# 8580023
# 000252992
# 10/26/2010
# 5/28/2011
# 104(a)
# 10/26/2010
# C
# Y
# 56.14130(g)
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec56-14130.pdf
# 585.00
# Closed
# 585.00
# 585.00
# ---------
# Dirt Con
# Dirt Con
# J392
# 8580025
# 000239419
# 10/26/2010
# 1/2/2011
# 104(a)
# 10/27/2010
# C
# N
# 56.14100(b)
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec56-14100.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Sunshine Reclamation Inc.
# Sunshine Reclamation Inc.
#
# 8580029
# 000240535
# 10/26/2010
# 1/13/2011
# 104(a)
# 10/26/2010
# C
# N
# 56.14132(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec56-14132.pdf
# 362.00
# Closed
# 362.00
# 362.00
# ---------
# Dirt Con
# Dirt Con
# J392
# 8580026
# 000252992
# 10/26/2010
# 5/28/2011
# 104(a)
# 10/26/2010
# C
# Y
# 56.14207
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec56-14207.pdf
# 1,944.00
# Closed
# 1,944.00
# 1,944.00
# ---------
# Dirt Con
# Dirt Con
# J392
# 8580027
# 000239419
# 10/26/2010
# 1/2/2011
# 104(a)
# 10/27/2010
# C
# Y
# 56.14100(b)
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec56-14100.pdf
# 176.00
# Closed
# 176.00
# 176.00
# ---------
# Dirt Con
# Dirt Con
# J392
# 8580024
# 000239419
# 10/26/2010
# 1/2/2011
# 104(a)
# 10/27/2010
# C
# Y
# 56.14100(b)
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec56-14100.pdf
# 176.00
# Closed
# 176.00
# 176.00
# ---------
# Sunshine Reclamation Inc.
# Sunshine Reclamation Inc.
#
# 8570069
# 000221815
# 4/19/2010
# 7/23/2010
# 104(a)
# 5/4/2010
# C
# N
# 56.9300(b)
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec56-9300.pdf
# 150.00
# Closed
# 150.00
# 150.00
# ---------
# Sunshine Reclamation Inc.
# Sunshine Reclamation Inc.
#
# 8570066
# 000221815
# 4/15/2010
# 7/23/2010
# 104(a)
# 4/15/2010
# C
# Y
# 56.12034
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec56-12034.pdf
# 1,412.00
# Closed
# 1,412.00
# 1,412.00
# ---------
# Sunshine Reclamation Inc.
# Sunshine Reclamation Inc.
#
# 8570068
# 000221815
# 4/15/2010
# 7/23/2010
# 104(a)
# 4/15/2010
# C
# N
# 50.30(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec50-30.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Sunshine Reclamation Inc.
# Sunshine Reclamation Inc.
#
# 8570063
# 000221815
# 4/15/2010
# 7/23/2010
# 104(a)
# 4/19/2010
# C
# N
# 56.14100(b)
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec56-14100.pdf
# 285.00
# Closed
# 285.00
# 285.00
# ---------
# Sunshine Reclamation Inc.
# Sunshine Reclamation Inc.
#
# 8570064
# 000221815
# 4/15/2010
# 7/23/2010
# 104(a)
# 4/19/2010
# C
# N
# 56.14100(b)
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec56-14100.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Sunshine Reclamation Inc.
# Sunshine Reclamation Inc.
#
# 8570067
# 000221815
# 4/15/2010
# 7/23/2010
# 104(a)
# 4/15/2010
# C
# N
#
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec-.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Sunshine Reclamation Inc.
# Sunshine Reclamation Inc.
#
# 8570070
# 000221815
# 4/15/2010
# 7/23/2010
# 104(a)
# 4/19/2010
# C
# N
# 56.14132(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec56-14132.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Sunshine Reclamation Inc.
# Sunshine Reclamation Inc.
#
# 8570065
# 000221815
# 4/15/2010
# 7/23/2010
# 104(a)
# 5/4/2010
# C
# N
# 56.14101(a)(3)
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec56-14101.pdf
# 285.00
# Closed
# 285.00
# 285.00
# ---------
# Sunshine Reclamation Inc.
# Sunshine Reclamation Inc.
#
# 8570062
# 000221815
# 4/15/2010
# 7/23/2010
# 104(a)
# 4/19/2010
# C
# N
# 56.14100(b)
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec56-14100.pdf
# 285.00
# Closed
# 285.00
# 285.00
# ---------
# Sunshine Reclamation Inc.
# Sunshine Reclamation Inc.
#
# 8570071
# 000221815
# 4/15/2010
# 7/23/2010
# 104(a)
# 4/20/2010
# C
# N
# 56.14100(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec56-14100.pdf
# 285.00
# Closed
# 285.00
# 285.00
# ---------
# Dirt Con
# Dirt Con
# J392
# 8570054
#
# 4/14/2010
# 107(a)
# 4/14/2010
# O
# N/A
#
# Non-Assessable
# Missing url
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8992368
# 000440809
# 5/2/2017
# 7/23/2017
# 104(a)
# 5/2/2017
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2017-title30-vol1/pdf/CFR-2017-title30-vol1-sec56-14107.pdf
# 116.00
# Closed
# 116.00
# 116.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8992214
# 000435717
# 2/7/2017
# 5/21/2017
# 104(a)
# 2/8/2017
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2017-title30-vol1/pdf/CFR-2017-title30-vol1-sec56-14107.pdf
# 116.00
# Closed
# 116.00
# 116.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8872462
# 000398910
# 10/21/2015
# 1/13/2016
# 104(a)
# 10/27/2015
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2015-title30-vol1/pdf/CFR-2015-title30-vol1-sec56-14107.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8872461
# 000398910
# 10/21/2015
# 1/13/2016
# 104(a)
# 10/27/2015
# C
# N
# 56.12004
# http://www.gpo.gov/fdsys/pkg/CFR-2015-title30-vol1/pdf/CFR-2015-title30-vol1-sec56-12004.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8790965
# 000383840
# 4/15/2015
# 7/17/2015
# 104(a)
# 4/15/2015
# C
# N
# 56.13015
# http://www.gpo.gov/fdsys/pkg/CFR-2015-title30-vol1/pdf/CFR-2015-title30-vol1-sec56-13015.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8790964
# 000383840
# 4/13/2015
# 7/17/2015
# 104(a)
# 4/15/2015
# C
# N
# 56.4101
# http://www.gpo.gov/fdsys/pkg/CFR-2015-title30-vol1/pdf/CFR-2015-title30-vol1-sec56-4101.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8790962
# 000383840
# 4/10/2015
# 7/17/2015
# 104(a)
# 4/10/2015
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2015-title30-vol1/pdf/CFR-2015-title30-vol1-sec56-14107.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8790963
# 000383840
# 4/10/2015
# 7/17/2015
# 104(a)
# 4/13/2015
# C
# Y
# 56.15020
# http://www.gpo.gov/fdsys/pkg/CFR-2015-title30-vol1/pdf/CFR-2015-title30-vol1-sec56-15020.pdf
# 873.00
# Closed
# 873.00
# 873.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8694457
# 000345066
# 1/29/2014
# 4/12/2014
# 104(a)
# 1/29/2014
# C
# N
# 56.12004
# http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-vol1/pdf/CFR-2014-title30-vol1-sec56-12004.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8694458
# 000345066
# 1/29/2014
# 4/12/2014
# 104(a)
# 1/29/2014
# C
# N
# 56.12018
# http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-vol1/pdf/CFR-2014-title30-vol1-sec56-12018.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8694455
# 000345066
# 1/28/2014
# 4/12/2014
# 104(a)
# 1/29/2014
# C
# N
# 56.12004
# http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-vol1/pdf/CFR-2014-title30-vol1-sec56-12004.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8694450
# 000345066
# 1/28/2014
# 4/12/2014
# 104(a)
# 1/29/2014
# C
# N
# 56.14132(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-vol1/pdf/CFR-2014-title30-vol1-sec56-14132.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8694456
# 000345066
# 1/28/2014
# 4/12/2014
# 104(a)
# 1/29/2014
# C
# N
# 56.14132(b)(1)
# http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-vol1/pdf/CFR-2014-title30-vol1-sec56-14132.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8694454
# 000345066
# 1/28/2014
# 4/12/2014
# 104(a)
# 1/29/2014
# C
# Y
# 56.12032
# http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-vol1/pdf/CFR-2014-title30-vol1-sec56-12032.pdf
# 243.00
# Closed
# 243.00
# 243.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8694453
# 000345066
# 1/28/2014
# 4/12/2014
# 104(a)
# 1/29/2014
# C
# N
# 56.4201(a)(1)
# http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-vol1/pdf/CFR-2014-title30-vol1-sec56-4201.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8694451
# 000347758
# 1/28/2014
# 5/14/2014
# 104(a)
# 1/29/2014
# C
# N
# 56.14100(b)
# http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-vol1/pdf/CFR-2014-title30-vol1-sec56-14100.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8694452
# 000345066
# 1/28/2014
# 4/12/2014
# 104(a)
# 1/29/2014
# C
# N
# 56.14132(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-vol1/pdf/CFR-2014-title30-vol1-sec56-14132.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# ---------
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8599787
# 000291331
# 5/1/2012
# 7/13/2012
# 104(a)
# 5/7/2012
# C
# N
# 56.14108
# http://www.gpo.gov/fdsys/pkg/CFR-2012-title30-vol1/pdf/CFR-2012-title30-vol1-sec56-14108.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8599788
# 000291331
# 5/1/2012
# 7/13/2012
# 104(a)
# 5/7/2012
# C
# N
# 56.12004
# http://www.gpo.gov/fdsys/pkg/CFR-2012-title30-vol1/pdf/CFR-2012-title30-vol1-sec56-12004.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8599789
# 000297041
# 5/1/2012
# 9/13/2012
# 104(a)
# 5/7/2012
# C
# Y
# 56.14101(a)(2)
# http://www.gpo.gov/fdsys/pkg/CFR-2012-title30-vol1/pdf/CFR-2012-title30-vol1-sec56-14101.pdf
# 243.00
# Closed
# 243.00
# 243.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8599107
# 000269626
# 9/7/2011
# 11/18/2011
# 104(a)
# 9/19/2011
# C
# N
# 50.30(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2011-title30-vol1/pdf/CFR-2011-title30-vol1-sec50-30.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8599025
# 000239613
# 10/7/2010
# 1/5/2011
# 104(a)
# 10/7/2010
# C
# N
# 56.12004
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec56-12004.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 8599026
# 000239613
# 10/7/2010
# 1/5/2011
# 104(a)
# 10/7/2010
# C
# N
# 56.12004
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec56-12004.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6398905
# 000220925
# 4/20/2010
# 7/9/2010
# 104(a)
# 6/8/2010
# C
# Y
# 56.11001
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec56-11001.pdf
# 117.00
# Closed
# 117.00
# 117.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6338510
# 000210055
# 12/29/2009
# 1/10/2013
# 104(a)
# 12/30/2009
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-14107.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6338509
# 000210055
# 12/29/2009
# 1/10/2013
# 104(a)
# 1/11/2010
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-14107.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6338511
# 000210055
# 12/29/2009
# 1/10/2013
# 104(a)
# 1/11/2010
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-14107.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6338507
# 000210055
# 12/29/2009
# 1/10/2013
# 104(a)
# 1/11/2010
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-14107.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6338508
# 000210055
# 12/29/2009
# 1/10/2013
# 104(a)
# 12/30/2009
# C
# N
# 56.11002
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-11002.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6338512
# 000210055
# 12/29/2009
# 1/10/2013
# 104(a)
# 12/29/2009
# C
# N
# 56.12004
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-12004.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6479620
# 000180614
# 2/26/2009
# 5/8/2009
# 104(a)
# 3/4/2009
# C
# N
# 56.12028
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-12028.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6479618
# 000180614
# 2/26/2009
# 5/22/2010
# 104(a)
# 3/4/2009
# C
# N
# 56.14130(i)
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-14130.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6479613
# 000180614
# 2/26/2009
# 5/22/2010
# 104(a)
# 2/26/2009
# C
# Y
# 56.3200
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-3200.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6479617
# 000180614
# 2/26/2009
# 5/8/2009
# 104(a)
# 3/4/2009
# C
# N
# 56.4201(a)(2)
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-4201.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6479616
# 000180614
# 2/26/2009
# 5/22/2010
# 104(a)
# 3/4/2009
# C
# N
# 56.14103(b)
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-14103.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6479619
# 000180614
# 2/26/2009
# 5/22/2010
# 104(a)
# 2/26/2009
# C
# N
# 56.14100(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-14100.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6479615
# 000180614
# 2/26/2009
# 5/22/2010
# 104(a)
# 3/4/2009
# C
# N
# 56.14100(b)
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-14100.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6479614
# 000180614
# 2/26/2009
# 5/22/2010
# 104(a)
# 3/4/2009
# C
# N
# 56.14100(d)
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-14100.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6479612
# 000180614
# 2/26/2009
# 5/22/2010
# 104(a)
# 3/4/2009
# C
# Y
# 56.9200(d)
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-9200.pdf
# 263.00
# Closed
# 263.00
# 263.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6430326
# 000152001
# 4/2/2008
# 7/10/2008
# 104(a)
# 4/3/2008
# C
# N
# 56.14100(b)
# http://www.gpo.gov/fdsys/pkg/CFR-2008-title30-vol1/pdf/CFR-2008-title30-vol1-sec56-14100.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6430325
# 000152001
# 4/2/2008
# 7/10/2008
# 104(a)
# 4/3/2008
# C
# N
# 56.14112(a)(1)
# http://www.gpo.gov/fdsys/pkg/CFR-2008-title30-vol1/pdf/CFR-2008-title30-vol1-sec56-14112.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6342895
# 000121048
# 5/23/2007
# 8/17/2007
# 104(a)
# 5/24/2007
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2007-title30-vol1/pdf/CFR-2007-title30-vol1-sec56-14107.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6342893
# 000121048
# 5/23/2007
# 8/17/2007
# 104(a)
# 5/24/2007
# C
# N
# 56.14100(b)
# http://www.gpo.gov/fdsys/pkg/CFR-2007-title30-vol1/pdf/CFR-2007-title30-vol1-sec56-14100.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6342892
# 000121048
# 5/23/2007
# 8/17/2007
# 104(a)
# 5/24/2007
# C
# N
# 56.14100(b)
# http://www.gpo.gov/fdsys/pkg/CFR-2007-title30-vol1/pdf/CFR-2007-title30-vol1-sec56-14100.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6342894
# 000121048
# 5/23/2007
# 8/17/2007
# 104(a)
# 5/24/2007
# C
# N
# 56.14132(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2007-title30-vol1/pdf/CFR-2007-title30-vol1-sec56-14132.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6383438
# 000086543
# 3/1/2006
# 6/16/2006
# 104(a)
# 3/2/2006
# C
# N
# 56.11002
# http://www.gpo.gov/fdsys/pkg/CFR-2006-title30-vol1/pdf/CFR-2006-title30-vol1-sec56-11002.pdf
# 60.00
# Closed
# 60.00
# 60.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6383437
# 000086543
# 3/1/2006
# 6/16/2006
# 104(a)
# 3/2/2006
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2006-title30-vol1/pdf/CFR-2006-title30-vol1-sec56-14107.pdf
# 60.00
# Closed
# 60.00
# 60.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6368407
# 000051247
# 10/27/2004
# 7/23/2005
# 104(a)
# 1/21/2005
# C
# N
# 62.120
# http://www.gpo.gov/fdsys/pkg/CFR-2004-title30-vol1/pdf/CFR-2004-title30-vol1-sec62-120.pdf
# 60.00
# Closed
# 60.00
# 60.00
# ---------
# Newberg Rock & Dirt
# Newberg Rock & Dirt
#
# 6368406
# 000044260
# 10/25/2004
# 1/12/2005
# 104(a)
# 10/27/2004
# C
# Y
# 56.14131(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2004-title30-vol1/pdf/CFR-2004-title30-vol1-sec56-14131.pdf
# 99.00
# Closed
# 99.00
# 99.00
# ---------
# AM Dirtworks & Aggregate Sales
# AM Dirtworks & Aggregate Sales
#
# 8933510
# 000426827
# 11/1/2016
# 1/20/2017
# 104(a)
# 1/11/2017
# C
# N
# 56.1000
# http://www.gpo.gov/fdsys/pkg/CFR-2016-title30-vol1/pdf/CFR-2016-title30-vol1-sec56-1000.pdf
# 114.00
# Delinquent
# 114.00
# 0.00
# ---------
# AM Dirtworks & Aggregate Sales
# AM Dirtworks & Aggregate Sales
#
# 8753189
# 000407999
# 3/3/2016
# 6/24/2016
# 104(a)
# 3/3/2016
# C
# N
# 46.9(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2016-title30-vol1/pdf/CFR-2016-title30-vol1-sec46-9.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# AM Dirtworks & Aggregate Sales
# AM Dirtworks & Aggregate Sales
#
# 8753190
# 000407999
# 3/3/2016
# 6/24/2016
# 104(a)
# 3/3/2016
# C
# Y
# 56.14115(b)
# http://www.gpo.gov/fdsys/pkg/CFR-2016-title30-vol1/pdf/CFR-2016-title30-vol1-sec56-14115.pdf
# 108.00
# Closed
# 108.00
# 108.00
# ---------
# AM Dirtworks & Aggregate Sales
# AM Dirtworks & Aggregate Sales
#
# 8753187
# 000407999
# 3/2/2016
# 6/24/2016
# 104(a)
# 3/2/2016
# C
# Y
# 56.9300(b)
# http://www.gpo.gov/fdsys/pkg/CFR-2016-title30-vol1/pdf/CFR-2016-title30-vol1-sec56-9300.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# AM Dirtworks & Aggregate Sales
# AM Dirtworks & Aggregate Sales
#
# 8753188
# 000407999
# 3/2/2016
# 6/24/2016
# 104(a)
# 3/24/2016
# C
# Y
# 56.11001
# http://www.gpo.gov/fdsys/pkg/CFR-2016-title30-vol1/pdf/CFR-2016-title30-vol1-sec56-11001.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# AM Dirtworks & Aggregate Sales
# AM Dirtworks & Aggregate Sales
#
# 8825833
# 000376854
# 2/4/2015
# 5/19/2015
# 104(a)
# 2/10/2015
# C
# N
# 50.30(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2015-title30-vol1/pdf/CFR-2015-title30-vol1-sec50-30.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Dirt Company
# Dirt Company
#
# 8601715
# 000423303
# 10/1/2016
# 12/16/2016
# 104(a)
# 10/28/2016
# C
# N
# 56.14132(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2016-title30-vol1/pdf/CFR-2016-title30-vol1-sec56-14132.pdf
# 114.00
# Closed
# 114.00
# 114.00
# ---------
# Dirt Company
# Dirt Company
#
# 8601716
# 000423303
# 10/1/2016
# 12/16/2016
# 104(a)
# 10/28/2016
# C
# N
# 56.14103(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2016-title30-vol1/pdf/CFR-2016-title30-vol1-sec56-14103.pdf
# 114.00
# Closed
# 114.00
# 114.00
# ---------
# Dirt Company
# Dirt Company
#
# 8601714
# 000423303
# 10/1/2016
# 12/16/2016
# 104(a)
# 10/28/2016
# C
# N
# 56.14132(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2016-title30-vol1/pdf/CFR-2016-title30-vol1-sec56-14132.pdf
# 114.00
# Closed
# 114.00
# 114.00
# ---------
# Dirt Company
# Dirt Company
#
# 8601713
# 000423303
# 10/1/2016
# 12/16/2016
# 104(a)
# 10/28/2016
# C
# N
# 56.9300(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2016-title30-vol1/pdf/CFR-2016-title30-vol1-sec56-9300.pdf
# 114.00
# Closed
# 114.00
# 114.00
# ---------
# Dirt Company
# Dirt Company
#
# 8601712
# 000423303
# 10/1/2016
# 12/16/2016
# 104(a)
# 10/28/2016
# C
# N
# 56.14112(a)(1)
# http://www.gpo.gov/fdsys/pkg/CFR-2016-title30-vol1/pdf/CFR-2016-title30-vol1-sec56-14112.pdf
# 114.00
# Closed
# 114.00
# 114.00
# ---------
# Dirt Company
# Dirt Company
#
# 6356395
# 000416201
# 6/28/2016
# 9/16/2016
# 104(a)
# 6/30/2016
# C
# N
# 56.14112(b)
# http://www.gpo.gov/fdsys/pkg/CFR-2016-title30-vol1/pdf/CFR-2016-title30-vol1-sec56-14112.pdf
# 114.00
# Closed
# 114.00
# 114.00
# ---------
# Dirt Company
# Dirt Company
#
# 6356396
# 000416201
# 6/28/2016
# 9/16/2016
# 104(a)
# 6/28/2016
# C
# N
# 56.14132(b)(2)
# http://www.gpo.gov/fdsys/pkg/CFR-2016-title30-vol1/pdf/CFR-2016-title30-vol1-sec56-14132.pdf
# 114.00
# Closed
# 114.00
# 114.00
# ---------
# Dirt Company
# Dirt Company
#
# 8601395
# 000390299
# 7/2/2015
# 10/8/2015
# 104(a)
# 8/25/2015
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2015-title30-vol1/pdf/CFR-2015-title30-vol1-sec56-14107.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Dirt Company
# Dirt Company
#
# 8601400
# 000390299
# 7/2/2015
# 10/8/2015
# 104(a)
# 8/25/2015
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2015-title30-vol1/pdf/CFR-2015-title30-vol1-sec56-14107.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Dirt Company
# Dirt Company
#
# 8601414
# 000390299
# 7/2/2015
# 10/8/2015
# 104(a)
# 8/25/2015
# C
# Y
# 56.11002
# http://www.gpo.gov/fdsys/pkg/CFR-2015-title30-vol1/pdf/CFR-2015-title30-vol1-sec56-11002.pdf
# 108.00
# Closed
# 108.00
# 108.00
# ---------
# Dirt Company
# Dirt Company
#
# 8601413
# 000390299
# 7/2/2015
# 10/8/2015
# 104(a)
# 8/25/2015
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2015-title30-vol1/pdf/CFR-2015-title30-vol1-sec56-14107.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Dirt Company
# Dirt Company
#
# 8601402
# 000357404
# 6/17/2014
# 9/3/2014
# 104(a)
# 6/17/2014
# C
# N
# 56.4201(a)(1)
# http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-vol1/pdf/CFR-2014-title30-vol1-sec56-4201.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Dirt Company
# Dirt Company
#
# 8601223
# 000293537
# 5/31/2012
# 8/9/2012
# 104(a)
# 5/31/2012
# C
# Y
# 56.14100(d)
# http://www.gpo.gov/fdsys/pkg/CFR-2012-title30-vol1/pdf/CFR-2012-title30-vol1-sec56-14100.pdf
# 243.00
# Closed
# 243.00
# 243.00
# ---------
# Dirt Company
# Dirt Company
#
# 8601226
# 000293537
# 5/31/2012
# 8/9/2012
# 104(a)
# 5/31/2012
# C
# Y
# 56.11002
# http://www.gpo.gov/fdsys/pkg/CFR-2012-title30-vol1/pdf/CFR-2012-title30-vol1-sec56-11002.pdf
# 108.00
# Closed
# 108.00
# 108.00
# ---------
# Dirt Company
# Dirt Company
#
# 8601224
# 000293537
# 5/31/2012
# 8/9/2012
# 104(a)
# 5/31/2012
# C
# N
# 56.4201(a)(1)
# http://www.gpo.gov/fdsys/pkg/CFR-2012-title30-vol1/pdf/CFR-2012-title30-vol1-sec56-4201.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Dirt Company
# Dirt Company
#
# 8601225
# 000293537
# 5/31/2012
# 8/9/2012
# 104(a)
# 5/31/2012
# C
# Y
# 56.15001
# http://www.gpo.gov/fdsys/pkg/CFR-2012-title30-vol1/pdf/CFR-2012-title30-vol1-sec56-15001.pdf
# 108.00
# Closed
# 108.00
# 108.00
# ---------
# Dirt Company
# Dirt Company
#
# 8601222
# 000293537
# 5/31/2012
# 8/9/2012
# 104(a)
# 5/31/2012
# C
# Y
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2012-title30-vol1/pdf/CFR-2012-title30-vol1-sec56-14107.pdf
# 108.00
# Closed
# 108.00
# 108.00
# ---------
# Dirt Company
# Dirt Company
#
# 8601228
# 000293537
# 5/31/2012
# 8/9/2012
# 104(a)
# 5/31/2012
# C
# Y
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2012-title30-vol1/pdf/CFR-2012-title30-vol1-sec56-14107.pdf
# 807.00
# Closed
# 807.00
# 807.00
# ---------
# Dirt Company
# Dirt Company
#
# 8601038
# 000270890
# 9/8/2011
# 12/7/2011
# 104(a)
# 9/8/2011
# C
# N
# 50.30(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2011-title30-vol1/pdf/CFR-2011-title30-vol1-sec50-30.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Dirt Company
# Dirt Company
#
# 8601037
# 000270890
# 9/8/2011
# 12/7/2011
# 104(a)
# 9/8/2011
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2011-title30-vol1/pdf/CFR-2011-title30-vol1-sec56-14107.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Dirt Company
# Dirt Company
#
# 6478923
# 000207313
# 11/20/2009
# 2/6/2010
# 104(a)
# 11/20/2009
# C
# N
# 56.1000
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-1000.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Dirt Company
# Dirt Company
#
# 6478924
# 000207313
# 11/20/2009
# 2/6/2010
# 104(a)
# 11/20/2009
# C
# N
# 41.12
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec41-12.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Dirt Company
# Dirt Company
#
# 6444512
# 000198763
# 8/24/2009
# 10/30/2010
# 104(a)
# 9/21/2009
# C
# N
# 50.30(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec50-30.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Dirt Company
# Dirt Company
#
# 6358299
# 000041449
# 8/11/2004
# 12/23/2004
# 104(a)
# 8/15/2004
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2004-title30-vol1/pdf/CFR-2004-title30-vol1-sec56-14107.pdf
# 60.00
# Closed
# 60.00
# 60.00
# ---------
# Dirt Company
# Dirt Company
#
# 6358302
# 000046666
# 8/11/2004
# 2/24/2005
# 104(g)(1)
# 8/26/2004
# O
# Y
# 46.8(a)(1)
# http://www.gpo.gov/fdsys/pkg/CFR-2004-title30-vol1/pdf/CFR-2004-title30-vol1-sec46-8.pdf
# 101.00
# Closed
# 101.00
# 101.00
# ---------
# Dirt Company
# Dirt Company
#
# 6358300
# 000041449
# 8/11/2004
# 12/23/2004
# 104(a)
# 8/15/2004
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2004-title30-vol1/pdf/CFR-2004-title30-vol1-sec56-14107.pdf
# 60.00
# Closed
# 60.00
# 60.00
# ---------
# Dirt Company
# Dirt Company
#
# 6358297
# 000041449
# 8/11/2004
# 12/23/2004
# 104(a)
# 8/12/2004
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2004-title30-vol1/pdf/CFR-2004-title30-vol1-sec56-14107.pdf
# 60.00
# Closed
# 60.00
# 60.00
# ---------
# Dirt Company
# Dirt Company
#
# 6358298
# 000041449
# 8/11/2004
# 12/23/2004
# 104(a)
# 8/15/2004
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2004-title30-vol1/pdf/CFR-2004-title30-vol1-sec56-14107.pdf
# 60.00
# Closed
# 60.00
# 60.00
# ---------
# Dirt Company
# Dirt Company
#
# 6358301
# 000041449
# 8/11/2004
# 12/23/2004
# 104(a)
# 8/26/2004
# C
# Y
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2004-title30-vol1/pdf/CFR-2004-title30-vol1-sec56-14107.pdf
# 99.00
# Closed
# 99.00
# 99.00
# ---------
# Dirt Company
# Dirt Company
#
# 6358295
# 000041449
# 8/11/2004
# 12/23/2004
# 104(a)
# 8/26/2004
# C
# Y
# 56.14130(a)(1)
# http://www.gpo.gov/fdsys/pkg/CFR-2004-title30-vol1/pdf/CFR-2004-title30-vol1-sec56-14130.pdf
# 124.00
# Closed
# 124.00
# 124.00
# ---------
# Dirt Company
# Dirt Company
#
# 6358296
# 000041449
# 8/11/2004
# 12/23/2004
# 104(a)
# 8/12/2004
# C
# Y
# 56.12032
# http://www.gpo.gov/fdsys/pkg/CFR-2004-title30-vol1/pdf/CFR-2004-title30-vol1-sec56-12032.pdf
# 124.00
# Closed
# 124.00
# 124.00
# ---------
# ---------
# ---------
# Sunshine Reclamation Inc.
# Sunshine Reclamation Inc.
#
# 8657164
# 000291395
# 5/1/2012
# 7/25/2012
# 104(a)
# 5/2/2012
# C
# N
# 56.14107(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2012-title30-vol1/pdf/CFR-2012-title30-vol1-sec56-14107.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Sunshine Reclamation Inc.
# Sunshine Reclamation Inc.
#
# 8657165
# 000291395
# 5/1/2012
# 7/25/2012
# 104(a)
# 5/1/2012
# C
# Y
# 56.9300(b)
# http://www.gpo.gov/fdsys/pkg/CFR-2012-title30-vol1/pdf/CFR-2012-title30-vol1-sec56-9300.pdf
# 108.00
# Closed
# 108.00
# 108.00
# ---------
# Dirt Con
# Dirt Con
# J392
# 8580030
# 000242289
# 10/27/2010
# 1/30/2011
# 104(a)
# 10/27/2010
# C
# Y
# 56.14100(c)
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec56-14100.pdf
# 585.00
# Closed
# 585.00
# 585.00
# ---------
# Dirt Con
# Dirt Con
# J392
# 8580031
# 000242289
# 10/27/2010
# 1/30/2011
# 104(a)
# 10/27/2010
# C
# Y
# 56.14100(d)
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec56-14100.pdf
# 585.00
# Closed
# 585.00
# 585.00
# ---------
# Dirt Con
# Dirt Con
# J392
# 8580027
# 000239419
# 10/26/2010
# 1/2/2011
# 104(a)
# 10/27/2010
# C
# Y
# 56.14100(b)
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec56-14100.pdf
# 176.00
# Closed
# 176.00
# 176.00
# ---------
# Dirt Con
# Dirt Con
# J392
# 8580023
# 000252992
# 10/26/2010
# 5/28/2011
# 104(a)
# 10/26/2010
# C
# Y
# 56.14130(g)
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec56-14130.pdf
# 585.00
# Closed
# 585.00
# 585.00
# ---------
# Dirt Con
# Dirt Con
# J392
# 8580025
# 000239419
# 10/26/2010
# 1/2/2011
# 104(a)
# 10/27/2010
# C
# N
# 56.14100(b)
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec56-14100.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Dirt Con
# Dirt Con
# J392
# 8580024
# 000239419
# 10/26/2010
# 1/2/2011
# 104(a)
# 10/27/2010
# C
# Y
# 56.14100(b)
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec56-14100.pdf
# 176.00
# Closed
# 176.00
# 176.00
# ---------
# Dirt Con
# Dirt Con
# J392
# 8580026
# 000252992
# 10/26/2010
# 5/28/2011
# 104(a)
# 10/26/2010
# C
# Y
# 56.14207
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec56-14207.pdf
# 1,944.00
# Closed
# 1,944.00
# 1,944.00
# ---------
# Dirt Con
# Dirt Con
# J392
# 8580028
# 000239419
# 10/26/2010
# 1/2/2011
# 104(a)
# 10/26/2010
# C
# Y
# 56.14132(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec56-14132.pdf
# 585.00
# Closed
# 585.00
# 585.00
# ---------
# Sunshine Reclamation Inc.
# Sunshine Reclamation Inc.
#
# 8580029
# 000240535
# 10/26/2010
# 1/13/2011
# 104(a)
# 10/26/2010
# C
# N
# 56.14132(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec56-14132.pdf
# 362.00
# Closed
# 362.00
# 362.00
# ---------
# Sunshine Reclamation Inc.
# Sunshine Reclamation Inc.
#
# 8570069
# 000221815
# 4/19/2010
# 7/23/2010
# 104(a)
# 5/4/2010
# C
# N
# 56.9300(b)
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec56-9300.pdf
# 150.00
# Closed
# 150.00
# 150.00
# ---------
# Sunshine Reclamation Inc.
# Sunshine Reclamation Inc.
#
# 8570071
# 000221815
# 4/15/2010
# 7/23/2010
# 104(a)
# 4/20/2010
# C
# N
# 56.14100(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec56-14100.pdf
# 285.00
# Closed
# 285.00
# 285.00
# ---------
# Sunshine Reclamation Inc.
# Sunshine Reclamation Inc.
#
# 8570070
# 000221815
# 4/15/2010
# 7/23/2010
# 104(a)
# 4/19/2010
# C
# N
# 56.14132(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec56-14132.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Sunshine Reclamation Inc.
# Sunshine Reclamation Inc.
#
# 8570065
# 000221815
# 4/15/2010
# 7/23/2010
# 104(a)
# 5/4/2010
# C
# N
# 56.14101(a)(3)
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec56-14101.pdf
# 285.00
# Closed
# 285.00
# 285.00
# ---------
# Sunshine Reclamation Inc.
# Sunshine Reclamation Inc.
#
# 8570064
# 000221815
# 4/15/2010
# 7/23/2010
# 104(a)
# 4/19/2010
# C
# N
# 56.14100(b)
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec56-14100.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Sunshine Reclamation Inc.
# Sunshine Reclamation Inc.
#
# 8570067
# 000221815
# 4/15/2010
# 7/23/2010
# 104(a)
# 4/15/2010
# C
# N
#
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec-.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Sunshine Reclamation Inc.
# Sunshine Reclamation Inc.
#
# 8570063
# 000221815
# 4/15/2010
# 7/23/2010
# 104(a)
# 4/19/2010
# C
# N
# 56.14100(b)
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec56-14100.pdf
# 285.00
# Closed
# 285.00
# 285.00
# ---------
# Sunshine Reclamation Inc.
# Sunshine Reclamation Inc.
#
# 8570066
# 000221815
# 4/15/2010
# 7/23/2010
# 104(a)
# 4/15/2010
# C
# Y
# 56.12034
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec56-12034.pdf
# 1,412.00
# Closed
# 1,412.00
# 1,412.00
# ---------
# Sunshine Reclamation Inc.
# Sunshine Reclamation Inc.
#
# 8570062
# 000221815
# 4/15/2010
# 7/23/2010
# 104(a)
# 4/19/2010
# C
# N
# 56.14100(b)
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec56-14100.pdf
# 285.00
# Closed
# 285.00
# 285.00
# ---------
# Sunshine Reclamation Inc.
# Sunshine Reclamation Inc.
#
# 8570068
# 000221815
# 4/15/2010
# 7/23/2010
# 104(a)
# 4/15/2010
# C
# N
# 50.30(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec50-30.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Dirt Con
# Dirt Con
# J392
# 8570058
# 000220499
# 4/14/2010
# 6/25/2010
# 104(a)
# 4/15/2010
# C
# N
# 56.14100(d)
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec56-14100.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Dirt Con
# Dirt Con
# J392
# 8570061
# 000220499
# 4/14/2010
# 6/25/2010
# 104(a)
# 4/15/2010
# C
# N
# 56.14100(a)
# http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec56-14100.pdf
# 100.00
# Closed
# 100.00
# 100.00
# ---------
# Dirt Con
# Dirt Con
# J392
# 8570054
#
# 4/14/2010
# 107(a)
# 4/14/2010
# O
# N/A
#
# Non-Assessable
# Missing url
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-34-164e05e5bc7e> in <module>()
# ----> 1 all_df.apply(get_violations, axis=1)
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6002                          args=args,
#    6003                          kwds=kwds)
# -> 6004         return op.get_result()
#    6005
#    6006     def applymap(self, func):
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\pandas\core\apply.py in get_result(self)
#     140             return self.apply_raw()
#     141
# --> 142         return self.apply_standard()
#     143
#     144     def apply_empty_result(self):
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     246
#     247         # compute the result using the series generator
# --> 248         self.apply_series_generator()
#     249
#     250         # wrap results
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     275             try:
#     276                 for i, v in enumerate(series_gen):
# --> 277                     results[i] = self.f(v)
#     278                     keys.append(v.name)
#     279             except Exception as e:
#
# <ipython-input-17-30736609cdeb> in get_violations(row)
#      77                 print('Missing url')
#      78
# ---> 79             data['proposed_penalty'] = report.find_elements_by_class_name('drsviols')[11].text
#      80             print(report.find_elements_by_class_name('drsviols')[11].text)
#      81
#
# IndexError: ('list index out of range', 'occurred at index 3')
